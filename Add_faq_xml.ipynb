# %% [markdown]
# ### Add script to faq.xml

# %% [raw]
# #!/usr/bin/env python3
# # -*- coding: utf-8 -*-
# """
# Created on Thu Aug  2 10:20:47 2018
#
# @author: zhili
# """
#
# #from xml.etree.ElementTree import parse, Element
# #doc = parse('faq.xml')
# #root = doc.getroot()
# #
# #
# ## Remove a few elements
# ##root.remove(root.find('sri'))
# ##root.remove(root.find('cr'))
# ## Insert a new element after <nm>...</nm>
# #root.getchildren().index(root.find('qa'))
# #
# #e = Element('spam')
# #e.text = 'This is a test'
# #
# #root.insert(2, e)
# #
# ## Write back to a file
# #doc.write('newpred.xml', xml_declaration=True)
#
#
# TAIL = 4
#
# # --------------
# from xml.etree.ElementTree import ElementTree,Element
#
# def read_xml(in_path):
#     '''读取并解析xml文件
#        in_path: xml路径
#        return: ElementTree'''
#     tree = ElementTree()
#     tree.parse(in_path)
#     return tree
#
# def write_xml(tree, out_path):
#     '''将xml文件写出
#        tree: xml树
#        out_path: 写出路径'''
#     tree.write(out_path, encoding="utf-8",xml_declaration=True)
#
#
# def if_match(node, kv_map):
#     '''判断某个节点是否包含所有传入参数属性
#        node: 节点
#        kv_map: 属性及属性值组成的map'''
#     for key in kv_map:
#         if node.get(key) != kv_map.get(key):
#             return False
#     return True
#
# #---------------search -----
#
# def find_nodes(tree, path):
#     '''查找某个路径匹配的所有节点
#        tree: xml树
#        path: 节点路径'''
#     return tree.findall(path)
#
#
# def get_node_by_keyvalue(nodelist, kv_map):
#     '''根据属性及属性值定位符合的节点，返回节点
#        nodelist: 节点列表
#        kv_map: 匹配属性及属性值map'''
#     result_nodes = []
#     for node in nodelist:
#         if if_match(node, kv_map):
#             result_nodes.append(node)
#     return result_nodes
#
#
# def get_node_by_tag(nodelist, tag):
#     '''根据tag定位符合的节点，返回节点
#        nodelist: 节点列表
#        tag 节点类型'''
#     result_nodes = []
#     for node in nodelist:
#         if node.tag == tag:
#             result_nodes.append(node)
#     return result_nodes
#
# #---------------change -----
#
# def change_node_properties(nodelist, kv_map, is_delete=False):
#     '''修改/增加 /删除 节点的属性及属性值
#        nodelist: 节点列表
#        kv_map:属性及属性值map'''
#     for node in nodelist:
#         for key in kv_map:
#             if is_delete:
#                 if key in node.attrib:
#                     del node.attrib[key]
#             else:
#                 node.set(key, kv_map.get(key))
#
# def change_node_text(nodelist, text, is_add=False, is_delete=False):
#     '''改变/增加/删除一个节点的文本
#        nodelist:节点列表
#        text : 更新后的文本'''
#     for node in nodelist:
#         if is_add:
#             node.text += text
#         elif is_delete:
#             node.text = ""
#         else:
#             node.text = text
#
# def create_node(tag, property_map, content, tail=TAIL):
#     '''新造一个节点
#        tag:节点标签
#        property_map:属性及属性值map
#        content: 节点闭合标签里的文本内容
#        return 新节点'''
#     element = Element(tag, property_map)
#     element.text = content
#     element.tail = "\n" + tail*"  "
#     return element
#
# def add_child_node(nodelist, element, tail=TAIL):
#     '''给一个节点添加子节点
#        nodelist: 节点列表
#        element: 子节点'''
#     # 调节indent
#     if len(nodelist[-1]) > 0:
#         last_node = nodelist[-1][-1]
#         last_node.tail = "\n" + tail*"  "
#     for node in nodelist:
#         node.append(element)
#
# def del_node_by_tagkeyvalue(nodelist, tag, kv_map):
#     '''同过属性及属性值定位一个节点，并删除之
#        nodelist: 父节点列表
#        tag:子节点标签
#        kv_map: 属性及属性值列表'''
#     for parent_node in nodelist:
#         children = parent_node.getchildren()
#         for child in children:
#             if child.tag == tag and if_match(child, kv_map):
#                 parent_node.remove(child)
#
#
#
# def example_2_use():
#
#     #1. 读取xml文件
#     tree = read_xml("test.xml")
#
#     #2. 属性修改
#       #A. 找到父节点
#     nodes = find_nodes(tree, "processers/processer")
#       #B. 通过属性准确定位子节点
#     result_nodes = get_node_by_keyvalue(nodes, {"name":"BProcesser"})
#       #C. 修改节点属性
#     change_node_properties(result_nodes, {"age": "1"})
#       #D. 删除节点属性
#     change_node_properties(result_nodes, {"value":""}, True)
#
#     #3. 节点修改
#       #A.新建节点
#     a = create_node("person", {"age":"15","money":"200000"}, "this is the firest content")
#       #B.插入到父节点之下
#     add_child_node(result_nodes, a)
#
#     #4. 删除节点
#        #定位父节点
#     del_parent_nodes = find_nodes(tree, "processers/services/service")
#        #准确定位子节点并删除之
#     del_node_by_tagkeyvalue(del_parent_nodes, "chain", {"sequency" : "chain1"})
#
#     #5. 修改节点文本
#        #定位节点
#     text_nodes = get_node_by_keyvalue(find_nodes(tree, "processers/services/service/chain"), {"sequency":"chain3"})
#     change_node_text(text_nodes, "new text")
#
#     #6. 输出到结果文件
#     write_xml(tree, "./out.xml")
#
#
#
# def get_seeds_by_scid(scid, path):
#     print(scid)
#     tree = read_xml(path)
#
#     nodes = find_nodes(tree, "intents/intent/qa")
#
# #    scid = "SC86"
#     scid = "VpaGetAnswer__Question--String__"+scid
#
#     result_nodes = get_node_by_keyvalue(nodes, {"id": scid})
#
#     seeds_nodes = get_node_by_keyvalue(result_nodes[0], {"source":"seed"})
#
#     seed_lst = list()
#
#     for seed in seeds_nodes:
#         seed_lst.append(seed.text)
#
#     return seed_lst
#
#
# def get_all_by_scid(scid, path):
#     print(scid)
#     tree = read_xml(path)
#
#     nodes = find_nodes(tree, "intents/intent/qa")
#
# #    scid = "SC86"
#     scid = "VpaGetAnswer__Question--String__"+scid
#
#     result_nodes = get_node_by_keyvalue(nodes, {"id": scid})
#
#     res_nodes = get_node_by_tag(result_nodes[0], tag="question")
#
#     lst = list()
#
#     for node in res_nodes:
#
#         lst.append(node.text)
#
#     return lst
#
#
# def insert_xml(toAddList, scid, path):
#     # --------------faq------------
#     tree = read_xml(path)
#
#     nodes = find_nodes(tree, "intents/intent/qa")
#
#     result_nodes = get_node_by_keyvalue(nodes, {"id": scid})
#
#     from hasher import hashify
#
#     #--------------func------------------------
#     def faq_adding(seeds, path):
#
#         for i in range(len(seeds)):
#             content = seeds[i]
#
#             a = create_node("question", {"id":hashify(content),"scope":"train", "source":"seed"}, content)
#             if i==len(seeds)-1:
#                 a = create_node("question", {"id":hashify(content),"scope":"train", "source":"seed"}, content, tail=3)
#
#             add_child_node(result_nodes, a)
#
#         write_xml(tree, path)
#     #-------------------------------------
#
#     faq_adding(toAddList, path)
#
#     print(scid + "finished.")

# %% [raw]
# a = ["G1011", "Eligibility" ..]
# b = [[xx,xx,xx], [xx,x,x,x]]
# c = {
#     "G1011": [xxx,xxx,xx],
#     "G1011": [xxx,xxx,xx]
# }

# %% [markdown]
# ## Adding question into xml

# %%
# 1

import csv
from pprint import pprint

with open('Jim_2019-01-16-v2_subset.csv', newline='') as file:
    reader = csv.reader(file)
    l = list(map(tuple, reader))
    pprint(l)
# Out:
# [('Question',
#   'Orig Intent',
#   'Orig Answer ID',
#   'Annotated Intent',
#   'Annotated Answer ID',
#   'Annotated Answer Text',
#   'Annotated By',
#   'Correct ID',
#   'comment'),
#  ('税务居留国之确认书',
#   'VpaUnknownRequest',
#   '',
#   'VpaGetDefinition',
#   'G1011',
#   'ID: G1011\nQ: 下載\nA: 只要上我哋嘅網站，你就可以下載所有相關嘅文件或表格。',
#   'tszhim.tsui',
#   '',
#   ''),
#  ('我每月薪金一萬七 可以申請money back 信用卡嗎？',
#   'VpaGetAnswer',
#   'SC318',
#   'VpaGetAnswer',
#   'Eligibility',
#   'ID: Eligibility\n'
#   'Q: 有 什麼 申請 資格\n'
#   'A: I have not learned how to process this request. Can you tell me which '
#   'product are you interested in?',
#   'tszhim.tsui',
#   '',
#   ''),
#  ('怎么开公司户口',
#   'Apply',
#   '',
#   'VpaGetDefinition',
#   'G1015',
#   'ID: G1015',
#   'tszhim.tsui',
#   '',
#   ''),
#  ('查詢網上過數問題',
#   'Transfer',
#   '',
#   'VpaGetAnswer',
#   'SC629-1',
#   'ID: SC629-1\n'
#   'Q: 我 可否 從 網上理財 看 到 戶口結餘\n'
#   'A: 透過網上理財，你幾乎可以登入到所有類型嘅戶口，包括: </br>\n'
#   '<ul>\n'
#   '<li>港幣儲蓄、往來及定期存款戶口；</li>\n'
#   '<li>人民幣存款及定期存款戶口；</li>\n'
#   '<li>外幣儲蓄、往來及定期存款戶口；</li>\n'
#   '<li>按揭戶口；</li>\n'
#   '<li>私人貸款戶口；</li>\n'
#   '<li>信用卡戶口；</li>\n'
#   '<li>投資戶口。</li>\n'
#   '</ul>',
#   'tszhim.tsui',
#   '',
#   ''),
#  ('渣打亞洲萬里通萬事達卡',
#   'VpaGetDefinition',
#   'G400',
#   'VpaGetDefinition',
#   'G400',
#   'ID: G400',
#   'tszhim.tsui',
#   '',
#   ''),
#  ('我想問我credit card statement',
#   'VpaGetDefinition',
#   'G105',
#   'VpaGetAnswer',
#   'GetStatement_DynFAQ',
#   'ID: GetStatement_DynFAQ\nQ: @getstatementtype 信用卡交易紀錄\nA: 你想收到邊一種月結單？',
#   'tszhim.tsui',
#   '',
#   ''),
#  ('同時申請「渣打亞洲萬里通萬事達卡」及「綜合存款戶口, 是否享有可享額外1,111「亞洲萬里通」里數?',
#   'VpaGetAnswer',
#   'SC516',
#   'VpaGetAnswer',
#   'SC516',
#   'ID: SC516\n'
#   'Q: 用 亞洲萬里通信用卡 簽帳 有 什麼 獎賞\n'
#   'A: 用亞洲萬里通萬事達作食肆、網上及海外簽賬每HK$4就可以賺到1里數，其他簽賬每HK$6亦可以賺到1里數。',
#   'tszhim.tsui',
#   '',
#   ''),
#  ('有冇投訴熱線',
#   'VpaGetAnswer',
#   'SC432',
#   'VpaGetAnswer',
#   'SC151',
#   'ID: SC151\n'
#   'Q: 你們 怎樣 處理 客戶 投訴\n'
#   'A: 你嘅意見對我哋好重要，所以喺收到投訴後，我哋會立即跟進，並希望盡快解決你嘅問題，而同事亦會喺期間同你保持聯絡。',
#   'tszhim.tsui',
#   '',
#   ''),
#  ('查詢戶口',
#   'VpaUnknownRequest',
#   '',
#   'VpaGetAnswer',
#   'SC629-1',
#   'ID: SC629-1\n'
#   'Q: 我 可否 從 網上理財 看 到 戶口結餘\n'
#   'A: 透過網上理財，你幾乎可以登入到所有類型嘅戶口，包括: </br>\n'
#   '<ul>\n'
#   '<li>港幣儲蓄、往來及定期存款戶口；</li>\n'
#   '<li>人民幣存款及定期存款戶口；</li>\n'
#   '<li>外幣儲蓄、往來及定期存款戶口；</li>\n'
#   '<li>按揭戶口；</li>\n'
#   '<li>私人貸款戶口；</li>\n'
#   '<li>信用卡戶口；</li>\n'
#   '<li>投資戶口。</li>\n'
#   '</ul>',
#   'tszhim.tsui',
#   '',
#   ''),
#  ('八達通自動增值服務',
#   'VpaGetDefinition',
#   'G374',
#   'VpaGetAnswer',
#   'G374',
#   'ID: Apply\n'
#   'Q: 我 可以 申請 什麼\n'
#   'A: I have not learned how to process this request. Can you tell me which '
#   'product are you interested in?',
#   'tszhim.tsui',
#   'G374',
#   'it is a definition'),
#  ('九唔搭八',
#   'VpaGetAnswer',
#   'SC329',
#   'VpaGetAnswer',
#   'P10',
#   'ID: P10\nQ: 你 點 決 定 答 咩\nA: 如果我答唔到你問題嘅話，麻煩你畀多次機會我，打「重新開始」然後再問。',
#   'tszhim.tsui',
#   '',
#   ''),
#  ('預約公司開戶',
#   'Apply',
#   '',
#   'VpaGetDefinition',
#   'G1015',
#   'ID: G1015',
#   'tszhim.tsui',
#   '',
#   ''),
#  ('想查詢一下如申請銀聯信用卡可否簽申請簽帳分期?',
#   'Apply',
#   '',
#   'VpaGetAnswer',
#   'SC411',
#   'ID: SC411\nQ: 如何 申請 分期付款\nA: 只要消費滿HK$1,500或以上，你就可以喺網上申請我哋嘅信用卡「月結單分期」計劃。',
#   'tszhim.tsui',
#   '',
#   ''),
#  ('我想睇我信用卡嘅網上月結單',
#   'VpaGetDefinition',
#   'G410',
#   'VpaGetAnswer',
#   'GetStatement_DynFAQ',
#   'ID: GetStatement_DynFAQ\nQ: @getstatementtype 信用卡交易紀錄\nA: 你想收到邊一種月結單？',
#   'tszhim.tsui',
#   '',
#   ''),
#  ('电子账户',
#   'VpaUnknownRequest',
#   '',
#   'VpaGetDefinition',
#   'G462',
#   'ID: G462',
#   'tszhim.tsui',
#   '',
#   ''),
#  ('你答緊乜',
#   'VpaUnknownRequest',
#   '',
#   'VpaGetAnswer',
#   'P10',
#   'ID: P10\nQ: 你 點 決 定 答 咩\nA: 如果我答唔到你問題嘅話，麻煩你畀多次機會我，打「重新開始」然後再問。',
#   'tszhim.tsui',
#   '',
#   ''),
#  ('申請資格',
#   'Eligibility',
#   '',
#   'VpaGetAnswer',
#   'Eligibility',
#   'ID: Eligibility\n'
#   'Q: 有 什麼 申請 資格\n'
#   'A: I have not learned how to process this request. Can you tell me which '
#   'product are you interested in?',
#   'tszhim.tsui',
#   '',
#   ''),
#  ('想預訂人民幣',
#   'VpaGetDefinition',
#   'G377',
#   'VpaGetAnswer',
#   'SC4019',
#   'ID: SC4019\nQ: 我 如何 可以 在 分行 兌換 外幣\nA: {ctaId=SC4019}',
#   'tszhim.tsui',
#   '',
#   ''),
#  ('萬里通萬事達信用卡',
#   'VpaGetDefinition',
#   'G410',
#   'VpaGetDefinition',
#   'G400',
#   'ID: G400',
#   'tszhim.tsui',
#   '',
#   ''),
#  ('可以存款嗎',
#   'Apply',
#   '',
#   'VpaGetDefinition',
#   'G387',
#   'ID: G387',
#   'tszhim.tsui',
#   '',
#   ''),
#  ('信用卡積分',
#   'VpaGetDefinition',
#   'G410',
#   'VpaGetDefinition',
#   'G390',
#   'ID: G390\n'
#   'Q: 積分 換領 有 咩 換\n'
#   'A: '
#   '「360°全面賞」積分可以透過信用卡簽賬、存款、投資、保險、個人分期貸款同樓宇按揭貸款嚟賺取，你可以用積分換領唔同獎賞，例如電子產品、飛行里數、家居精品、旅行用品、購物禮券等等。',
#   'tszhim.tsui',
#   '',
#   ''),
#  ('查询一下我个人账户',
#   'VpaGetAnswer',
#   'SC224',
#   'VpaGetAnswer',
#   'SC629-1',
#   'ID: SC629-1\n'
#   'Q: 我 可否 從 網上理財 看 到 戶口結餘\n'
#   'A: 透過網上理財，你幾乎可以登入到所有類型嘅戶口，包括: </br>\n'
#   '<ul>\n'
#   '<li>港幣儲蓄、往來及定期存款戶口；</li>\n'
#   '<li>人民幣存款及定期存款戶口；</li>\n'
#   '<li>外幣儲蓄、往來及定期存款戶口；</li>\n'
#   '<li>按揭戶口；</li>\n'
#   '<li>私人貸款戶口；</li>\n'
#   '<li>信用卡戶口；</li>\n'
#   '<li>投資戶口。</li>\n'
#   '</ul>',
#   'tszhim.tsui',
#   '',
#   ''),
#  ('香港渣打银行的SWIFT NUMBER是多少',
#   'VpaGetAnswer',
#   'SC86',
#   'VpaGetAnswer',
#   'SC86',
#   'ID: SC86\n'
#   'Q: swift 代碼 是 什麼\n'
#   'A: 我哋嘅Swift代碼係 SCBLHKHHXXX，另外以下資料你都可能有用。</br>\n'
#   '銀行代碼：003</br>\n'
#   '銀行名稱：Standard Chartered Bank (Hong Kong) Limited</br>\n'
#   '銀行地址：Payment Centre, 15/F, Standard Chartered Tower, 388 Kwun Tong Road, '
#   'Kwun Tong, Kowloon, Hong Kong</br>\n'
#   '分行代碼：請提供指定接收匯款賬戶嘅首3位賬戶號碼</br>',
#   'kevincs.wong',
#   '',
#   ''),
#  ('查詢信用卡批核情況 以上number是申請信用卡編號',
#   'VpaGetAnswer',
#   'SC365',
#   'VpaGetAnswer',
#   'SC417',
#   'ID: SC417\n'
#   'Q: 如何 查詢 到 我 信用卡 申請 進 度\n'
#   'A: 我嘅同事會有你嘅最新信用卡申請狀況，你可以打去2886 4111搵佢哋幫手喇。',
#   'kevincs.wong',
#   '',
#   ''),
#  ('Hello,想更改聯絡電話',
#   'VpaGetDefinition',
#   'G498',
#   'VpaGetAnswer',
#   'SC433',
#   'ID: SC433\n'
#   'Q: 我 手提電話 已 更改 如何 更新 手提電話 紀錄\n'
#   'A: 最簡單嘅方法係打去2886 8888搵我嘅同事幫你更新電話號碼，你亦可以親身去分行遞交「個人客戶更改通訊資料表格」。',
#   'kevincs.wong',
#   '',
#   ''),
#  ('換信用卡積分',
#   'VpaGetAnswer',
#   'SC812',
#   'VpaGetAnswer',
#   'SC343',
#   'ID: SC343\n'
#   'Q: 如何 兌換 已 賺取 積分\n'
#   'A: 最容易兌換「360°全面賞」積分嘅方法就係透過網上理財服務，只需要喺目錄click入「360°全面賞」，你就可以管理你啲積分喇。',
#   'kevincs.wong',
#   '',
#   ''),
#  ('用來轉$比人会否收手續費？',
#   'VpaGetAnswer',
#   'SC648',
#   'VpaGetAnswer',
#   'SC648',
#   'ID: SC648\n'
#   'Q: 資金 轉帳 需要 任何 收費 嗎\n'
#   'A: 透過網上理財喺本行戶口同其他本地銀行戶口嘅港元轉賬係免費㗎，不過以電匯轉賬或本地電子付款就會收取相應嘅手續費。',
#   'kevincs.wong',
#   '',
#   ''),
#  ('如何登录',
#   'VpaUnknownRequest',
#   '',
#   'VpaGetAnswer',
#   'SC1001',
#   'ID: SC1001\nQ: 如何 登入 網上 理財 戶口\nA: 你只要click喺top menu上嘅「登入」，然後揀「渣打網上理財」就得㗎啦。',
#   'kevincs.wong',
#   '',
#   ''),
#  ('申請取消信用卡年費',
#   'VpaGetAnswer',
#   'SC423',
#   'VpaGetAnswer',
#   'SC423',
#   'ID: SC423\nQ: 可否 豁免 我 信用卡 年費\nA: 我嘅同事可以幫你申請年費豁免，你可以打去2886 4111搵佢哋幫手。',
#   'kevincs.wong',
#   '',
#   ''),
#  ('我意思係現金存款',
#   'VpaGetDefinition',
#   'G489',
#   'VpaGetDefinition',
#   'G489',
#   'ID: G489',
#   'kevincs.wong',
#   '',
#   ''),
#  ('我提供的網上編號怎不對呢',
#   'VpaGetAnswer',
#   'SC110',
#   'VpaGetAnswer',
#   'SC110',
#   'ID: SC110\nQ: 銀行 銀行編號 及 分行 編號 是 什麼\nA: 我哋嘅銀行編號係003，而分行編號就係你獲發嘅戶口號碼頭3位數字。',
#   'kevincs.wong',
#   '',
#   ''),
#  ('我去左旅行交唔到卡數,可否WAIVE?',
#   'VpaGetAnswer',
#   'SC424',
#   'VpaGetAnswer',
#   'SC424',
#   'ID: SC424\nQ: 可以 豁免 我 信用卡 罰 款 嗎\nA: 我嘅同事可以幫你申請豁免購信用卡財務費，佢哋嘅電話係2886 4111。',
#   'kevincs.wong',
#   '',
#   ''),
#  ('人工',
#   'VpaGetAnswer',
#   'SC832-1',
#   'VpaGetAnswer',
#   'SC832-1',
#   'ID: SC832-1\nQ: 人工 客服\nA: 你可以打畀我哋嘅24小時客戶服務熱線2886 8888，或者點擊以下連結同我哋嘅線上客戶顧問傾傾。',
#   'kevincs.wong',
#   '',
#   ''),
#  ('我要上載申請亞洲萬里通卡之所需文件呀',
#   'VpaGetAnswer',
#   'SC435',
#   'VpaGetAnswer',
#   'SC435',
#   'ID: SC435\nQ: 如何 提交 網上 申請 信用卡 所 需 文件\nA: 麻煩你將所需文件上載到我哋嘅網站，我哋會盡快處理你嘅申請。',
#   'kevincs.wong',
#   '',
#   ''),
#  ('我剛用轉數快轉賬，不是即時嗎？',
#   'VpaGetAnswer',
#   'SC4008',
#   'VpaGetAnswer',
#   'SC4008',
#   'ID: SC4008\nQ: 我 如何 透過 sc pay 付款\nA: {ctaId=SC4008}',
#   'kevincs.wong',
#   '',
#   ''),
#  ('經常收到舊租客的信，已把舊信交給管理處多次，寫明冇此人，都沒有用',
#   'VpaGetAnswer',
#   'SC832-1',
#   'VpaGetAnswer',
#   'SC832-1',
#   'ID: SC832-1\nQ: 人工 客服\nA: 你可以打畀我哋嘅24小時客戶服務熱線2886 8888，或者點擊以下連結同我哋嘅線上客戶顧問傾傾。',
#   'kevincs.wong',
#   '',
#   ''),
#  ('你好 想資訊一下 我將有筆海外轉賬轉入本銀行 請問我需要提供的號碼是提款咭上的號碼 或是平時的轉帳發儲蓄號？',
#   'VpaGetAnswer',
#   'SC110',
#   'VpaGetAnswer',
#   'SC86',
#   'ID: SC86\n'
#   'Q: swift 代碼 是 什麼\n'
#   'A: 我哋嘅Swift代碼係 SCBLHKHHXXX，另外以下資料你都可能有用。</br>\n'
#   '銀行代碼：003</br>\n'
#   '銀行名稱：Standard Chartered Bank (Hong Kong) Limited</br>\n'
#   '銀行地址：Payment Centre, 15/F, Standard Chartered Tower, 388 Kwun Tong Road, '
#   'Kwun Tong, Kowloon, Hong Kong</br>\n'
#   '分行代碼：請提供指定接收匯款賬戶嘅首3位賬戶號碼</br>',
#   'kevincs.wong',
#   '',
#   ''),
#  ('請問如何申請中小企戶口?',
#   'Apply',
#   '',
#   'VpaGetDefinition',
#   'G444',
#   'ID: G444\n'
#   'Q: 如何 下載 中小企業\n'
#   'A: 我哋嘅中小企業理財為中小型企業提供全面嘅理財方案，幫你實踐宏圖。你可以click下面了解更多，或者打2886 6988搵我同事傾吓。',
#   'kevincs.wong',
#   '',
#   ''),
#  ('用來出糧',
#   'VpaUnknownRequest',
#   '',
#   'VpaGetDefinition',
#   'G414',
#   'ID: G414\n'
#   'Q: 想 查詢 有 關 出糧戶口 事 宜\n'
#   'A: 渣打「出糧升級組合」助你更精明運用你所賺嘅每$1。你唔單止可以享有特惠儲蓄利息，仲有一系列精彩禮遇。',
#   'kevincs.wong',
#   '',
#   ''),
#  ('港幣户口',
#   'VpaUnknownRequest',
#   '',
#   'VpaGetAnswer',
#   'SC138',
#   'ID: SC138\nQ: 銀行 提供 什麼 戶口 類型\nA: 我哋提供多種戶口選擇，助你管理財富。你可以睇睇邊款戶口符合你嘅需要。',
#   'kevincs.wong',
#   '',
#   ''),
#  ('我已申請, 但以上文件交到哪裡',
#   'VpaGetAnswer',
#   'SC435',
#   'VpaGetAnswer',
#   'SC435',
#   'ID: SC435\nQ: 如何 提交 網上 申請 信用卡 所 需 文件\nA: 麻煩你將所需文件上載到我哋嘅網站，我哋會盡快處理你嘅申請。',
#   'kevincs.wong',
#   '',
#   ''),
#  ('不能登入',
#   'VpaGetAnswer',
#   'SC642-1',
#   'VpaGetAnswer',
#   'SC642-1',
#   'ID: SC642-1\n'
#   'Q: 我 帳戶 為什麼 登錄 不\n'
#   'A: 如果你登入唔到你嘅賬戶，請你打2886 8868，再按1、6、0直接搵我嘅同事幫手喇。',
#   'kevincs.wong',
#   '',
#   ''),
#  ('签賬積分怎样換购禮品？',
#   'VpaGetAnswer',
#   'SC336',
#   'VpaGetAnswer',
#   'SC336',
#   'ID: SC336\n'
#   'Q: 如何 登記 換領 獎賞\n'
#   'A: 我已經幫所有網上理財嘅客戶登記咗「360°全面賞」，你只需要登入網上理財就可以用㗎喇! 如果你冇持有任何網上理財戶口，咁就要去申請返個先喇。',
#   'kevincs.wong',
#   '',
#   ''),
#  ('客服',
#   'VpaGetAnswer',
#   'SC832-1',
#   'VpaGetAnswer',
#   'SC832-1',
#   'ID: SC832-1\nQ: 人工 客服\nA: 你可以打畀我哋嘅24小時客戶服務熱線2886 8888，或者點擊以下連結同我哋嘅線上客戶顧問傾傾。',
#   'kevincs.wong',
#   '',
#   ''),
#  ('Premium理財」客戶豁免海外提款嘅手續費',
#   'VpaGetDefinition',
#   'G372',
#   'VpaGetAnswer',
#   'SC221',
#   'ID: SC221\n'
#   'Q: 用 premium 理財 提款卡 於 海外提款 有 任何 收費 嗎\n'
#   'A: '
#   '我哋已經幫所有「Premium理財」客戶豁免海外提款嘅手續費，所以你係全球所有銀通、MasterCard/Cirrus、銀聯及Visa/PLUS自動櫃員機網絡提款果陣，都唔需要擔心要俾手續費啦。',
#   'kevincs.wong',
#   '',
#   ''),
#  ('想補交申請信用卡文件',
#   'VpaGetDefinition',
#   'G1010',
#   'VpaGetDefinition',
#   'G1010',
#   'ID: G1010\n'
#   'Q: 想 請問 一 下 如果 需要 重新 上 載 申請 信用卡 文件 可以 係邊 做 到\n'
#   'A: 只要上我哋嘅網站，你就可以上載相關申請所需嘅文件。',
#   'kevincs.wong',
#   '',
#   ''),
#  ('我要找職員',
#   'VpaGetAnswer',
#   'SC832',
#   'VpaGetAnswer',
#   'SC832',
#   'ID: SC832\n'
#   'Q: 我 想 同 職員 對話\n'
#   'A: 你可以打畀我哋嘅24小時客戶服務熱線2886 8888，或者點擊以下連結同我哋嘅線上客戶顧問傾傾。',
#   'kevincs.wong',
#   '',
#   ''),
#  ('我想致電bank confirmation department',
#   'VpaGetDefinition',
#   'G399',
#   'VpaGetAnswer',
#   'SC832',
#   'ID: SC832\n'
#   'Q: 我 想 同 職員 對話\n'
#   'A: 你可以打畀我哋嘅24小時客戶服務熱線2886 8888，或者點擊以下連結同我哋嘅線上客戶顧問傾傾。',
#   'kevincs.wong',
#   '',
#   ''),
#  ('我想查询一下我的账户',
#   'VpaGetAnswer',
#   'SC4008-1',
#   'VpaGetAnswer',
#   'SC629-1',
#   'ID: SC629-1\n'
#   'Q: 我 可否 從 網上理財 看 到 戶口結餘\n'
#   'A: 透過網上理財，你幾乎可以登入到所有類型嘅戶口，包括: </br>\n'
#   '<ul>\n'
#   '<li>港幣儲蓄、往來及定期存款戶口；</li>\n'
#   '<li>人民幣存款及定期存款戶口；</li>\n'
#   '<li>外幣儲蓄、往來及定期存款戶口；</li>\n'
#   '<li>按揭戶口；</li>\n'
#   '<li>私人貸款戶口；</li>\n'
#   '<li>信用卡戶口；</li>\n'
#   '<li>投資戶口。</li>\n'
#   '</ul>',
#   'tszhim.tsui',
#   '',
#   ''),
#  ('香港渣打银行邮政编码',
#   'VpaGetDefinition',
#   'G399',
#   'VpaGetAnswer',
#   'SC86',
#   'ID: SC86\n'
#   'Q: swift 代碼 是 什麼\n'
#   'A: 我哋嘅Swift代碼係 SCBLHKHHXXX，另外以下資料你都可能有用。</br>\n'
#   '銀行代碼：003</br>\n'
#   '銀行名稱：Standard Chartered Bank (Hong Kong) Limited</br>\n'
#   '銀行地址：Payment Centre, 15/F, Standard Chartered Tower, 388 Kwun Tong Road, '
#   'Kwun Tong, Kowloon, Hong Kong</br>\n'
#   '分行代碼：請提供指定接收匯款賬戶嘅首3位賬戶號碼</br>',
#   'tszhim.tsui',
#   '',
#   ''),
#  ('迎新是亞洲萬里通獎賞',
#   'VpaGetDefinition',
#   'G458',
#   'VpaGetAnswer',
#   'Promotions_DynFAQ',
#   'ID: Promotions_DynFAQ\nQ: @promotiontype 現金回贈 優惠\nA: 你對邊種優惠有興趣？',
#   'tszhim.tsui',
#   '',
#   ''),
#  ('留了11111111 是否渣打銀行的電話',
#   'VpaGetDefinition',
#   'G498',
#   'VpaGetDefinition',
#   'G498',
#   'ID: G498\nQ: 你們 客服 電話 是 多少\nA: 如果你需要協助，可以打比我哋嘅客戶服務熱線。',
#   'tszhim.tsui',
#   '',
#   ''),
#  ('轉帳收費',
#   'VpaGetDefinition',
#   'G461',
#   'VpaGetAnswer',
#   'SC648',
#   'ID: SC648\n'
#   'Q: 資金 轉帳 需要 任何 收費 嗎\n'
#   'A: 透過網上理財喺本行戶口同其他本地銀行戶口嘅港元轉賬係免費㗎，不過以電匯轉賬或本地電子付款就會收取相應嘅手續費。',
#   'tszhim.tsui',
#   '',
#   ''),
#  ('請問我用櫃員機可以轉賬11,111港紙到中銀戶口嗎',
#   'Transfer',
#   '',
#   'VpaGetAnswer',
#   'SC96',
#   'ID: SC96\n'
#   'Q: 我 可以 憑 atm 卡 使用 什麼 服務\n'
#   'A: 除左提取現金，你亦可以用ATM卡進行現金存款、查詢戶口結餘、戶口轉賬、繳付賬單、申請月結單或支票簿，以及捐款至慈善機構。',
#   'tszhim.tsui',
#   '',
#   ''),
#  ('信用卡不能用',
#   'VpaGetDefinition',
#   'G410',
#   'VpaGetAnswer',
#   'SC317',
#   'ID: SC317\n'
#   'Q: 如 我 在 使用 信用卡 服務 時 遇上 任何 問 題 可以 向 誰 求 助\n'
#   'A: 你可以打電話畀我同事，佢哋會好樂意幫你。呢度係佢哋嘅電話號碼：28864111。你亦可以喺網上搵佢哋幫手。',
#   'tszhim.tsui',
#   '',
#   ''),
#  ('回贈係回落張card?',
#   'VpaUnknownRequest',
#   '',
#   'VpaGetAnswer',
#   'SC383',
#   'ID: SC383\n'
#   'Q: 怎樣 換領現金回贈\n'
#   'A: '
#   '你可以透過網上理財兌換已賺取嘅現金回贈，只需要喺目錄Click入「網上360°全面賞」頁面，就可以直接兌換現金或者其他禮遇，每個戶口嘅最低兌換金額喺HK$50。',
#   'tszhim.tsui',
#   '',
#   ''),
#  ('想問下張visa 白金卡果千幾蚊欠賬係乜來？睇唔到',
#   'VpaGetAnswer',
#   'SC828',
#   'VpaGetAnswer',
#   'SC406',
#   'ID: SC406\n'
#   'Q: 我 怎樣 知道 我 信用卡 應繳 款 項\n'
#   'A: 你可以喺網上理財睇到你嘅信用卡戶口結餘，亦可以喺月結單睇到你所需嘅繳款資料。',
#   'tszhim.tsui',
#   '',
#   ''),
#  ('VISA 欠賬',
#   'VpaUnknownRequest',
#   '',
#   'VpaGetAnswer',
#   'SC406',
#   'ID: SC406\n'
#   'Q: 我 怎樣 知道 我 信用卡 應繳 款 項\n'
#   'A: 你可以喺網上理財睇到你嘅信用卡戶口結餘，亦可以喺月結單睇到你所需嘅繳款資料。',
#   'tszhim.tsui',
#   '',
#   ''),
#  ('可唔可以電話apply定期存款',
#   'Apply',
#   '',
#   'VpaGetAnswer',
#   'Apply',
#   'ID: Apply\n'
#   'Q: 我 可以 申請 什麼\n'
#   'A: I have not learned how to process this request. Can you tell me which '
#   'product are you interested in?',
#   'tszhim.tsui',
#   '',
#   ''),
#  ('尋找旅行優惠', 'ShowOffers', '', 'ShowOffers', '', '', 'tszhim.tsui', '', ''),
#  ('我要從香港渣打銀行匯款到台灣渣打銀行',
#   'VpaGetAnswer',
#   'SC94',
#   'VpaGetAnswer',
#   'SC230',
#   'ID: SC230\nQ: 如何 進行 電匯 交易\nA: 你可以好方便地喺網上理財進行電匯轉賬，亦好歡迎你親臨鄰近嘅分行匯出匯款。',
#   'tszhim.tsui',
#   '',
#   ''),
#  ('请问大额行号是多少？',
#   'VpaGetAnswer',
#   'SC695',
#   'VpaGetAnswer',
#   'SC86',
#   'ID: SC86\n'
#   'Q: swift 代碼 是 什麼\n'
#   'A: 我哋嘅Swift代碼係 SCBLHKHHXXX，另外以下資料你都可能有用。</br>\n'
#   '銀行代碼：003</br>\n'
#   '銀行名稱：Standard Chartered Bank (Hong Kong) Limited</br>\n'
#   '銀行地址：Payment Centre, 15/F, Standard Chartered Tower, 388 Kwun Tong Road, '
#   'Kwun Tong, Kowloon, Hong Kong</br>\n'
#   '分行代碼：請提供指定接收匯款賬戶嘅首3位賬戶號碼</br>',
#   'tszhim.tsui',
#   '',
#   ''),
#  ('你無真人通話？',
#   'VpaGetAnswer',
#   'P3',
#   'VpaGetAnswer',
#   'SC832',
#   'ID: SC832\n'
#   'Q: 我 想 同 職員 對話\n'
#   'A: 你可以打畀我哋嘅24小時客戶服務熱線2886 8888，或者點擊以下連結同我哋嘅線上客戶顧問傾傾。',
#   'tszhim.tsui',
#   '',
#   ''),
#  ('寄件地址',
#   'VpaUnknownRequest',
#   '',
#   'VpaGetDefinition',
#   'G498',
#   'ID: G498\nQ: 你們 客服 電話 是 多少\nA: 如果你需要協助，可以打比我哋嘅客戶服務熱線。',
#   'tszhim.tsui',
#   '',
#   ''),
#  ('人工服务',
#   'VpaGetAnswer',
#   'SC832-1',
#   'VpaGetAnswer',
#   'SC832-1',
#   'ID: SC832-1\nQ: 人工 客服\nA: 你可以打畀我哋嘅24小時客戶服務熱線2886 8888，或者點擊以下連結同我哋嘅線上客戶顧問傾傾。',
#   'vanessa.cheung',
#   '',
#   ''),
#  ('上限是多少呢？',
#   'VpaGetAnswer',
#   'SC93',
#   'VpaGetAnswer',
#   'SC93',
#   'ID: SC93\n'
#   'Q: 每日 現金 透支 上限 為 多少\n'
#   'A: '
#   '「優先理財」或「Premium理財」嘅個別客戶每日預設提款額係HK$30,000，而「快易理財」或非綜合理財嘅個別客戶每日預設提款額就係HK$20,000。',
#   'vanessa.cheung',
#   '',
#   ''),
#  ('點樣賺取現金回贈？',
#   'VpaGetAnswer',
#   'SC345',
#   'VpaGetAnswer',
#   'SC345',
#   'ID: SC345\n'
#   'Q: 如何 賺取 到 現金回贈\n'
#   'A: 你可以憑Simply Cash '
#   'Visa卡或其他合資格現金回贈信用卡簽賬消費就可以賺到現金回贈㗎喇。不過要留意，企業或商務信用卡係唔能夠參與現金回贈嘅。',
#   'vanessa.cheung',
#   '',
#   ''),
#  ('我是新卡主，請問迎新mileage 何時可以取得？',
#   'VpaGetAnswer',
#   'SC431',
#   'VpaGetAnswer',
#   'SC524',
#   'ID: SC524\n'
#   'Q: 我 何 時 會 收 到 亞洲萬里通 迎新 飛行裡數 禮遇\n'
#   'A: 你嘅亞洲萬里通迎新禮遇將會喺新卡發出後5個月內存入到指定戶口。',
#   'vanessa.cheung',
#   '',
#   ''),
#  ('想從外幣戶口取日元',
#   'VpaGetAnswer',
#   'SC752',
#   'VpaGetAnswer',
#   'SC752',
#   'ID: SC752\n'
#   'Q: 快易理財 客戶 在 外幣 戶口 中 存款 或 提款 會 收 取 什麼 費用 嗎\n'
#   'A: '
#   '「快易理財」客戶嘅外幣存款同提款上限係1,500澳元、1,500加元、1,500瑞士法郎、1,500歐元、1,500英鎊、150,000日圓、1,500紐西蘭元、1,500新加坡元或2,500美元。如果金額低過或等於上限，我哋將會豁免手續費。否則會收取相當於存款或提款額0.25%嘅手續費。',
#   'vanessa.cheung',
#   '',
#   ''),
#  ('我因為忘記密碼，在剛剛有去銀行重新申請一個密碼了，但輸入新密碼為什麼還是沒有辦法登入。',
#   'VpaGetAnswer',
#   'SC633',
#   'VpaGetAnswer',
#   'SC633',
#   'ID: SC633\n'
#   'Q: 如果 我 忘記 我 用戶名稱 或 密碼 我 該 怎樣 做\n'
#   'A: 就算你唔記得咗你嘅網上理財帳戶同密碼都唔駛擔心，你可以透過電話理財賬戶及密碼，或者提款卡賬戶及密碼去重新登記。',
#   'vanessa.cheung',
#   '',
#   ''),
#  ('渣打Simply Cash Visa 卡 需要年費嗎?',
#   'VpaGetAnswer',
#   'SC504',
#   'VpaGetAnswer',
#   'SC504',
#   'ID: SC504\n'
#   'Q: simply cash visa card 年費 是 多少\n'
#   'A: Simply Cash '
#   'Visa卡年費為HK$1,800，但如果你係「優先理財」/「Premium理財」/「渣打紅利出糧戶口」嘅客戶就會獲永久免年費，而附屬卡嘅年費亦已被豁免。',
#   'vanessa.cheung',
#   '',
#   ''),
#  ('買禮券雖要付手續費嗎?',
#   'VpaGetAnswer',
#   'SC757',
#   'VpaGetAnswer',
#   'SC757',
#   'ID: SC757\nQ: 快易理財 客戶 簽發 禮券 有 手續費 嗎\nA: 「快易理財」客戶簽發禮券要畀每次HK$10嘅手續費。',
#   'vanessa.cheung',
#   '',
#   ''),
#  ('我想透過網路銀行將我的美金匯到台灣渣打銀行',
#   'VpaGetAnswer',
#   'SC4017',
#   'VpaGetAnswer',
#   'SC230',
#   'ID: SC230\nQ: 如何 進行 電匯 交易\nA: 你可以好方便地喺網上理財進行電匯轉賬，亦好歡迎你親臨鄰近嘅分行匯出匯款。',
#   'vanessa.cheung',
#   '',
#   ''),
#  ('我想登入戶口唔知點解入咗嚟呢個版面',
#   'VpaGetAnswer',
#   'SC1001',
#   'VpaGetAnswer',
#   'SC1001',
#   'ID: SC1001\nQ: 如何 登入 網上 理財 戶口\nA: 你只要click喺top menu上嘅「登入」，然後揀「渣打網上理財」就得㗎啦。',
#   'vanessa.cheung',
#   '',
#   ''),
#  ('請問渣打信用卡有無傻惠機場橋車接送服務',
#   'VpaGetAnswer',
#   'SC489',
#   'VpaGetAnswer',
#   'SC489',
#   'ID: SC489\n'
#   'Q: 我 正 手持 優先理財信用卡 會 不 會 有 priority pass\n'
#   'A: 我哋會為所有「優先理財」信用卡主卡持卡人提供Priority Pass™會藉，你可以免費進入全球各地超過1,000個Priority '
#   'Pass™機場貴賓候機室。只要打去2209 5888登記領取新卡就得喇。',
#   'vanessa.cheung',
#   '',
#   ''),
#  ('電話號碼',
#   'VpaGetDefinition',
#   'G498',
#   'VpaGetDefinition',
#   'G498',
#   'ID: G498\nQ: 你們 客服 電話 是 多少\nA: 如果你需要協助，可以打比我哋嘅客戶服務熱線。',
#   'vanessa.cheung',
#   '',
#   ''),
#  ('信用卡務中心電話？',
#   'VpaGetDefinition',
#   'G410',
#   'VpaGetAnswer',
#   'SC831',
#   'ID: SC831\n'
#   'Q: 如何 聯絡 你們 熱線 職員\n'
#   'A: 最簡單嘅方法當然係打電話畀我哋信用卡熱線嘅同事啦，只需要撥打2886 '
#   '4111然後按1,2,1,#,0選擇中文服務，或者按2,2,1,#,0選擇英文服務。',
#   'vanessa.cheung',
#   '',
#   ''),
#  ('外幣手續費',
#   'VpaGetDefinition',
#   'G377',
#   'VpaGetAnswer',
#   'SC752',
#   'ID: SC752\n'
#   'Q: 快易理財 客戶 在 外幣 戶口 中 存款 或 提款 會 收 取 什麼 費用 嗎\n'
#   'A: '
#   '「快易理財」客戶嘅外幣存款同提款上限係1,500澳元、1,500加元、1,500瑞士法郎、1,500歐元、1,500英鎊、150,000日圓、1,500紐西蘭元、1,500新加坡元或2,500美元。如果金額低過或等於上限，我哋將會豁免手續費。否則會收取相當於存款或提款額0.25%嘅手續費。',
#   'vanessa.cheung',
#   '',
#   ''),
#  ('ATM 存款上限',
#   'VpaGetAnswer',
#   'SC104',
#   'VpaGetAnswer',
#   'SC104',
#   'ID: SC104\n'
#   'Q: 我 最多 可以 存入 多少 張 鈔 票 進 現金存款機\n'
#   'A: 我哋嘅現金存款機每次現金交易可以存入最多99張鈔票，並只接受港幣面額HK$100、HK$500及HK$1,000鈔票。',
#   'vanessa.cheung',
#   '',
#   ''),
#  ('想問下信用卡簽帳分期',
#   'VpaGetDefinition',
#   'G410',
#   'VpaGetAnswer',
#   'SC374',
#   'ID: SC374\n'
#   'Q: 我 可否 以 信用卡 進行 分期付款\n'
#   'A: '
#   '你可以用你嘅信用卡進行月結單分期付款，零售消費夠HK$1,500就可以申請分期，不過並唔包括賭場籌碼、透支現金、上期月結單結欠、以分期付款之簽賬、各項收費或利息。',
#   'vanessa.cheung',
#   '',
#   ''),
#  ('出糧户口推廣',
#   'VpaGetDefinition',
#   'G414',
#   'VpaGetDefinition',
#   'G414',
#   'ID: G414\n'
#   'Q: 想 查詢 有 關 出糧戶口 事 宜\n'
#   'A: 渣打「出糧升級組合」助你更精明運用你所賺嘅每$1。你唔單止可以享有特惠儲蓄利息，仲有一系列精彩禮遇。',
#   'vanessa.cheung',
#   '',
#   ''),
#  ('請問港元定期利率多少',
#   'VpaGetAnswer',
#   'SC119',
#   'VpaGetAnswer',
#   'SC119',
#   'ID: SC119\n'
#   'Q: 今 日 定期存款 利率 是 多少\n'
#   'A: 您只需登入網上理財，然後選擇「利率及匯率」就可以睇到今日嘅定期存款利率，你亦可以點擊以下「查看定期存款利率」到我哋嘅網站去查看利率。 '
#   '。請注意，所列出嘅利率僅供參考，我哋可能會不時進行調整，歡迎你聯絡我哋嘅線上客戶顧問查詢。',
#   'vanessa.cheung',
#   '',
#   ''),
#  ('請問我昨天在海港城消費滿1千想換領現金卷可以在網上登記換領的嗎？',
#   'VpaGetAnswer',
#   'SC336',
#   'VpaGetAnswer',
#   'SC336',
#   'ID: SC336\n'
#   'Q: 如何 登記 換領 獎賞\n'
#   'A: 我已經幫所有網上理財嘅客戶登記咗「360°全面賞」，你只需要登入網上理財就可以用㗎喇! 如果你冇持有任何網上理財戶口，咁就要去申請返個先喇。',
#   'vanessa.cheung',
#   '',
#   ''),
#  ('有關開立渣打出糧戶口事宜',
#   'VpaGetDefinition',
#   'G414',
#   'VpaGetDefinition',
#   'G414',
#   'ID: G414\n'
#   'Q: 想 查詢 有 關 出糧戶口 事 宜\n'
#   'A: 渣打「出糧升級組合」助你更精明運用你所賺嘅每$1。你唔單止可以享有特惠儲蓄利息，仲有一系列精彩禮遇。',
#   'vanessa.cheung',
#   '',
#   ''),
#  ('每天的转账金额上限是多少？',
#   'VpaGetAnswer',
#   'SC93',
#   'VpaGetAnswer',
#   'SC1003',
#   'ID: SC1003\n'
#   'Q: 如何 調 整 每日 轉帳 上限\n'
#   'A: '
#   '喺網上理財加大每日轉帳限額其實好簡單，只要喺目錄選擇「我的喜好」，然後選擇「轉賬額設定」，就可以調整每日限額啦。你亦可以點擊下面連結下載「網上理財更改每日轉賬額表格」 '
#   '，填好後交去任何一間分行或寄返俾我哋。我哋會係收到申請後約三個工作天就會更新有關資料。 ',
#   'vanessa.cheung',
#   '',
#   ''),
#  ('我需要向上面的地址快递文件，但不知道联系电话是什么？',
#   'VpaGetAnswer',
#   'SC435',
#   'VpaGetDefinition',
#   'G498',
#   'ID: G498\nQ: 你們 客服 電話 是 多少\nA: 如果你需要協助，可以打比我哋嘅客戶服務熱線。',
#   'tszhim.tsui',
#   '',
#   ''),
#  ('我登入唔到網上信用卡',
#   'VpaGetAnswer',
#   'SC642-1',
#   'VpaGetAnswer',
#   'SC642',
#   'ID: SC642\n'
#   'Q: 如果 我 未 能 以 正 確 密碼 登 入 帳 戶 我 該 怎樣 做\n'
#   'A: 如果你登入唔到你嘅賬戶，請你打2886 8868，再按1、6、0直接搵我嘅同事幫手喇。',
#   'tszhim.tsui',
#   '',
#   ''),
#  ('请问STANDARD CHARTERED BANK (HONG KONG) LIMITED P.O. BOX 11111 KOWLOON EAST '
#   'POST OFFICE HONG KONG 地址及联系电话是什么？',
#   'VpaUnknownRequest',
#   '',
#   'VpaGetAnswer',
#   'SC832',
#   'ID: SC832\n'
#   'Q: 我 想 同 職員 對話\n'
#   'A: 你可以打畀我哋嘅24小時客戶服務熱線2886 8888，或者點擊以下連結同我哋嘅線上客戶顧問傾傾。',
#   'tszhim.tsui',
#   '',
#   ''),
#  ('亚洲万里通',
#   'VpaUnknownRequest',
#   '',
#   'VpaGetDefinition',
#   'G451',
#   'ID: G451',
#   'tszhim.tsui',
#   '',
#   ''),
#  ('亞洲萬裡通',
#   'VpaUnknownRequest',
#   '',
#   'VpaGetDefinition',
#   'G451',
#   'ID: G451',
#   'tszhim.tsui',
#   '',
#   ''),
#  ('網上估價',
#   'VpaUnknownRequest',
#   '',
#   'VpaGetDefinition',
#   'G463',
#   'ID: G463',
#   'tszhim.tsui',
#   '',
#   ''),
#  ('你好想問111萬新資金係咪有111111 Asia miles',
#   'VpaGetAnswer',
#   'SC334',
#   'VpaGetAnswer',
#   'SC516',
#   'ID: SC516\n'
#   'Q: 用 亞洲萬里通信用卡 簽帳 有 什麼 獎賞\n'
#   'A: 用亞洲萬里通萬事達作食肆、網上及海外簽賬每HK$4就可以賺到1里數，其他簽賬每HK$6亦可以賺到1里數。',
#   'tszhim.tsui',
#   '',
#   ''),
#  ('新戶口首次登入, 如何操作?',
#   'VpaGetAnswer',
#   'SC1001',
#   'VpaGetAnswer',
#   'SC1001',
#   'ID: SC1001\nQ: 如何 登入 網上 理財 戶口\nA: 你只要click喺top menu上嘅「登入」，然後揀「渣打網上理財」就得㗎啦。',
#   'tszhim.tsui',
#   '',
#   ''),
#  ('我在本期月結單見到一項收費 : ANNUAL FEE ANNIVERSARY HKD1111..11',
#   'VpaGetAnswer',
#   'SC424',
#   'VpaGetAnswer',
#   'SC423',
#   'ID: SC423\nQ: 可否 豁免 我 信用卡 年費\nA: 我嘅同事可以幫你申請年費豁免，你可以打去2886 4111搵佢哋幫手。',
#   'tszhim.tsui',
#   '',
#   ''),
#  ('出糧戶口回贈',
#   'VpaGetDefinition',
#   'G414',
#   'VpaGetDefinition',
#   'G414',
#   'ID: G414\n'
#   'Q: 想 查詢 有 關 出糧戶口 事 宜\n'
#   'A: 渣打「出糧升級組合」助你更精明運用你所賺嘅每$1。你唔單止可以享有特惠儲蓄利息，仲有一系列精彩禮遇。',
#   'tszhim.tsui',
#   '',
#   ''),
#  ('現金回贈優惠迎新優惠',
#   'VpaGetAnswer',
#   'Promotions_DynFAQ',
#   'VpaGetAnswer',
#   'Promotions_DynFAQ',
#   'ID: Promotions_DynFAQ\nQ: @promotiontype 現金回贈 優惠\nA: 你對邊種優惠有興趣？',
#   'tszhim.tsui',
#   '',
#   ''),
#  ('你好, 我今天剛開了一個戶口, 但不知是否要收年費..',
#   'VpaGetAnswer',
#   'SC423',
#   'VpaGetAnswer',
#   'SC99',
#   'ID: SC99\n'
#   'Q: 快易理財 有 沒 有 任何 服務費\n'
#   'A: 如果你喺季度內嘅每日平均總結餘滿HK$10,000，即可免費享用我哋嘅「快易理財」升級組合服務；相反，你就需要繳付HK$120 '
#   '為當季度嘅服務費。',
#   'tszhim.tsui',
#   '',
#   ''),
#  ('要收費?',
#   'VpaGetDefinition',
#   'G377',
#   'VpaGetDefinition',
#   'G377',
#   'ID: G377',
#   'tszhim.tsui',
#   '',
#   ''),
#  ('想請問用asia miles 果張mastercard 上網繳交保險 可否儲到里數？',
#   'VpaUnknownRequest',
#   '',
#   'VpaGetAnswer',
#   'SC516',
#   'ID: SC516\n'
#   'Q: 用 亞洲萬里通信用卡 簽帳 有 什麼 獎賞\n'
#   'A: 用亞洲萬里通萬事達作食肆、網上及海外簽賬每HK$4就可以賺到1里數，其他簽賬每HK$6亦可以賺到1里數。',
#   'tszhim.tsui',
#   '',
#   ''),
#  ('想請問用asia miles 果張mastercard 網上繳交保險每年費用， 可否儲到asia miles里數？',
#   'VpaGetAnswer',
#   'SC528',
#   'VpaGetAnswer',
#   'SC516',
#   'ID: SC516\n'
#   'Q: 用 亞洲萬里通信用卡 簽帳 有 什麼 獎賞\n'
#   'A: 用亞洲萬里通萬事達作食肆、網上及海外簽賬每HK$4就可以賺到1里數，其他簽賬每HK$6亦可以賺到1里數。',
#   'tszhim.tsui',
#   '',
#   ''),
#  ('你好，我有一笔汇款，好多天了，为何还没入账？',
#   'VpaGreeting',
#   '',
#   'VpaGetAnswer',
#   'SC112',
#   'ID: SC112\n'
#   'Q: 匯 出 電匯 需 時 多久\n'
#   'A: 匯出電匯其實常快捷方便，通常喺提交匯款申請後1至2個工作天就會被處理，不過電匯時間亦取決於收款銀行。',
#   'tszhim.tsui',
#   '',
#   ''),
#  ('有没人',
#   'VpaUnknownRequest',
#   '',
#   'VpaGetAnswer',
#   'P44',
#   'ID: SC832\n'
#   'Q: 我 想 同 職員 對話\n'
#   'A: 你可以打畀我哋嘅24小時客戶服務熱線2886 8888，或者點擊以下連結同我哋嘅線上客戶顧問傾傾。',
#   'tszhim.tsui',
#   'P44',
#   ''),
#  ('无论用用户名加密码 还是指纹 都无法登录 显示we are unable to process ur request.pls try again',
#   'VpaGetAnswer',
#   'SC632',
#   'VpaGetAnswer',
#   'SC1016',
#   'ID: SC1016\n'
#   'Q: 為何 不能 登入 流動理財 app\n'
#   'A: 如果你登入唔到你嘅網上理財帳戶，可以打去2886 8868(按1,6,0)，直接搵我哋嘅客戶服務主任幫手啦。',
#   'tszhim.tsui',
#   '',
#   ''),
#  ('我要看我戶口裡面有多少錢',
#   'VpaGetAnswer',
#   'SC93',
#   'VpaGetAnswer',
#   'SC629-1',
#   'ID: SC629-1\n'
#   'Q: 我 可否 從 網上理財 看 到 戶口結餘\n'
#   'A: 透過網上理財，你幾乎可以登入到所有類型嘅戶口，包括: </br>\n'
#   '<ul>\n'
#   '<li>港幣儲蓄、往來及定期存款戶口；</li>\n'
#   '<li>人民幣存款及定期存款戶口；</li>\n'
#   '<li>外幣儲蓄、往來及定期存款戶口；</li>\n'
#   '<li>按揭戶口；</li>\n'
#   '<li>私人貸款戶口；</li>\n'
#   '<li>信用卡戶口；</li>\n'
#   '<li>投資戶口。</li>\n'
#   '</ul>',
#   'tszhim.tsui',
#   '',
#   ''),
#  ('業主貸款',
#   'VpaGetDefinition',
#   'G74',
#   'VpaGetAnswer',
#   'Apply',
#   'ID: Apply\n'
#   'Q: 我 可以 申請 什麼\n'
#   'A: I have not learned how to process this request. Can you tell me which '
#   'product are you interested in?',
#   'tszhim.tsui',
#   '',
#   ''),
#  ('請問用asiamiles簽單分期，可同時 賺取asiamiles績分?',
#   'VpaGetAnswer',
#   'SC479',
#   'VpaGetAnswer',
#   'SC516',
#   'ID: SC516\n'
#   'Q: 用 亞洲萬里通信用卡 簽帳 有 什麼 獎賞\n'
#   'A: 用亞洲萬里通萬事達作食肆、網上及海外簽賬每HK$4就可以賺到1里數，其他簽賬每HK$6亦可以賺到1里數。',
#   'tszhim.tsui',
#   '',
#   ''),
#  ('asiamiles master card 分期可賺積分嗎',
#   'VpaGetAnswer',
#   'SC479',
#   'VpaGetAnswer',
#   'SC516',
#   'ID: SC516\n'
#   'Q: 用 亞洲萬里通信用卡 簽帳 有 什麼 獎賞\n'
#   'A: 用亞洲萬里通萬事達作食肆、網上及海外簽賬每HK$4就可以賺到1里數，其他簽賬每HK$6亦可以賺到1里數。',
#   'tszhim.tsui',
#   '',
#   ''),
#  ('信用卡積分換禮物',
#   'VpaGetAnswer',
#   'SC349',
#   'VpaGetAnswer',
#   'SC344',
#   'ID: SC344\n'
#   'Q: 我 可以 用 獎賞 積分 兌換 到 什麼\n'
#   'A: 我哋希望帶畀客戶最好嘅獎賞，所以我哋準備多種驚喜優惠畀你，只要上獎賞目錄就睇到㗎喇!',
#   'tszhim.tsui',
#   '',
#   ''),
#  ('品牌簽賬獎賞',
#   'VpaGetAnswer',
#   'SC516',
#   'VpaGetAnswer',
#   'Promotions_DynFAQ',
#   'ID: Promotions_DynFAQ\nQ: @promotiontype 現金回贈 優惠\nA: 你對邊種優惠有興趣？',
#   'tszhim.tsui',
#   '',
#   ''),
#  ('請問網上申請信用卡幾時可以有答復，多謝',
#   'VpaGetAnswer',
#   'SC435',
#   'VpaGetAnswer',
#   'SC365',
#   'ID: SC365\n'
#   'Q: 申請 信用卡 需 時 多久\n'
#   'A: 當我哋收到所有有效文件後，一般情況下你嘅信用卡申請會喺3至4個星期內處理，但實際時間仍需視乎銀行嘅審批程序。',
#   'michael.chan',
#   '',
#   ''),
#  ('我用唔到face id login',
#   'VpaGetAnswer',
#   'SC642-1',
#   'VpaGetAnswer',
#   'SC642-1',
#   'ID: SC642-1\n'
#   'Q: 我 帳戶 為什麼 登錄 不\n'
#   'A: 如果你登入唔到你嘅賬戶，請你打2886 8868，再按1、6、0直接搵我嘅同事幫手喇。',
#   'michael.chan',
#   '',
#   ''),
#  ('我要看我戶口裡面現在有多少錢',
#   'VpaGetAnswer',
#   'SC93',
#   'VpaGetAnswer',
#   'SC629-1',
#   'ID: SC629-1\n'
#   'Q: 我 可否 從 網上理財 看 到 戶口結餘\n'
#   'A: 透過網上理財，你幾乎可以登入到所有類型嘅戶口，包括: </br>\n'
#   '<ul>\n'
#   '<li>港幣儲蓄、往來及定期存款戶口；</li>\n'
#   '<li>人民幣存款及定期存款戶口；</li>\n'
#   '<li>外幣儲蓄、往來及定期存款戶口；</li>\n'
#   '<li>按揭戶口；</li>\n'
#   '<li>私人貸款戶口；</li>\n'
#   '<li>信用卡戶口；</li>\n'
#   '<li>投資戶口。</li>\n'
#   '</ul>',
#   'michael.chan',
#   '',
#   ''),
#  ('我要看我的戶口裡面有多少錢',
#   'VpaGetAnswer',
#   'SC93',
#   'VpaGetAnswer',
#   'SC629-1',
#   'ID: SC629-1\n'
#   'Q: 我 可否 從 網上理財 看 到 戶口結餘\n'
#   'A: 透過網上理財，你幾乎可以登入到所有類型嘅戶口，包括: </br>\n'
#   '<ul>\n'
#   '<li>港幣儲蓄、往來及定期存款戶口；</li>\n'
#   '<li>人民幣存款及定期存款戶口；</li>\n'
#   '<li>外幣儲蓄、往來及定期存款戶口；</li>\n'
#   '<li>按揭戶口；</li>\n'
#   '<li>私人貸款戶口；</li>\n'
#   '<li>信用卡戶口；</li>\n'
#   '<li>投資戶口。</li>\n'
#   '</ul>',
#   'michael.chan',
#   '',
#   ''),
#  ('打不到 有其他電話嗎',
#   'VpaGetAnswer',
#   'SC4001',
#   'VpaGetAnswer',
#   'SC4001',
#   'ID: SC4001\nQ: 為什麼 你們 熱線 那 麼 繁 忙\nA: {ctaId=SC4001}',
#   'michael.chan',
#   '',
#   ''),
#  ('请问如何申请港元支票薄',
#   'VpaGetAnswer',
#   'SC188',
#   'VpaGetAnswer',
#   'SC188',
#   'ID: SC188\n'
#   'Q: 如何 申請 支票簿\n'
#   'A: '
#   '你可以喺網上理財申請支票簿。只要喺目錄click「支援及服務」，然後跟住指示做就可以完成申請。你亦可以透過填寫申請表格、ATM或電話理財申請支票簿。',
#   'michael.chan',
#   '',
#   ''),
#  ('我想上網交税，應該點做？',
#   'VpaGetAnswer',
#   'SC659',
#   'VpaGetAnswer',
#   'SC638',
#   'ID: SC638\n'
#   'Q: 如 可 透過 網上理財 繳付 稅 項\n'
#   'A: 有咗網上理財，交稅變得更簡單、直接! '
#   '你只要揀「繳款」，喺商戶類別選擇「政府或法定機構」，然後喺商戶名稱按「稅務局」以繳付賬單。如果稅務總額超過HK$99,999，你就可能要分兩次去交稅㗎。',
#   'michael.chan',
#   '',
#   ''),
#  ('電話號碼?',
#   'VpaGetDefinition',
#   'G498',
#   'VpaGetDefinition',
#   'G498',
#   'ID: G498\nQ: 你們 客服 電話 是 多少\nA: 如果你需要協助，可以打比我哋嘅客戶服務熱線。',
#   'michael.chan',
#   '',
#   ''),
#  ('已申請 但卡還未有',
#   'VpaGetAnswer',
#   'SC424-1',
#   'VpaGetAnswer',
#   'SC417',
#   'ID: SC417\n'
#   'Q: 如何 查詢 到 我 信用卡 申請 進 度\n'
#   'A: 我嘅同事會有你嘅最新信用卡申請狀況，你可以打去2886 4111搵佢哋幫手喇。',
#   'michael.chan',
#   '',
#   ''),
#  ('我想問下張simply cash張卡申請狀況？',
#   'VpaGetAnswer',
#   'SC417',
#   'VpaGetAnswer',
#   'SC417',
#   'ID: SC417\n'
#   'Q: 如何 查詢 到 我 信用卡 申請 進 度\n'
#   'A: 我嘅同事會有你嘅最新信用卡申請狀況，你可以打去2886 4111搵佢哋幫手喇。',
#   'michael.chan',
#   '',
#   ''),
#  ('想問有關按揭事宜',
#   'VpaGetDefinition',
#   'G414',
#   'VpaGetDefinition',
#   'G80',
#   'ID: G80',
#   'michael.chan',
#   '',
#   ''),
#  ('我想做網上物業估價',
#   'VpaGetAnswer',
#   'SC659',
#   'VpaGetDefinition',
#   'G463',
#   'ID: G463',
#   'michael.chan',
#   '',
#   ''),
#  ('你有冇家居保險既熱線電話',
#   'Apply',
#   '',
#   'VpaGetDefinition',
#   'G498',
#   'ID: G498\nQ: 你們 客服 電話 是 多少\nA: 如果你需要協助，可以打比我哋嘅客戶服務熱線。',
#   'michael.chan',
#   '',
#   ''),
#  ('請問如何登記為「渣打亞洲萬里通萬事達卡會員推薦計劃 」的推薦人?',
#   'VpaGetDefinition',
#   'G449',
#   'VpaGetDefinition',
#   'G449',
#   'ID: G449\nQ: 我 想 推薦朋友 申請 信用卡\nA: 同你嘅親友分享用渣打理財服務同信用卡嘅喜悅，仲可以獲得額外獎賞！',
#   'michael.chan',
#   '',
#   ''),
#  ('111萬定期',
#   'VpaGetDefinition',
#   'G432',
#   'VpaGetDefinition',
#   'G428',
#   'ID: G428',
#   'michael.chan',
#   '',
#   ''),
#  ('定期',
#   'VpaGetDefinition',
#   'G432',
#   'VpaGetDefinition',
#   'G428',
#   'ID: G428',
#   'michael.chan',
#   '',
#   ''),
#  ('电汇汇出有转帐记录吗？',
#   'VpaGetAnswer',
#   'SC112',
#   'VpaGetAnswer',
#   'SC629-1',
#   'ID: SC629-1\n'
#   'Q: 我 可否 從 網上理財 看 到 戶口結餘\n'
#   'A: 透過網上理財，你幾乎可以登入到所有類型嘅戶口，包括: </br>\n'
#   '<ul>\n'
#   '<li>港幣儲蓄、往來及定期存款戶口；</li>\n'
#   '<li>人民幣存款及定期存款戶口；</li>\n'
#   '<li>外幣儲蓄、往來及定期存款戶口；</li>\n'
#   '<li>按揭戶口；</li>\n'
#   '<li>私人貸款戶口；</li>\n'
#   '<li>信用卡戶口；</li>\n'
#   '<li>投資戶口。</li>\n'
#   '</ul>',
#   'michael.chan',
#   '',
#   ''),
#  ('电汇没有汇出的原因',
#   'VpaGetAnswer',
#   'SC112',
#   'VpaGetAnswer',
#   'SC112',
#   'ID: SC112\n'
#   'Q: 匯 出 電匯 需 時 多久\n'
#   'A: 匯出電匯其實常快捷方便，通常喺提交匯款申請後1至2個工作天就會被處理，不過電匯時間亦取決於收款銀行。',
#   'michael.chan',
#   '',
#   ''),
#  ('請問如果我想更改郵寄地址, 但不方便去銀行辦理, 可以將表格傳真去哪個號碼?',
#   'VpaGetAnswer',
#   'SC353',
#   'VpaGetAnswer',
#   'SC353',
#   'ID: SC353\n'
#   'Q: 如何 更改 個人 資料\n'
#   'A: 最容易嘅方法係透過網上理財更改你嘅個人資料，你亦可以打去2886 8888搵同事幫手，或者遞交「個人客戶更改通訊資料表格」畀我哋。',
#   'michael.chan',
#   '',
#   ''),
#  ('更改地址',
#   'VpaGetAnswer',
#   'SC434',
#   'VpaGetAnswer',
#   'SC434',
#   'ID: SC434\n'
#   'Q: 我 已 經 搬 離 住址 如何 更新 地址\n'
#   'A: 最簡單嘅方法係登入網上理財去更新你嘅地址，你亦可以打去2886 8888搵我嘅同事幫手，或者親身去分行遞交「個人客戶更改通訊資料表格」。',
#   'michael.chan',
#   '',
#   ''),
#  ('电汇到香港花旗银行需要多长时间',
#   'VpaGetDefinition',
#   'G329',
#   'VpaGetAnswer',
#   'SC112',
#   'ID: SC112\n'
#   'Q: 匯 出 電匯 需 時 多久\n'
#   'A: 匯出電匯其實常快捷方便，通常喺提交匯款申請後1至2個工作天就會被處理，不過電匯時間亦取決於收款銀行。',
#   'michael.chan',
#   '',
#   ''),
#  ('怎么确认网上银行电汇已经汇出？',
#   'VpaGetAnswer',
#   'SC112',
#   'VpaGetAnswer',
#   'SC112',
#   'ID: SC112\n'
#   'Q: 匯 出 電匯 需 時 多久\n'
#   'A: 匯出電匯其實常快捷方便，通常喺提交匯款申請後1至2個工作天就會被處理，不過電匯時間亦取決於收款銀行。',
#   'michael.chan',
#   '',
#   ''),
#  ('請問點樣用信用咭交稅?',
#   'VpaGetAnswer',
#   'SC355',
#   'VpaGetAnswer',
#   'SC638',
#   'ID: SC638\n'
#   'Q: 如 可 透過 網上理財 繳付 稅 項\n'
#   'A: 有咗網上理財，交稅變得更簡單、直接! '
#   '你只要揀「繳款」，喺商戶類別選擇「政府或法定機構」，然後喺商戶名稱按「稅務局」以繳付賬單。如果稅務總額超過HK$99,999，你就可能要分兩次去交稅㗎。',
#   'michael.chan',
#   '',
#   ''),
#  ('电汇手续费',
#   'VpaGetDefinition',
#   'G329',
#   'VpaGetAnswer',
#   'SC657',
#   'ID: SC657\nQ: 電匯 收費 是 多少\nA: 詳情請參閱本行之最新服務收費表。',
#   'michael.chan',
#   '',
#   ''),
#  ('我忘記網上登入密碼',
#   'VpaGetAnswer',
#   'SC633',
#   'VpaGetAnswer',
#   'SC633',
#   'ID: SC633\n'
#   'Q: 如果 我 忘記 我 用戶名稱 或 密碼 我 該 怎樣 做\n'
#   'A: 就算你唔記得咗你嘅網上理財帳戶同密碼都唔駛擔心，你可以透過電話理財賬戶及密碼，或者提款卡賬戶及密碼去重新登記。',
#   'michael.chan',
#   '',
#   ''),
#  ('信用咭繳稅',
#   'VpaGetDefinition',
#   'G410',
#   'VpaGetAnswer',
#   'SC638',
#   'ID: SC638\n'
#   'Q: 如 可 透過 網上理財 繳付 稅 項\n'
#   'A: 有咗網上理財，交稅變得更簡單、直接! '
#   '你只要揀「繳款」，喺商戶類別選擇「政府或法定機構」，然後喺商戶名稱按「稅務局」以繳付賬單。如果稅務總額超過HK$99,999，你就可能要分兩次去交稅㗎。',
#   'michael.chan',
#   '',
#   ''),
#  ('信用卡交稅',
#   'VpaGetDefinition',
#   'G410',
#   'VpaGetAnswer',
#   'SC638',
#   'ID: SC638\n'
#   'Q: 如 可 透過 網上理財 繳付 稅 項\n'
#   'A: 有咗網上理財，交稅變得更簡單、直接! '
#   '你只要揀「繳款」，喺商戶類別選擇「政府或法定機構」，然後喺商戶名稱按「稅務局」以繳付賬單。如果稅務總額超過HK$99,999，你就可能要分兩次去交稅㗎。',
#   'michael.chan',
#   '',
#   ''),
#  ('轉帳需要填嗎',
#   'Transfer',
#   '',
#   'VpaGetAnswer',
#   'SC4008-1',
#   'ID: SC4008-1\nQ: 如何 轉帳\nA: {ctaId=SC4008}',
#   'tszhim.tsui',
#   '',
#   ''),
#  ('你有咩幫到我?', 'VpaGetAnswer', 'SC1022', 'Help', '', '', 'tszhim.tsui', '', ''),
#  ('我可以用 Asiamiles Mastercard去交稅嗎?',
#   'VpaGetAnswer',
#   'SC638',
#   'VpaGetAnswer',
#   'SC638',
#   'ID: SC638\n'
#   'Q: 如 可 透過 網上理財 繳付 稅 項\n'
#   'A: 有咗網上理財，交稅變得更簡單、直接! '
#   '你只要揀「繳款」，喺商戶類別選擇「政府或法定機構」，然後喺商戶名稱按「稅務局」以繳付賬單。如果稅務總額超過HK$99,999，你就可能要分兩次去交稅㗎。',
#   'tszhim.tsui',
#   '',
#   ''),
#  ('如果我只有信用卡可以網上理財交稅嗎？',
#   'VpaGetAnswer',
#   'SC638',
#   'VpaGetAnswer',
#   'SC355',
#   'ID: SC355\n'
#   'Q: 如何 以 信用卡 繳付 帳單 費用\n'
#   'A: 用信用卡繳費非常簡單，只要喺網上理財加入收款人，然後喺收款人清單入面揀返收款人個名去繳費就得㗎喇。',
#   'tszhim.tsui',
#   '',
#   ''),
#  ('有冇電話可以直接問',
#   'VpaGetAnswer',
#   'SC831',
#   'VpaGetAnswer',
#   'SC832',
#   'ID: SC832\n'
#   'Q: 我 想 同 職員 對話\n'
#   'A: 你可以打畀我哋嘅24小時客戶服務熱線2886 8888，或者點擊以下連結同我哋嘅線上客戶顧問傾傾。',
#   'tszhim.tsui',
#   '',
#   ''),
#  ('我成功登入網上理財後，無法查閱我最近信用卡的消費記錄',
#   'VpaGetAnswer',
#   'SC1012',
#   'VpaGetAnswer',
#   'GetStatement_DynFAQ',
#   'ID: GetStatement_DynFAQ\nQ: @getstatementtype 信用卡交易紀錄\nA: 你想收到邊一種月結單？',
#   'tszhim.tsui',
#   '',
#   ''),
#  ('想問問我的戶口中的一筆繳費是什麼',
#   'VpaGetAnswer',
#   'SC110',
#   'VpaGetAnswer',
#   'GetStatement_DynFAQ',
#   'ID: GetStatement_DynFAQ\nQ: @getstatementtype 信用卡交易紀錄\nA: 你想收到邊一種月結單？',
#   'tszhim.tsui',
#   '',
#   ''),
#  ('信用卡 111 reward',
#   'VpaGetDefinition',
#   'G410',
#   'VpaGetDefinition',
#   'G389',
#   'ID: G389',
#   'tszhim.tsui',
#   '',
#   ''),
#  ('电汇处理的工作时间？',
#   'VpaGetDefinition',
#   'G329',
#   'VpaGetAnswer',
#   'SC234',
#   'ID: SC234\n'
#   'Q: 電匯 交易 付款 何 時 會 被 處理\n'
#   'A: 匯出電匯其實非常快捷方便，通常喺提交匯款申請後1至2個工作天就會被處理，不過電匯時間亦取決於收款銀行。',
#   'tszhim.tsui',
#   '',
#   ''),
#  ('請問用asiamile card 網上交學費可以儲里數嗎?',
#   'VpaGetAnswer',
#   'SC659',
#   'VpaGetAnswer',
#   'SC516',
#   'ID: SC516\n'
#   'Q: 用 亞洲萬里通信用卡 簽帳 有 什麼 獎賞\n'
#   'A: 用亞洲萬里通萬事達作食肆、網上及海外簽賬每HK$4就可以賺到1里數，其他簽賬每HK$6亦可以賺到1里數。',
#   'tszhim.tsui',
#   '',
#   ''),
#  ('網上繳費有里數嗎?',
#   'VpaGetAnswer',
#   'SC659',
#   'VpaGetAnswer',
#   'SC516',
#   'ID: SC516\n'
#   'Q: 用 亞洲萬里通信用卡 簽帳 有 什麼 獎賞\n'
#   'A: 用亞洲萬里通萬事達作食肆、網上及海外簽賬每HK$4就可以賺到1里數，其他簽賬每HK$6亦可以賺到1里數。',
#   'tszhim.tsui',
#   '',
#   ''),
#  ('电汇转账处理时间',
#   'VpaGetAnswer',
#   'SC230',
#   'VpaGetAnswer',
#   'SC234',
#   'ID: SC234\n'
#   'Q: 電匯 交易 付款 何 時 會 被 處理\n'
#   'A: 匯出電匯其實非常快捷方便，通常喺提交匯款申請後1至2個工作天就會被處理，不過電匯時間亦取決於收款銀行。',
#   'tszhim.tsui',
#   '',
#   ''),
#  ('电汇服务时间',
#   'VpaGetDefinition',
#   'G122',
#   'VpaGetAnswer',
#   'SC234',
#   'ID: SC234\n'
#   'Q: 電匯 交易 付款 何 時 會 被 處理\n'
#   'A: 匯出電匯其實非常快捷方便，通常喺提交匯款申請後1至2個工作天就會被處理，不過電匯時間亦取決於收款銀行。',
#   'tszhim.tsui',
#   '',
#   ''),
#  ('各戶口有咩分別？我不是用做定期，',
#   'VpaGetAnswer',
#   'SC141',
#   'VpaGetAnswer',
#   'SC138',
#   'ID: SC138\nQ: 銀行 提供 什麼 戶口 類型\nA: 我哋提供多種戶口選擇，助你管理財富。你可以睇睇邊款戶口符合你嘅需要。',
#   'tszhim.tsui',
#   '',
#   ''),
#  ('你識做得乜嘢?', 'VpaGetAnswer', 'P29', 'Help', '', '', 'tszhim.tsui', '', ''),
#  ('需要什麼證明文件',
#   'VpaGetDefinition',
#   'G1011',
#   'VpaGetAnswer',
#   'Eligibility',
#   'ID: Eligibility\n'
#   'Q: 有 什麼 申請 資格\n'
#   'A: I have not learned how to process this request. Can you tell me which '
#   'product are you interested in?',
#   'tszhim.tsui',
#   '',
#   ''),
#  ('咁你識得啲乜嘢?', 'VpaGetAnswer', 'P29', 'Help', '', '', 'tszhim.tsui', '', ''),
#  ('我想將信用卡回贈金額。全數入番落信用卡戶口度',
#   'VpaGetAnswer',
#   'SC417',
#   'VpaGetAnswer',
#   'SC383',
#   'ID: SC383\n'
#   'Q: 怎樣 換領現金回贈\n'
#   'A: '
#   '你可以透過網上理財兌換已賺取嘅現金回贈，只需要喺目錄Click入「網上360°全面賞」頁面，就可以直接兌換現金或者其他禮遇，每個戶口嘅最低兌換金額喺HK$50。',
#   'tszhim.tsui',
#   '',
#   ''),
#  ('樂富分行有提供保管箱服務嗎？',
#   'ATMFinder',
#   '',
#   'ATMFinder',
#   '',
#   '',
#   'tszhim.tsui',
#   '',
#   ''),
#  ('本人已持有渣打銀行戶口，想做港元定期，請問利率點計，有何手續？',
#   'ATMFinder',
#   '',
#   'VpaGetAnswer',
#   'SC119',
#   'ID: SC119\n'
#   'Q: 今 日 定期存款 利率 是 多少\n'
#   'A: 您只需登入網上理財，然後選擇「利率及匯率」就可以睇到今日嘅定期存款利率，你亦可以點擊以下「查看定期存款利率」到我哋嘅網站去查看利率。 '
#   '。請注意，所列出嘅利率僅供參考，我哋可能會不時進行調整，歡迎你聯絡我哋嘅線上客戶顧問查詢。',
#   'tszhim.tsui',
#   '',
#   ''),
#  ('我想問取消聯名戶口有什麼手續',
#   'VpaGetAnswer',
#   'SC1015',
#   'VpaGetAnswer',
#   'SC87',
#   'ID: SC87\n'
#   'Q: 怎樣 取消 我 銀行戶口\n'
#   'A: '
#   '如果想取消戶口，你要帶同有效身分證明文件去我哋係香港嘅任何一間分行，我哋嘅同事就會幫你處理㗎喇。雖然我覺得好可惜，不過希望未來我哋可以再次為你服務!',
#   'tszhim.tsui',
#   '',
#   ''),
#  ('一般經網上銀行付款需時多少個工作天',
#   'VpaGetAnswer',
#   'SC349',
#   'VpaGetAnswer',
#   'SC662',
#   'ID: SC662\n'
#   'Q: 帳單 繳 款 有沒有 截數時間\n'
#   'A: 繳付賬款嘅截數時間係星期一至五下午四點 '
#   '。喺截數時間後或星期六、日及公眾假期進行嘅繳款都會喺下一個結算日去處理。記得睇清楚今日係咪最後嘅繳款日期喇。',
#   'tszhim.tsui',
#   '',
#   ''),
#  ('信用卡返现怎么拿到钱？',
#   'VpaGetDefinition',
#   'G410',
#   'VpaGetAnswer',
#   'SC383',
#   'ID: SC383\n'
#   'Q: 怎樣 換領現金回贈\n'
#   'A: '
#   '你可以透過網上理財兌換已賺取嘅現金回贈，只需要喺目錄Click入「網上360°全面賞」頁面，就可以直接兌換現金或者其他禮遇，每個戶口嘅最低兌換金額喺HK$50。',
#   'tszhim.tsui',
#   '',
#   ''),
#  ('Visa signature card 積分有咩用？',
#   'VpaGetAnswer',
#   'SC344',
#   'VpaGetAnswer',
#   'SC344',
#   'ID: SC344\n'
#   'Q: 我 可以 用 獎賞 積分 兌換 到 什麼\n'
#   'A: 我哋希望帶畀客戶最好嘅獎賞，所以我哋準備多種驚喜優惠畀你，只要上獎賞目錄就睇到㗎喇!',
#   'paul.yuen',
#   '',
#   ''),
#  ('如何網上交稅',
#   'VpaGetAnswer',
#   'SC638-1',
#   'VpaGetAnswer',
#   'SC638-1',
#   'ID: SC638-1\n'
#   'Q: 交 稅\n'
#   'A: 有咗網上理財，交稅變得更簡單、直接! '
#   '你只要揀「繳款」，喺商戶類別選擇「政府或法定機構」，然後喺商戶名稱按「稅務局」以繳付賬單。如果稅務總額超過HK$99,999，你就可能要分兩次去交稅㗎。',
#   'paul.yuen',
#   '',
#   ''),
#  ('我未收到提款卡密碼',
#   'ATMFinder',
#   '',
#   'VpaGetAnswer',
#   'SC1006-1',
#   'ID: SC1006-1\n'
#   'Q: 我 提款卡 密碼 是 什麼\n'
#   'A: 我哋嘅客戶顧問可以俾個新嘅櫃員機密碼你。你只要click下面條link，就可以搵到佢地幫手㗎啦。我哋亦都好歡迎你嚟我哋嘅分行辦理。',
#   'paul.yuen',
#   '',
#   ''),
#  ('按忘記密碼，跟着步驟輸入資料又說錯誤',
#   'VpaGetAnswer',
#   'SC1006',
#   'VpaGetAnswer',
#   'SC1006',
#   'ID: SC1006\n'
#   'Q: 如何 重設 私人密碼\n'
#   'A: 我哋嘅客戶顧問可以俾個新嘅櫃員機密碼你。你只要click下面條link，就可以搵到佢地幫手㗎啦。我哋亦都好歡迎你嚟我哋嘅分行辦理。',
#   'paul.yuen',
#   '',
#   ''),
#  ('我已經持有Manhattan信用咭，那是否屬於舊客戶？',
#   'VpaGetAnswer',
#   'SC364',
#   'VpaGetAnswer',
#   'SC364',
#   'ID: SC364\n'
#   'Q: 如果 我 是 現有 客戶 會 否 收 到 迎新 禮遇\n'
#   'A: 我哋只會為喺過去6個月都冇持有渣打信用卡或MANHATTAN信用卡主卡嘅客戶提供迎新禮遇，如果你想了解更多，可以睇吓我哋嘅信用卡申請條款及細則。',
#   'paul.yuen',
#   '',
#   ''),
#  ('請問信用卡批核情況',
#   'VpaGetDefinition',
#   'G410',
#   'VpaGetAnswer',
#   'SC417',
#   'ID: SC417\n'
#   'Q: 如何 查詢 到 我 信用卡 申請 進 度\n'
#   'A: 我嘅同事會有你嘅最新信用卡申請狀況，你可以打去2886 4111搵佢哋幫手喇。',
#   'paul.yuen',
#   '',
#   ''),
#  ('你係咪機器人',
#   'VpaGetAnswer',
#   'P70',
#   'VpaGetAnswer',
#   'P70',
#   'ID: P70\nQ: 你 係 人 定 機械人\nA: 我就係我。',
#   'paul.yuen',
#   '',
#   ''),
#  ('請問我有設海外提款，1/11-1/11，但是我在馬來西亞的渣打銀行也領不出來',
#   'VpaGetAnswer',
#   'SC413',
#   'VpaGetAnswer',
#   'SC413',
#   'ID: SC413\n'
#   'Q: 如何 啟用 海外提款\n'
#   'A: 想啓動海外提款服務，最方便嘅方法係透過網上理財啓動服務，你亦可以透過本地或者我哋分行嘅銀通自動櫃員機、或打去2886 8868搵同事幫手。',
#   'paul.yuen',
#   '',
#   ''),
#  ('筲箕灣有冇入錢機？', 'ATMFinder', '', 'ATMFinder', '', '', 'paul.yuen', '', ''),
#  ('我 internet banking有問題',
#   'VpaGetAnswer',
#   'SC1012',
#   'VpaGetAnswer',
#   'SC1012',
#   'ID: SC1012\n'
#   'Q: 為何 不能 登入 網上理財\n'
#   'A: 如果你登入唔到你嘅網上理財帳戶，可以打去2886 8868(按1,6,0)，直接搵我哋嘅客戶服務主任幫手啦。',
#   'paul.yuen',
#   '',
#   ''),
#  ('你好,之前有信息提我補交申請信用卡證明文件,但係條link入唔到,想問問應該點做?',
#   'VpaGetAnswer',
#   'SC435',
#   'VpaGetAnswer',
#   'SC435',
#   'ID: SC435\nQ: 如何 提交 網上 申請 信用卡 所 需 文件\nA: 麻煩你將所需文件上載到我哋嘅網站，我哋會盡快處理你嘅申請。',
#   'paul.yuen',
#   '',
#   ''),
#  ('安卓app怎么下载',
#   'VpaGetAnswer',
#   'SC1016',
#   'VpaGetAnswer',
#   'SC1009',
#   'ID: SC1009\n'
#   'Q: 如何 下載 app\n'
#   'A: 您可以喺Apple App Store同Google Play Store搵「SC Mobile」，然後免費下載我哋嘅SC Mobile '
#   'App。你亦都可以去我哋網站下載個App㗎。',
#   'paul.yuen',
#   '',
#   ''),
#  ('你識答乜問題?',
#   'VpaGetAnswer',
#   'P5',
#   'VpaGetAnswer',
#   'P5',
#   'ID: P5\nQ: 我 應該 點 問 你 問 題\nA: 同你平時send短訊畀朋友一樣，我中文好流行㗎!',
#   'paul.yuen',
#   '',
#   ''),
#  ('手續費',
#   'VpaGetDefinition',
#   'G377',
#   'VpaGetDefinition',
#   'G377',
#   'ID: G377',
#   'paul.yuen',
#   '',
#   ''),
#  ('香港本地电汇当天的工作截止时间是？',
#   'VpaUnknownRequest',
#   '',
#   'VpaGetAnswer',
#   'SC646',
#   'ID: SC646\n'
#   'Q: 我 可以 在 任何時間 轉帳 嗎\n'
#   'A: '
#   '你可以喺任何時間作相同貨幣嘅轉賬，但係唔同貨幣嘅轉賬就只限於星期一至五由上午9點至晚上9點，而星期六就由上午9點至下午1點，星期日同公眾假期除外。',
#   'paul.yuen',
#   '',
#   ''),
#  ('信用卡客服电话',
#   'VpaGetDefinition',
#   'G410',
#   'VpaGetAnswer',
#   'SC831',
#   'ID: SC831\n'
#   'Q: 如何 聯絡 你們 熱線 職員\n'
#   'A: 最簡單嘅方法當然係打電話畀我哋信用卡熱線嘅同事啦，只需要撥打2886 '
#   '4111然後按1,2,1,#,0選擇中文服務，或者按2,2,1,#,0選擇英文服務。',
#   'paul.yuen',
#   '',
#   ''),
#  ('你好，請問外幣存款收手續費嗎？',
#   'ATMFinder',
#   '',
#   'VpaGetAnswer',
#   'SC752',
#   'ID: SC752\n'
#   'Q: 快易理財 客戶 在 外幣 戶口 中 存款 或 提款 會 收 取 什麼 費用 嗎\n'
#   'A: '
#   '「快易理財」客戶嘅外幣存款同提款上限係1,500澳元、1,500加元、1,500瑞士法郎、1,500歐元、1,500英鎊、150,000日圓、1,500紐西蘭元、1,500新加坡元或2,500美元。如果金額低過或等於上限，我哋將會豁免手續費。否則會收取相當於存款或提款額0.25%嘅手續費。',
#   'paul.yuen',
#   '',
#   ''),
#  ('Simply Cash 沒有永久豁免年費？',
#   'VpaGetAnswer',
#   'SC503',
#   'VpaGetAnswer',
#   'SC503',
#   'ID: SC503\n'
#   'Q: 可以 豁免 我 simply cash 信用卡 年費 嗎\n'
#   'A: 如果你係「優先理財」/「Premium理財」/「渣打紅利出糧戶口」嘅客戶，我哋會為你嘅Simply Cash Visa卡主卡永久豁免年費㗎。',
#   'paul.yuen',
#   '',
#   ''),
#  ('什麼是渣打亞洲萬里通萬事達卡',
#   'VpaGetDefinition',
#   'G400',
#   'VpaGetDefinition',
#   'G400',
#   'ID: G400',
#   'paul.yuen',
#   '',
#   ''),
#  ('請問轉帳需要填分行信息嗎？',
#   'VpaGetAnswer',
#   'SC110',
#   'VpaGetAnswer',
#   'SC110',
#   'ID: SC110\nQ: 銀行 銀行編號 及 分行 編號 是 什麼\nA: 我哋嘅銀行編號係003，而分行編號就係你獲發嘅戶口號碼頭3位數字。',
#   'paul.yuen',
#   '',
#   ''),
#  ('信用卡查詢',
#   'VpaGetDefinition',
#   'G410',
#   'VpaGetDefinition',
#   'G410',
#   'ID: G410',
#   'paul.yuen',
#   '',
#   ''),
#  ('信用卡積分可當現金用嗎',
#   'VpaGetAnswer',
#   'SC344',
#   'VpaGetAnswer',
#   'SC344',
#   'ID: SC344\n'
#   'Q: 我 可以 用 獎賞 積分 兌換 到 什麼\n'
#   'A: 我哋希望帶畀客戶最好嘅獎賞，所以我哋準備多種驚喜優惠畀你，只要上獎賞目錄就睇到㗎喇!',
#   'tszhim.tsui',
#   '',
#   ''),
#  ('現在申請這張有什麼迎新禮品？',
#   'WelcomeOffers',
#   '',
#   'VpaGetAnswer',
#   'WelcomeOffers',
#   'ID: WelcomeOffers\n'
#   'Q: 有 什麼 迎新 優惠\n'
#   'A: I have not learned how to process this request. Can you tell me which '
#   'product are you interested in?',
#   'tszhim.tsui',
#   '',
#   ''),
#  ('海外優惠呢？',
#   'ShowOffers',
#   '',
#   'VpaGetAnswer',
#   'Promotions_DynFAQ',
#   'ID: Promotions_DynFAQ\nQ: @promotiontype 現金回贈 優惠\nA: 你對邊種優惠有興趣？',
#   'tszhim.tsui',
#   '',
#   ''),
#  ('請問我可以以渣打信用卡交稅嗎',
#   'VpaGetAnswer',
#   'SC638',
#   'VpaGetAnswer',
#   'SC638',
#   'ID: SC638\n'
#   'Q: 如 可 透過 網上理財 繳付 稅 項\n'
#   'A: 有咗網上理財，交稅變得更簡單、直接! '
#   '你只要揀「繳款」，喺商戶類別選擇「政府或法定機構」，然後喺商戶名稱按「稅務局」以繳付賬單。如果稅務總額超過HK$99,999，你就可能要分兩次去交稅㗎。',
#   'tszhim.tsui',
#   '',
#   ''),
#  ('你長頭髮定短頭髮㗎',
#   'VpaGetAnswer',
#   'SC141',
#   'VpaGetAnswer',
#   'P16',
#   'ID: P16\nQ: 你 係 由 咩 組 成\nA: 我嘅身體係由一堆代碼組成，不過創造我嘅人亦都賦予我好多能力，令我可以更貼心咁幫到有需要嘅人。',
#   'tszhim.tsui',
#   '',
#   ''),
#  ('信用卡幾多積分可換現金',
#   'VpaGetAnswer',
#   'SC344',
#   'VpaGetAnswer',
#   'SC344',
#   'ID: SC344\n'
#   'Q: 我 可以 用 獎賞 積分 兌換 到 什麼\n'
#   'A: 我哋希望帶畀客戶最好嘅獎賞，所以我哋準備多種驚喜優惠畀你，只要上獎賞目錄就睇到㗎喇!',
#   'tszhim.tsui',
#   '',
#   ''),
#  ('最低存款額係幾多',
#   'VpaGetDefinition',
#   'G44',
#   'VpaGetAnswer',
#   'Eligibility',
#   'ID: Eligibility\n'
#   'Q: 有 什麼 申請 資格\n'
#   'A: I have not learned how to process this request. Can you tell me which '
#   'product are you interested in?',
#   'tszhim.tsui',
#   '',
#   ''),
#  ('我想問我帳戶嘅最低deposit',
#   'VpaGetAnswer',
#   'SC87',
#   'VpaGetAnswer',
#   'SC99',
#   'ID: SC99\n'
#   'Q: 快易理財 有 沒 有 任何 服務費\n'
#   'A: 如果你喺季度內嘅每日平均總結餘滿HK$10,000，即可免費享用我哋嘅「快易理財」升級組合服務；相反，你就需要繳付HK$120 '
#   '為當季度嘅服務費。',
#   'tszhim.tsui',
#   '',
#   ''),
#  ('最低存款額',
#   'VpaGetDefinition',
#   'G44',
#   'VpaGetAnswer',
#   'G288',
#   'ID: Eligibility\n'
#   'Q: 有 什麼 申請 資格\n'
#   'A: I have not learned how to process this request. Can you tell me which '
#   'product are you interested in?',
#   'tszhim.tsui',
#   'G288',
#   'it is a definition'),
#  ('確認收妥提款卡及設定密碼',
#   'VpaGetAnswer',
#   'SC1006',
#   'VpaGetAnswer',
#   'SC1011',
#   'ID: SC1011\nQ: 如何 啟用 atm 卡\nA: 你無需啟動你嘅提款卡。 當你收到你張提款卡後，就可以享受我哋的自動櫃員機服務。',
#   'tszhim.tsui',
#   '',
#   ''),
#  ('如何用渣打信用卡交稅',
#   'VpaGetAnswer',
#   'SC355',
#   'VpaGetAnswer',
#   'SC638',
#   'ID: SC638\n'
#   'Q: 如 可 透過 網上理財 繳付 稅 項\n'
#   'A: 有咗網上理財，交稅變得更簡單、直接! '
#   '你只要揀「繳款」，喺商戶類別選擇「政府或法定機構」，然後喺商戶名稱按「稅務局」以繳付賬單。如果稅務總額超過HK$99,999，你就可能要分兩次去交稅㗎。',
#   'tszhim.tsui',
#   '',
#   ''),
#  ('亞洲萬里通',
#   'VpaUnknownRequest',
#   '',
#   'VpaGetDefinition',
#   'G451',
#   'ID: G451',
#   'tszhim.tsui',
#   '',
#   ''),
#  ('請問點用渣打信用卡交税？',
#   'VpaGetAnswer',
#   'SC355',
#   'VpaGetAnswer',
#   'SC638',
#   'ID: SC638\n'
#   'Q: 如 可 透過 網上理財 繳付 稅 項\n'
#   'A: 有咗網上理財，交稅變得更簡單、直接! '
#   '你只要揀「繳款」，喺商戶類別選擇「政府或法定機構」，然後喺商戶名稱按「稅務局」以繳付賬單。如果稅務總額超過HK$99,999，你就可能要分兩次去交稅㗎。',
#   'tszhim.tsui',
#   '',
#   ''),
#  ('我想問下，我申請左Asia miles張卡點解無收以迎新個里量？',
#   'VpaGetAnswer',
#   'SC417',
#   'VpaGetAnswer',
#   'SC524',
#   'ID: SC524\n'
#   'Q: 我 何 時 會 收 到 亞洲萬里通 迎新 飛行裡數 禮遇\n'
#   'A: 你嘅亞洲萬里通迎新禮遇將會喺新卡發出後5個月內存入到指定戶口。',
#   'tszhim.tsui',
#   '',
#   ''),
#  ('網上交税',
#   'VpaUnknownRequest',
#   '',
#   'VpaGetAnswer',
#   'SC638',
#   'ID: SC638\n'
#   'Q: 如 可 透過 網上理財 繳付 稅 項\n'
#   'A: 有咗網上理財，交稅變得更簡單、直接! '
#   '你只要揀「繳款」，喺商戶類別選擇「政府或法定機構」，然後喺商戶名稱按「稅務局」以繳付賬單。如果稅務總額超過HK$99,999，你就可能要分兩次去交稅㗎。',
#   'tszhim.tsui',
#   '',
#   ''),
#  ('請問simpycard 迎新優惠有＄1111回贈的詳情',
#   'WelcomeOffers',
#   '',
#   'VpaGetAnswer',
#   'WelcomeOffers',
#   'ID: WelcomeOffers\n'
#   'Q: 有 什麼 迎新 優惠\n'
#   'A: I have not learned how to process this request. Can you tell me which '
#   'product are you interested in?',
#   'tszhim.tsui',
#   '',
#   ''),
#  ('開左張支票唔知係咪彈票',
#   'VpaGetAnswer',
#   'SC244',
#   'VpaGetAnswer',
#   'SC239',
#   'ID: SC239\n'
#   'Q: 我 發 出 支票 後 發現 存款 不 足 你們 有沒有 免 退 票 保障\n'
#   'A: '
#   '我哋會為所有持有港幣支票戶口嘅客戶，提供高達HK$40,000嘅支票透支保障服務，而最終限額係取決於存款數目。每項支票透支保障手續費及透支利息仍然適用於透支保障下嘅支票結算。',
#   'tszhim.tsui',
#   '',
#   ''),
#  ('未有密码',
#   'VpaGetAnswer',
#   'SC642',
#   'VpaGetAnswer',
#   'SC632',
#   'ID: SC632\n'
#   'Q: 我 登入 用戶名稱 及 密碼 是 什麼\n'
#   'A: 你嘅網上理財或信用卡網上服務用戶名稱同密碼係由你自己設定，所以我唔會知佢地係咩，不過我知道會係介乎8到16個位嘅字母及數字。\n'
#   '\n'
#   '另外，你亦可以隨時用你嘅提款卡號碼同櫃員機密碼，或者用你嘅電話理財卡號碼同電子理財私人密碼去重新設定用戶名稱同密碼。',
#   'tszhim.tsui',
#   '',
#   ''),
#  ('最低存款？',
#   'VpaGetDefinition',
#   'G44',
#   'VpaGetAnswer',
#   'G288',
#   'ID: Eligibility\n'
#   'Q: 有 什麼 申請 資格\n'
#   'A: I have not learned how to process this request. Can you tell me which '
#   'product are you interested in?',
#   'tszhim.tsui',
#   'G288',
#   'It is a definition'),
#  ('支票戶口迎新優惠',
#   'WelcomeOffers',
#   '',
#   'VpaGetAnswer',
#   'WelcomeOffers',
#   'ID: WelcomeOffers\n'
#   'Q: 有 什麼 迎新 優惠\n'
#   'A: I have not learned how to process this request. Can you tell me which '
#   'product are you interested in?',
#   'tszhim.tsui',
#   '',
#   ''),
#  ('信用卡迎新優惠',
#   'WelcomeOffers',
#   '',
#   'VpaGetAnswer',
#   'WelcomeOffers',
#   'ID: WelcomeOffers\n'
#   'Q: 有 什麼 迎新 優惠\n'
#   'A: I have not learned how to process this request. Can you tell me which '
#   'product are you interested in?',
#   'tszhim.tsui',
#   '',
#   ''),
#  ('自動增值申請資格',
#   'Eligibility',
#   '',
#   'VpaGetAnswer',
#   'Eligibility',
#   'ID: Eligibility\n'
#   'Q: 有 什麼 申請 資格\n'
#   'A: I have not learned how to process this request. Can you tell me which '
#   'product are you interested in?',
#   'tszhim.tsui',
#   '',
#   ''),
#  ('电汇',
#   'VpaGetDefinition',
#   'G329',
#   'VpaGetDefinition',
#   'G329',
#   'ID: G329\n'
#   'Q: 我 想 咨詢 一 下 有 關 匯款 業務\n'
#   'A: 我哋嘅匯款服務覆蓋大部份國家同地區，你可以透過分行或者網上理財，享受可靠、快捷同安全嘅轉賬服務。',
#   'harris.wong',
#   '',
#   ''),
#  ('存款戶口申請資格',
#   'Eligibility',
#   '',
#   'VpaGetAnswer',
#   'Eligibility',
#   'ID: Eligibility\n'
#   'Q: 有 什麼 申請 資格\n'
#   'A: I have not learned how to process this request. Can you tell me which '
#   'product are you interested in?',
#   'harris.wong',
#   '',
#   ''),
#  ('貸款申請資格',
#   'Eligibility',
#   '',
#   'VpaGetAnswer',
#   'SC739',
#   'ID: SC739\nQ: 申請 貸款 最低 要求 是 什麼\nA: 你對邊種貸款有興趣?',
#   'harris.wong',
#   '',
#   ''),
#  ('交稅',
#   'VpaGetAnswer',
#   'SC638-1',
#   'VpaGetAnswer',
#   'SC638-1',
#   'ID: SC638-1\n'
#   'Q: 交 稅\n'
#   'A: 有咗網上理財，交稅變得更簡單、直接! '
#   '你只要揀「繳款」，喺商戶類別選擇「政府或法定機構」，然後喺商戶名稱按「稅務局」以繳付賬單。如果稅務總額超過HK$99,999，你就可能要分兩次去交稅㗎。',
#   'harris.wong',
#   '',
#   ''),
#  ('最新優惠',
#   'VpaGetAnswer',
#   'Promotions_DynFAQ',
#   'VpaGetAnswer',
#   'Promotions_DynFAQ',
#   'ID: Promotions_DynFAQ\nQ: @promotiontype 現金回贈 優惠\nA: 你對邊種優惠有興趣？',
#   'harris.wong',
#   '',
#   ''),
#  ('八達通自動增值',
#   'VpaGetDefinition',
#   'G374',
#   'VpaGetDefinition',
#   'G374',
#   'ID: G374',
#   'harris.wong',
#   '',
#   ''),
#  ('上水廣場分行電話',
#   'VpaGetDefinition',
#   'G486',
#   'ATMFinder',
#   '',
#   '',
#   'harris.wong',
#   '',
#   ''),
#  ('我可以用獎賞積分兌換到什麼？',
#   'VpaGetAnswer',
#   'SC344',
#   'VpaGetAnswer',
#   'SC344',
#   'ID: SC344\n'
#   'Q: 我 可以 用 獎賞 積分 兌換 到 什麼\n'
#   'A: 我哋希望帶畀客戶最好嘅獎賞，所以我哋準備多種驚喜優惠畀你，只要上獎賞目錄就睇到㗎喇!',
#   'harris.wong',
#   '',
#   ''),
#  ('綱上買股票',
#   'VpaUnknownRequest',
#   '',
#   'VpaGetDefinition',
#   'G440',
#   'ID: G440\nQ: 基金 買 賣\nA: 我哋嘅網上投資戶口畀你一站式管理你嘅投資基金及股票。',
#   'harris.wong',
#   '',
#   ''),
#  ('我忘記密碼',
#   'VpaGetAnswer',
#   'SC1006',
#   'VpaGetAnswer',
#   'SC1006',
#   'ID: SC1006\n'
#   'Q: 如何 重設 私人密碼\n'
#   'A: 我哋嘅客戶顧問可以俾個新嘅櫃員機密碼你。你只要click下面條link，就可以搵到佢地幫手㗎啦。我哋亦都好歡迎你嚟我哋嘅分行辦理。',
#   'harris.wong',
#   '',
#   ''),
#  ('上網買東西，為什麼沒有短信通知？太危險⚠️',
#   'VpaGetAnswer',
#   'SC180',
#   'VpaGetAnswer',
#   'SC180',
#   'ID: SC180\n'
#   'Q: 有 什麼 類型 短訊 提示\n'
#   'A: 你可以就繳付賬單、現金提款、資金轉賬、購物、及退回支票，選擇以手機短訊形式接收存款戶口及信用卡提示（包括到期繳款日）。',
#   'harris.wong',
#   '',
#   ''),
#  ('想知日元匯率',
#   'VpaGetAnswer',
#   'SC111',
#   'VpaGetAnswer',
#   'SC111',
#   'ID: SC111\n'
#   'Q: 如何 查詢 匯率\n'
#   'A: '
#   '其實查詢匯率嘅過程非常簡單，你只需係登入網上理財後，選擇「利率及匯率」，我哋就會提供有關匯率以作參考。請注意，當你提出交易之前，系統將會再次確認當時嘅實際匯率。',
#   'harris.wong',
#   '',
#   ''),
#  ('你哋喺鰂魚涌有冇分行', 'ATMFinder', '', 'ATMFinder', '', '', 'harris.wong', '', ''),
#  ('請問介紹朋友成功申請有里數嗎',
#   'VpaGetDefinition',
#   'G449',
#   'VpaGetDefinition',
#   'G449',
#   'ID: G449\nQ: 我 想 推薦朋友 申請 信用卡\nA: 同你嘅親友分享用渣打理財服務同信用卡嘅喜悅，仲可以獲得額外獎賞！',
#   'harris.wong',
#   '',
#   ''),
#  ('邊張信用卡最好',
#   'VpaGetAnswer',
#   'SC1019',
#   'VpaGetAnswer',
#   'SC1019',
#   'ID: SC1019\n'
#   'Q: 有 什麼 信用卡 適 合 我\n'
#   'A: 我哋提供一系列可以賺取現金回贈﹑「亞洲萬里通」里數或積分嘅信用卡，畀您盡享獨家簽帳優惠同消費獎賞。',
#   'harris.wong',
#   '',
#   ''),
#  ('我想問你哋有咩保險產品',
#   'VpaGetAnswer',
#   'SC1015',
#   'VpaGetDefinition',
#   'G140',
#   'ID: G140\nQ: 包 保險 嗎\nA: 搵緊保險產品? 我哋嘅保險為你提供全面保障。',
#   'harris.wong',
#   '',
#   ''),
#  ('你好，我想取消個綜合銀行戶口，應該怎麼做？',
#   'VpaGetAnswer',
#   'SC87',
#   'VpaGetAnswer',
#   'SC87',
#   'ID: SC87\n'
#   'Q: 怎樣 取消 我 銀行戶口\n'
#   'A: '
#   '如果想取消戶口，你要帶同有效身分證明文件去我哋係香港嘅任何一間分行，我哋嘅同事就會幫你處理㗎喇。雖然我覺得好可惜，不過希望未來我哋可以再次為你服務!',
#   'harris.wong',
#   '',
#   ''),
#  ('提高每日轉賬',
#   'VpaGetAnswer',
#   'SC1003',
#   'VpaGetAnswer',
#   'SC1003',
#   'ID: SC1003\n'
#   'Q: 如何 調 整 每日 轉帳 上限\n'
#   'A: '
#   '喺網上理財加大每日轉帳限額其實好簡單，只要喺目錄選擇「我的喜好」，然後選擇「轉賬額設定」，就可以調整每日限額啦。你亦可以點擊下面連結下載「網上理財更改每日轉賬額表格」 '
#   '，填好後交去任何一間分行或寄返俾我哋。我哋會係收到申請後約三個工作天就會更新有關資料。 ',
#   'harris.wong',
#   '',
#   ''),
#  ('提款卡密碼如何設定？',
#   'VpaGetAnswer',
#   'SC1006',
#   'VpaGetAnswer',
#   'SC1006',
#   'ID: SC1006\n'
#   'Q: 如何 重設 私人密碼\n'
#   'A: 我哋嘅客戶顧問可以俾個新嘅櫃員機密碼你。你只要click下面條link，就可以搵到佢地幫手㗎啦。我哋亦都好歡迎你嚟我哋嘅分行辦理。',
#   'harris.wong',
#   '',
#   ''),
#  ('咁如何知道提款卡密碼？',
#   'ATMFinder',
#   '',
#   'VpaGetAnswer',
#   'SC1006-1',
#   'ID: SC1006-1\n'
#   'Q: 我 提款卡 密碼 是 什麼\n'
#   'A: 我哋嘅客戶顧問可以俾個新嘅櫃員機密碼你。你只要click下面條link，就可以搵到佢地幫手㗎啦。我哋亦都好歡迎你嚟我哋嘅分行辦理。',
#   'harris.wong',
#   '',
#   ''),
#  ('我有Asia miles SCB, 即是冇迎新禮物？',
#   'VpaGetAnswer',
#   'SC438',
#   'VpaGetAnswer',
#   'SC438',
#   'ID: SC438\n'
#   'Q: 如何 獲 得 迎新 禮品\n'
#   'A: 我哋只會為喺過去6個月都冇持有渣打信用卡或MANHATTAN信用卡主卡嘅客戶提供迎新禮遇，如果你想了解更多，可以睇吓我哋嘅信用卡申請條款及細則。',
#   'harris.wong',
#   '',
#   ''),
#  ('有冇迎新禮物',
#   'VpaGetAnswer',
#   'SC438',
#   'VpaGetAnswer',
#   'SC438',
#   'ID: SC438\n'
#   'Q: 如何 獲 得 迎新 禮品\n'
#   'A: 我哋只會為喺過去6個月都冇持有渣打信用卡或MANHATTAN信用卡主卡嘅客戶提供迎新禮遇，如果你想了解更多，可以睇吓我哋嘅信用卡申請條款及細則。',
#   'harris.wong',
#   '',
#   ''),
#  ('For「優先理財」信用卡,想問問 priority pass 的要求是什麼？',
#   'VpaGetAnswer',
#   'SC490-1',
#   'VpaGetAnswer',
#   'SC490-1',
#   'ID: SC490-1\n'
#   'Q: 如 我 正 在 使用 priority pass 有沒有 什麼 要求\n'
#   'A: Priority Pass™首年會藉並冇任何簽賬要求，而其後只你就要附合相關要求，就可以繼續免費享用機場貴賓候機室嘅服務喇。',
#   'harris.wong',
#   '',
#   ''),
#  ('點樣交稅',
#   'VpaGetAnswer',
#   'SC638-1',
#   'VpaGetAnswer',
#   'SC638-1',
#   'ID: SC638-1\n'
#   'Q: 交 稅\n'
#   'A: 有咗網上理財，交稅變得更簡單、直接! '
#   '你只要揀「繳款」，喺商戶類別選擇「政府或法定機構」，然後喺商戶名稱按「稅務局」以繳付賬單。如果稅務總額超過HK$99,999，你就可能要分兩次去交稅㗎。',
#   'harris.wong',
#   '',
#   ''),
#  ('儲積分',
#   'VpaGetDefinition',
#   'G390',
#   'VpaGetAnswer',
#   'G390',
#   'ID: G390\n'
#   'Q: 積分 換領 有 咩 換\n'
#   'A: '
#   '「360°全面賞」積分可以透過信用卡簽賬、存款、投資、保險、個人分期貸款同樓宇按揭貸款嚟賺取，你可以用積分換領唔同獎賞，例如電子產品、飛行里數、家居精品、旅行用品、購物禮券等等。',
#   'harris.wong',
#   '',
#   ''),
#  ('信用卡幾錢係一分',
#   'VpaGetAnswer',
#   'SC479',
#   'VpaGetAnswer',
#   'SC479',
#   'ID: SC479\n'
#   'Q: 如何 賺取 額外 積分\n'
#   'A: 用渣打信用卡每簽HK$1，即可以賺到1分積分，「優先理財」同「Premium理財」客戶更可賺取額外積分。',
#   'harris.wong',
#   '',
#   ''),
#  ('信用卡',
#   'VpaGetDefinition',
#   'G410',
#   'VpaGetDefinition',
#   'G410',
#   'ID: G410',
#   'tszhim.tsui',
#   '',
#   ''),
#  ('尋找分行', 'ATMFinder', '', 'ATMFinder', '', '', 'tszhim.tsui', '', ''),
#  ('綜合存款戶口迎新優惠',
#   'WelcomeOffers',
#   '',
#   'VpaGetAnswer',
#   'WelcomeOffers',
#   'ID: WelcomeOffers\n'
#   'Q: 有 什麼 迎新 優惠\n'
#   'A: I have not learned how to process this request. Can you tell me which '
#   'product are you interested in?',
#   'tszhim.tsui',
#   '',
#   ''),
#  ('戶口迎新優惠',
#   'WelcomeOffers',
#   '',
#   'VpaGetAnswer',
#   'WelcomeOffers',
#   'ID: WelcomeOffers\n'
#   'Q: 有 什麼 迎新 優惠\n'
#   'A: I have not learned how to process this request. Can you tell me which '
#   'product are you interested in?',
#   'tszhim.tsui',
#   '',
#   ''),
#  ('出糧升級組合迎新優惠',
#   'WelcomeOffers',
#   '',
#   'VpaGetAnswer',
#   'WelcomeOffers',
#   'ID: WelcomeOffers\n'
#   'Q: 有 什麼 迎新 優惠\n'
#   'A: I have not learned how to process this request. Can you tell me which '
#   'product are you interested in?',
#   'tszhim.tsui',
#   '',
#   ''),
#  ('如何申請綜合存款戶口',
#   'Apply',
#   '',
#   'VpaGetAnswer',
#   'Apply',
#   'ID: Apply\n'
#   'Q: 我 可以 申請 什麼\n'
#   'A: I have not learned how to process this request. Can you tell me which '
#   'product are you interested in?',
#   'tszhim.tsui',
#   '',
#   ''),
#  ('卡迎新優惠',
#   'WelcomeOffers',
#   '',
#   'VpaGetAnswer',
#   'WelcomeOffers',
#   'ID: WelcomeOffers\n'
#   'Q: 有 什麼 迎新 優惠\n'
#   'A: I have not learned how to process this request. Can you tell me which '
#   'product are you interested in?',
#   'tszhim.tsui',
#   '',
#   ''),
#  ('信用卡申請資格',
#   'Eligibility',
#   '',
#   'VpaGetAnswer',
#   'Eligibility',
#   'ID: Eligibility\n'
#   'Q: 有 什麼 申請 資格\n'
#   'A: I have not learned how to process this request. Can you tell me which '
#   'product are you interested in?',
#   'tszhim.tsui',
#   '',
#   ''),
#  ('存款戶口迎新優惠',
#   'WelcomeOffers',
#   '',
#   'VpaGetAnswer',
#   'WelcomeOffers',
#   'ID: WelcomeOffers\n'
#   'Q: 有 什麼 迎新 優惠\n'
#   'A: I have not learned how to process this request. Can you tell me which '
#   'product are you interested in?',
#   'tszhim.tsui',
#   '',
#   ''),
#  ('想問下最近asiamiles mastercard去海外簽賬有無promotion?',
#   'ShowOffers',
#   '',
#   'VpaGetAnswer',
#   'Promotions_DynFAQ',
#   'ID: Promotions_DynFAQ\nQ: @promotiontype 現金回贈 優惠\nA: 你對邊種優惠有興趣？',
#   'tszhim.tsui',
#   '',
#   ''),
#  ('迎新里數',
#   'VpaGetDefinition',
#   'G451',
#   'VpaGetAnswer',
#   'Promotions_DynFAQ',
#   'ID: Promotions_DynFAQ\nQ: @promotiontype 現金回贈 優惠\nA: 你對邊種優惠有興趣？',
#   'tszhim.tsui',
#   '',
#   ''),
#  ('如可透過網上理財繳付稅項？',
#   'VpaGetAnswer',
#   'SC638',
#   'VpaGetAnswer',
#   'SC638',
#   'ID: SC638\n'
#   'Q: 如 可 透過 網上理財 繳付 稅 項\n'
#   'A: 有咗網上理財，交稅變得更簡單、直接! '
#   '你只要揀「繳款」，喺商戶類別選擇「政府或法定機構」，然後喺商戶名稱按「稅務局」以繳付賬單。如果稅務總額超過HK$99,999，你就可能要分兩次去交稅㗎。',
#   'harris.wong',
#   '',
#   ''),
#  ('亞洲萬里通飛行裡數是否會自動轉到我的戶口？',
#   'VpaGetAnswer',
#   'SC521',
#   'VpaGetAnswer',
#   'SC521',
#   'ID: SC521\n'
#   'Q: 亞洲萬里通 飛行裡數 是 否 會 自動 轉 到 我 戶口\n'
#   'A: 用渣打亞洲萬里通萬事達卡賺里數非常簡單，因為所有里數都會免費自動存入到指定「「亞洲萬里通」賬戶內。',
#   'harris.wong',
#   '',
#   ''),
#  ('如何進行電匯交易？',
#   'VpaGetAnswer',
#   'SC230',
#   'VpaGetAnswer',
#   'SC230',
#   'ID: SC230\nQ: 如何 進行 電匯 交易\nA: 你可以好方便地喺網上理財進行電匯轉賬，亦好歡迎你親臨鄰近嘅分行匯出匯款。',
#   'harris.wong',
#   '',
#   ''),
#  ('想查看1111年全年交易紀錄',
#   'VpaGetDefinition',
#   'G146',
#   'VpaGetAnswer',
#   'SC653-1',
#   'ID: SC653-1\nQ: 想 查 返 交易 紀錄\nA: 你可以喺網上理財裡面嘅「交易紀錄」睇到你戶口嘅交易同轉賬狀態。',
#   'harris.wong',
#   '',
#   ''),
#  ('我可否透過網上理財重新預定指示？',
#   'VpaGetAnswer',
#   'SC669',
#   'VpaGetAnswer',
#   'SC669',
#   'ID: SC669\n'
#   'Q: 我 可否 透過 網上理財 重新 預定 指示\n'
#   'A: 你可以喺網上理財設置定期交易。但係你要留意，如果你嘅轉賬指示預設喺每個月嘅最後一日，有關指示就會根據每個月唔同嘅最後一日而執行。',
#   'harris.wong',
#   '',
#   ''),
#  ('信用卡年費',
#   'VpaGetDefinition',
#   'G145',
#   'VpaGetDefinition',
#   'G145',
#   'ID: G145\nQ: 信用卡 年費\nA: 年費係每年繳付嘅服務費用，銀行會就代為保管戶口同備用透支之類嘅服務收取年費。',
#   'harris.wong',
#   '',
#   ''),
#  ('定期利率',
#   'VpaGetDefinition',
#   'G428',
#   'VpaGetDefinition',
#   'G428',
#   'ID: G428',
#   'harris.wong',
#   '',
#   ''),
#  ('你今年幾多歲',
#   'VpaGetAnswer',
#   'P1',
#   'VpaGetAnswer',
#   'P1',
#   'ID: P1\nQ: 你 年紀 係\nA: 如果從人類嘅角度嚟睇，我應該喺一個啱啱出世嘅BB，不過我始終同你哋唔同。',
#   'harris.wong',
#   '',
#   ''),
#  ('現金回贈優惠',
#   'VpaGetAnswer',
#   'Promotions_DynFAQ',
#   'VpaGetAnswer',
#   'Promotions_DynFAQ',
#   'ID: Promotions_DynFAQ\nQ: @promotiontype 現金回贈 優惠\nA: 你對邊種優惠有興趣？',
#   'harris.wong',
#   '',
#   ''),
#  ('如何開戶口',
#   'Apply',
#   '',
#   'VpaGetAnswer',
#   'SC88',
#   'ID: SC88\nQ: 開 戶 有 什麼 文件 需要 準備\nA: 你對邊種戶口有興趣?',
#   'harris.wong',
#   '',
#   ''),
#  ('我想投訴',
#   'VpaGetAnswer',
#   'SC151',
#   'VpaGetAnswer',
#   'SC151',
#   'ID: SC151\n'
#   'Q: 你們 怎樣 處理 客戶 投訴\n'
#   'A: 你嘅意見對我哋好重要，所以喺收到投訴後，我哋會立即跟進，並希望盡快解決你嘅問題，而同事亦會喺期間同你保持聯絡。',
#   'harris.wong',
#   '',
#   ''),
#  ('亞洲萬里通飛行裡數需時多久才會轉入我的戶口？',
#   'VpaGetAnswer',
#   'SC522',
#   'VpaGetAnswer',
#   'SC522',
#   'ID: SC522\n'
#   'Q: 亞洲萬里通 飛行裡數 需 時 多久 才 會 轉 入 我 戶口\n'
#   'A: 你賺取嘅里數將會喺你嘅渣打亞洲萬里通萬事達卡月結單發出後14個工作天內存入到指定「亞洲萬里通」賬戶內。',
#   'harris.wong',
#   '',
#   ''),
#  ('請問長沙灣有冇入錢機', 'ATMFinder', '', 'ATMFinder', '', '', 'harris.wong', '', ''),
#  ('不能登入app',
#   'VpaGetAnswer',
#   'SC1016',
#   'VpaGetAnswer',
#   'SC1016',
#   'ID: SC1016\n'
#   'Q: 為何 不能 登入 流動理財 app\n'
#   'A: 如果你登入唔到你嘅網上理財帳戶，可以打去2886 8868(按1,6,0)，直接搵我哋嘅客戶服務主任幫手啦。',
#   'harris.wong',
#   '',
#   ''),
#  ('西灣河有存款機嘛？',
#   'VpaGetDefinition',
#   'G489',
#   'ATMFinder',
#   '',
#   '',
#   'harris.wong',
#   '',
#   ''),
#  ('忘記了網上銀行密碼及網上銀行帳號被鎖定，可以點做？',
#   'VpaGetAnswer',
#   'SC1005',
#   'VpaGetAnswer',
#   'SC1005',
#   'ID: SC1005\n'
#   'Q: 如何 重設 網上 理財 戶口 密碼\n'
#   'A: 我哋好重視你嘅網絡安全嘅，所以我會建議你定期更改你嘅網上理財密碼。只要登入網上理財或流動理財，然後click「更改登入密碼」就可以改密碼㗎啦。',
#   'harris.wong',
#   '',
#   ''),
#  ('繳稅',
#   'VpaGetAnswer',
#   'SC638-1',
#   'VpaGetAnswer',
#   'SC638-1',
#   'ID: SC638-1\n'
#   'Q: 交 稅\n'
#   'A: 有咗網上理財，交稅變得更簡單、直接! '
#   '你只要揀「繳款」，喺商戶類別選擇「政府或法定機構」，然後喺商戶名稱按「稅務局」以繳付賬單。如果稅務總額超過HK$99,999，你就可能要分兩次去交稅㗎。',
#   'harris.wong',
#   '',
#   ''),
#  ('如何查詢到我的信用卡申請進度？',
#   'VpaGetAnswer',
#   'SC417',
#   'VpaGetAnswer',
#   'SC417',
#   'ID: SC417\n'
#   'Q: 如何 查詢 到 我 信用卡 申請 進 度\n'
#   'A: 我嘅同事會有你嘅最新信用卡申請狀況，你可以打去2886 4111搵佢哋幫手喇。',
#   'harris.wong',
#   '',
#   ''),
#  ('我想同職員對話',
#   'VpaGetAnswer',
#   'SC832',
#   'VpaGetAnswer',
#   'SC832',
#   'ID: SC832\n'
#   'Q: 我 想 同 職員 對話\n'
#   'A: 你可以打畀我哋嘅24小時客戶服務熱線2886 8888，或者點擊以下連結同我哋嘅線上客戶顧問傾傾。',
#   'harris.wong',
#   '',
#   ''),
#  ('我要銅鑼灣分行', 'ATMFinder', '', 'ATMFinder', '', '', 'harris.wong', '', ''),
#  ('亞洲萬里通里數優惠',
#   'VpaGetAnswer',
#   'Promotions_DynFAQ',
#   'VpaGetAnswer',
#   'Promotions_DynFAQ',
#   'ID: Promotions_DynFAQ\nQ: @promotiontype 現金回贈 優惠\nA: 你對邊種優惠有興趣？',
#   'harris.wong',
#   '',
#   ''),
#  ('如何賺取積分？',
#   'VpaGetAnswer',
#   'SC796',
#   'VpaGetAnswer',
#   'SC796',
#   'ID: SC796\n'
#   'Q: 如何 賺取 積分\n'
#   'A: 憑渣打信用卡每簽HK$1，即可賺到1分額外積分，「優先理財」及「Premium理財」客戶更可賺取額外積分。',
#   'harris.wong',
#   '',
#   ''),
#  ('信用卡優惠',
#   'VpaGetAnswer',
#   'Promotions_DynFAQ',
#   'VpaGetAnswer',
#   'Promotions_DynFAQ',
#   'ID: Promotions_DynFAQ\nQ: @promotiontype 現金回贈 優惠\nA: 你對邊種優惠有興趣？',
#   'harris.wong',
#   '',
#   ''),
#  ('如何申請信用卡',
#   'Apply',
#   '',
#   'VpaGetAnswer',
#   'SC467',
#   'ID: SC467\n'
#   'Q: 申請 一 張 信用卡 需要 什麼 文件\n'
#   'A: 我哋提供多種信用卡去配合你嘅需要，而你只需要以下文件就可以申請：</br>1. 香港身分證</br> 2. 住址證明</br> 3. '
#   '最近嘅糧單或銀行月結單</br></br>至於申請資格方面，只要你係年滿 18 '
#   '歲或以上嘅香港永久性居民，並且每年固定收入符合個別信用卡要求，就可以申請啦。',
#   'harris.wong',
#   '',
#   ''),
#  ('請問銅鑼灣邊度有分行可以入錢？',
#   'ATMFinder',
#   '',
#   'ATMFinder',
#   '',
#   '',
#   'harris.wong',
#   '',
#   ''),
#  ('為何不能登入流動理財app',
#   'VpaGetAnswer',
#   'SC1016',
#   'VpaGetAnswer',
#   'SC1016',
#   'ID: SC1016\n'
#   'Q: 為何 不能 登入 流動理財 app\n'
#   'A: 如果你登入唔到你嘅網上理財帳戶，可以打去2886 8868(按1,6,0)，直接搵我哋嘅客戶服務主任幫手啦。',
#   'harris.wong',
#   '',
#   ''),
#  ('可以幫我申請豁免信用卡lage charge 及finance charge嗎',
#   'VpaGetAnswer',
#   'SC424',
#   'VpaGetAnswer',
#   'SC424',
#   'ID: SC424\nQ: 可以 豁免 我 信用卡 罰 款 嗎\nA: 我嘅同事可以幫你申請豁免購信用卡財務費，佢哋嘅電話係2886 4111。',
#   'harris.wong',
#   '',
#   ''),
#  ('網上理財',
#   'VpaGetDefinition',
#   'G462',
#   'VpaGetDefinition',
#   'G462',
#   'ID: G462',
#   'harris.wong',
#   '',
#   ''),
#  ('如何申請網上理財',
#   'Apply',
#   '',
#   'VpaGetAnswer',
#   'SC627',
#   'ID: SC627\n'
#   'Q: 如何 登記 銀行 網上理財 服務\n'
#   'A: 登記網上理財只需要幾個簡單步驟，你可以用電話理財卡號碼同電子理財私人密碼，又或者用你嘅提款卡號碼同櫃員機密碼去登記。',
#   'harris.wong',
#   '',
#   ''),
#  ('可以豁免我的 Simply Cash 信用卡年費嗎？',
#   'VpaGetAnswer',
#   'SC503',
#   'VpaGetAnswer',
#   'SC503',
#   'ID: SC503\n'
#   'Q: 可以 豁免 我 simply cash 信用卡 年費 嗎\n'
#   'A: 如果你係「優先理財」/「Premium理財」/「渣打紅利出糧戶口」嘅客戶，我哋會為你嘅Simply Cash Visa卡主卡永久豁免年費㗎。',
#   'harris.wong',
#   '',
#   ''),
#  ('網上銀行登入唔到',
#   'VpaGetAnswer',
#   'SC1012',
#   'VpaGetAnswer',
#   'SC1012',
#   'ID: SC1012\n'
#   'Q: 為何 不能 登入 網上理財\n'
#   'A: 如果你登入唔到你嘅網上理財帳戶，可以打去2886 8868(按1,6,0)，直接搵我哋嘅客戶服務主任幫手啦。',
#   'harris.wong',
#   '',
#   ''),
#  ('如何開戶?',
#   'Apply',
#   '',
#   'VpaGetAnswer',
#   'SC88',
#   'ID: SC88\nQ: 開 戶 有 什麼 文件 需要 準備\nA: 你對邊種戶口有興趣?',
#   'harris.wong',
#   '',
#   ''),
#  ('如何申請私人貸款',
#   'Apply',
#   '',
#   'VpaGetAnswer',
#   'SC740',
#   'ID: SC740\nQ: 申請 貸款 需要 遞 交 什麼 文件\nA: 申請貸款所需要嘅文件包括你嘅身分證影印本、現時嘅住址證明及入息證明。',
#   'harris.wong',
#   '',
#   ''),
#  ('登入唔到',
#   'VpaGetAnswer',
#   'SC642-1',
#   'VpaGetAnswer',
#   'SC642-1',
#   'ID: SC642-1\n'
#   'Q: 我 帳戶 為什麼 登錄 不\n'
#   'A: 如果你登入唔到你嘅賬戶，請你打2886 8868，再按1、6、0直接搵我嘅同事幫手喇。',
#   'harris.wong',
#   '',
#   ''),
#  ('你好 我登入不到網上銀行',
#   'VpaGetAnswer',
#   'SC1012',
#   'VpaGetAnswer',
#   'SC1012',
#   'ID: SC1012\n'
#   'Q: 為何 不能 登入 網上理財\n'
#   'A: 如果你登入唔到你嘅網上理財帳戶，可以打去2886 8868(按1,6,0)，直接搵我哋嘅客戶服務主任幫手啦。',
#   'harris.wong',
#   '',
#   ''),
#  ('開戶有冇咩文件要準備？',
#   'VpaGetAnswer',
#   'SC88',
#   'VpaGetAnswer',
#   'SC88',
#   'ID: SC88\nQ: 開 戶 有 什麼 文件 需要 準備\nA: 你對邊種戶口有興趣?',
#   'harris.wong',
#   '',
#   ''),
#  ('哪些白金信用卡交易可以賺取積分？',
#   'VpaGetAnswer',
#   'SC829',
#   'VpaGetAnswer',
#   'SC829',
#   'ID: SC829\n'
#   'Q: 哪 些 白金信用卡 交易 可以 賺取 積分\n'
#   'A: 憑白金信用卡簽賬消費每HK$1，你都可以獲得1分積分。而「優先理財」同「Premium理財」客戶更可賺取額外積分添！',
#   'harris.wong',
#   '',
#   ''),
#  ('如何聯絡你們熱線職員？',
#   'VpaGetAnswer',
#   'SC831',
#   'VpaGetAnswer',
#   'SC831',
#   'ID: SC831\n'
#   'Q: 如何 聯絡 你們 熱線 職員\n'
#   'A: 最簡單嘅方法當然係打電話畀我哋信用卡熱線嘅同事啦，只需要撥打2886 '
#   '4111然後按1,2,1,#,0選擇中文服務，或者按2,2,1,#,0選擇英文服務。',
#   'harris.wong',
#   '',
#   ''),
#  ('電匯是怎樣運作？',
#   'VpaGetAnswer',
#   'SC655',
#   'VpaGetAnswer',
#   'SC655',
#   'ID: SC655\nQ: 電匯 是 怎樣 運作\nA: 進行電匯嘅第一步就係透過網上理財新增電匯收款人嘅資料，然後你就可以開始轉賬喇!',
#   'harris.wong',
#   '',
#   ''),
#  ('貸款',
#   'VpaGetDefinition',
#   'G74',
#   'VpaGetDefinition',
#   'G74',
#   'ID: G74',
#   'harris.wong',
#   '',
#   '')]

# %%
#1

with open('Jim_2019-01-16-v2_subset.csv', mode='r') as infile:
    reader = csv.reader(infile)
    with open('coors_new.csv', mode='w') as outfile:
        writer = csv.writer(outfile)
        mydict = dict((rows[0],rows[4]) for rows in reader)

# %%
mydict
# Out:
# {'Question': 'Annotated Answer ID',
#  '税务居留国之确认书': 'G1011',
#  '我每月薪金一萬七 可以申請money back 信用卡嗎？': 'Eligibility',
#  '怎么开公司户口': 'G1015',
#  '查詢網上過數問題': 'SC629-1',
#  '渣打亞洲萬里通萬事達卡': 'G400',
#  '我想問我credit card statement': 'GetStatement_DynFAQ',
#  '同時申請「渣打亞洲萬里通萬事達卡」及「綜合存款戶口, 是否享有可享額外1,111「亞洲萬里通」里數?': 'SC516',
#  '有冇投訴熱線': 'SC151',
#  '查詢戶口': 'SC629-1',
#  '八達通自動增值服務': 'G374',
#  '九唔搭八': 'P10',
#  '預約公司開戶': 'G1015',
#  '想查詢一下如申請銀聯信用卡可否簽申請簽帳分期?': 'SC411',
#  '我想睇我信用卡嘅網上月結單': 'GetStatement_DynFAQ',
#  '电子账户': 'G462',
#  '你答緊乜': 'P10',
#  '申請資格': 'Eligibility',
#  '想預訂人民幣': 'SC4019',
#  '萬里通萬事達信用卡': 'G400',
#  '可以存款嗎': 'G387',
#  '信用卡積分': 'G390',
#  '查询一下我个人账户': 'SC629-1',
#  '香港渣打银行的SWIFT NUMBER是多少': 'SC86',
#  '查詢信用卡批核情況 以上number是申請信用卡編號': 'SC417',
#  'Hello,想更改聯絡電話': 'SC433',
#  '換信用卡積分': 'SC343',
#  '用來轉$比人会否收手續費？': 'SC648',
#  '如何登录': 'SC1001',
#  '申請取消信用卡年費': 'SC423',
#  '我意思係現金存款': 'G489',
#  '我提供的網上編號怎不對呢': 'SC110',
#  '我去左旅行交唔到卡數,可否WAIVE?': 'SC424',
#  '人工': 'SC832-1',
#  '我要上載申請亞洲萬里通卡之所需文件呀': 'SC435',
#  '我剛用轉數快轉賬，不是即時嗎？': 'SC4008',
#  '經常收到舊租客的信，已把舊信交給管理處多次，寫明冇此人，都沒有用': 'SC832-1',
#  '你好 想資訊一下 我將有筆海外轉賬轉入本銀行 請問我需要提供的號碼是提款咭上的號碼 或是平時的轉帳發儲蓄號？': 'SC86',
#  '請問如何申請中小企戶口?': 'G444',
#  '用來出糧': 'G414',
#  '港幣户口': 'SC138',
#  '我已申請, 但以上文件交到哪裡': 'SC435',
#  '不能登入': 'SC642-1',
#  '签賬積分怎样換购禮品？': 'SC336',
#  '客服': 'SC832-1',
#  'Premium理財」客戶豁免海外提款嘅手續費': 'SC221',
#  '想補交申請信用卡文件': 'G1010',
#  '我要找職員': 'SC832',
#  '我想致電bank confirmation department': 'SC832',
#  '我想查询一下我的账户': 'SC629-1',
#  '香港渣打银行邮政编码': 'SC86',
#  '迎新是亞洲萬里通獎賞': 'Promotions_DynFAQ',
#  '留了11111111 是否渣打銀行的電話': 'G498',
#  '轉帳收費': 'SC648',
#  '請問我用櫃員機可以轉賬11,111港紙到中銀戶口嗎': 'SC96',
#  '信用卡不能用': 'SC317',
#  '回贈係回落張card?': 'SC383',
#  '想問下張visa 白金卡果千幾蚊欠賬係乜來？睇唔到': 'SC406',
#  'VISA 欠賬': 'SC406',
#  '可唔可以電話apply定期存款': 'Apply',
#  '尋找旅行優惠': '',
#  '我要從香港渣打銀行匯款到台灣渣打銀行': 'SC230',
#  '请问大额行号是多少？': 'SC86',
#  '你無真人通話？': 'SC832',
#  '寄件地址': 'G498',
#  '人工服务': 'SC832-1',
#  '上限是多少呢？': 'SC93',
#  '點樣賺取現金回贈？': 'SC345',
#  '我是新卡主，請問迎新mileage 何時可以取得？': 'SC524',
#  '想從外幣戶口取日元': 'SC752',
#  '我因為忘記密碼，在剛剛有去銀行重新申請一個密碼了，但輸入新密碼為什麼還是沒有辦法登入。': 'SC633',
#  '渣打Simply Cash Visa 卡 需要年費嗎?': 'SC504',
#  '買禮券雖要付手續費嗎?': 'SC757',
#  '我想透過網路銀行將我的美金匯到台灣渣打銀行': 'SC230',
#  '我想登入戶口唔知點解入咗嚟呢個版面': 'SC1001',
#  '請問渣打信用卡有無傻惠機場橋車接送服務': 'SC489',
#  '電話號碼': 'G498',
#  '信用卡務中心電話？': 'SC831',
#  '外幣手續費': 'SC752',
#  'ATM 存款上限': 'SC104',
#  '想問下信用卡簽帳分期': 'SC374',
#  '出糧户口推廣': 'G414',
#  '請問港元定期利率多少': 'SC119',
#  '請問我昨天在海港城消費滿1千想換領現金卷可以在網上登記換領的嗎？': 'SC336',
#  '有關開立渣打出糧戶口事宜': 'G414',
#  '每天的转账金额上限是多少？': 'SC1003',
#  '我需要向上面的地址快递文件，但不知道联系电话是什么？': 'G498',
#  '我登入唔到網上信用卡': 'SC642',
#  '请问STANDARD CHARTERED BANK (HONG KONG) LIMITED P.O. BOX 11111 KOWLOON EAST POST OFFICE HONG KONG 地址及联系电话是什么？': 'SC832',
#  '亚洲万里通': 'G451',
#  '亞洲萬裡通': 'G451',
#  '網上估價': 'G463',
#  '你好想問111萬新資金係咪有111111 Asia miles': 'SC516',
#  '新戶口首次登入, 如何操作?': 'SC1001',
#  '我在本期月結單見到一項收費 : ANNUAL FEE ANNIVERSARY HKD1111..11': 'SC423',
#  '出糧戶口回贈': 'G414',
#  '現金回贈優惠迎新優惠': 'Promotions_DynFAQ',
#  '你好, 我今天剛開了一個戶口, 但不知是否要收年費..': 'SC99',
#  '要收費?': 'G377',
#  '想請問用asia miles 果張mastercard 上網繳交保險 可否儲到里數？': 'SC516',
#  '想請問用asia miles 果張mastercard 網上繳交保險每年費用， 可否儲到asia miles里數？': 'SC516',
#  '你好，我有一笔汇款，好多天了，为何还没入账？': 'SC112',
#  '有没人': 'P44',
#  '无论用用户名加密码 还是指纹 都无法登录 显示we are unable to process ur request.pls try again': 'SC1016',
#  '我要看我戶口裡面有多少錢': 'SC629-1',
#  '業主貸款': 'Apply',
#  '請問用asiamiles簽單分期，可同時 賺取asiamiles績分?': 'SC516',
#  'asiamiles master card 分期可賺積分嗎': 'SC516',
#  '信用卡積分換禮物': 'SC344',
#  '品牌簽賬獎賞': 'Promotions_DynFAQ',
#  '請問網上申請信用卡幾時可以有答復，多謝': 'SC365',
#  '我用唔到face id login': 'SC642-1',
#  '我要看我戶口裡面現在有多少錢': 'SC629-1',
#  '我要看我的戶口裡面有多少錢': 'SC629-1',
#  '打不到 有其他電話嗎': 'SC4001',
#  '请问如何申请港元支票薄': 'SC188',
#  '我想上網交税，應該點做？': 'SC638',
#  '電話號碼?': 'G498',
#  '已申請 但卡還未有': 'SC417',
#  '我想問下張simply cash張卡申請狀況？': 'SC417',
#  '想問有關按揭事宜': 'G80',
#  '我想做網上物業估價': 'G463',
#  '你有冇家居保險既熱線電話': 'G498',
#  '請問如何登記為「渣打亞洲萬里通萬事達卡會員推薦計劃 」的推薦人?': 'G449',
#  '111萬定期': 'G428',
#  '定期': 'G428',
#  '电汇汇出有转帐记录吗？': 'SC629-1',
#  '电汇没有汇出的原因': 'SC112',
#  '請問如果我想更改郵寄地址, 但不方便去銀行辦理, 可以將表格傳真去哪個號碼?': 'SC353',
#  '更改地址': 'SC434',
#  '电汇到香港花旗银行需要多长时间': 'SC112',
#  '怎么确认网上银行电汇已经汇出？': 'SC112',
#  '請問點樣用信用咭交稅?': 'SC638',
#  '电汇手续费': 'SC657',
#  '我忘記網上登入密碼': 'SC633',
#  '信用咭繳稅': 'SC638',
#  '信用卡交稅': 'SC638',
#  '轉帳需要填嗎': 'SC4008-1',
#  '你有咩幫到我?': '',
#  '我可以用 Asiamiles Mastercard去交稅嗎?': 'SC638',
#  '如果我只有信用卡可以網上理財交稅嗎？': 'SC355',
#  '有冇電話可以直接問': 'SC832',
#  '我成功登入網上理財後，無法查閱我最近信用卡的消費記錄': 'GetStatement_DynFAQ',
#  '想問問我的戶口中的一筆繳費是什麼': 'GetStatement_DynFAQ',
#  '信用卡 111 reward': 'G389',
#  '电汇处理的工作时间？': 'SC234',
#  '請問用asiamile card 網上交學費可以儲里數嗎?': 'SC516',
#  '網上繳費有里數嗎?': 'SC516',
#  '电汇转账处理时间': 'SC234',
#  '电汇服务时间': 'SC234',
#  '各戶口有咩分別？我不是用做定期，': 'SC138',
#  '你識做得乜嘢?': '',
#  '需要什麼證明文件': 'Eligibility',
#  '咁你識得啲乜嘢?': '',
#  '我想將信用卡回贈金額。全數入番落信用卡戶口度': 'SC383',
#  '樂富分行有提供保管箱服務嗎？': '',
#  '本人已持有渣打銀行戶口，想做港元定期，請問利率點計，有何手續？': 'SC119',
#  '我想問取消聯名戶口有什麼手續': 'SC87',
#  '一般經網上銀行付款需時多少個工作天': 'SC662',
#  '信用卡返现怎么拿到钱？': 'SC383',
#  'Visa signature card 積分有咩用？': 'SC344',
#  '如何網上交稅': 'SC638-1',
#  '我未收到提款卡密碼': 'SC1006-1',
#  '按忘記密碼，跟着步驟輸入資料又說錯誤': 'SC1006',
#  '我已經持有Manhattan信用咭，那是否屬於舊客戶？': 'SC364',
#  '請問信用卡批核情況': 'SC417',
#  '你係咪機器人': 'P70',
#  '請問我有設海外提款，1/11-1/11，但是我在馬來西亞的渣打銀行也領不出來': 'SC413',
#  '筲箕灣有冇入錢機？': '',
#  '我 internet banking有問題': 'SC1012',
#  '你好,之前有信息提我補交申請信用卡證明文件,但係條link入唔到,想問問應該點做?': 'SC435',
#  '安卓app怎么下载': 'SC1009',
#  '你識答乜問題?': 'P5',
#  '手續費': 'G377',
#  '香港本地电汇当天的工作截止时间是？': 'SC646',
#  '信用卡客服电话': 'SC831',
#  '你好，請問外幣存款收手續費嗎？': 'SC752',
#  'Simply Cash 沒有永久豁免年費？': 'SC503',
#  '什麼是渣打亞洲萬里通萬事達卡': 'G400',
#  '請問轉帳需要填分行信息嗎？': 'SC110',
#  '信用卡查詢': 'G410',
#  '信用卡積分可當現金用嗎': 'SC344',
#  '現在申請這張有什麼迎新禮品？': 'WelcomeOffers',
#  '海外優惠呢？': 'Promotions_DynFAQ',
#  '請問我可以以渣打信用卡交稅嗎': 'SC638',
#  '你長頭髮定短頭髮㗎': 'P16',
#  '信用卡幾多積分可換現金': 'SC344',
#  '最低存款額係幾多': 'Eligibility',
#  '我想問我帳戶嘅最低deposit': 'SC99',
#  '最低存款額': 'G288',
#  '確認收妥提款卡及設定密碼': 'SC1011',
#  '如何用渣打信用卡交稅': 'SC638',
#  '亞洲萬里通': 'G451',
#  '請問點用渣打信用卡交税？': 'SC638',
#  '我想問下，我申請左Asia miles張卡點解無收以迎新個里量？': 'SC524',
#  '網上交税': 'SC638',
#  '請問simpycard 迎新優惠有＄1111回贈的詳情': 'WelcomeOffers',
#  '開左張支票唔知係咪彈票': 'SC239',
#  '未有密码': 'SC632',
#  '最低存款？': 'G288',
#  '支票戶口迎新優惠': 'WelcomeOffers',
#  '信用卡迎新優惠': 'WelcomeOffers',
#  '自動增值申請資格': 'Eligibility',
#  '电汇': 'G329',
#  '存款戶口申請資格': 'Eligibility',
#  '貸款申請資格': 'SC739',
#  '交稅': 'SC638-1',
#  '最新優惠': 'Promotions_DynFAQ',
#  '八達通自動增值': 'G374',
#  '上水廣場分行電話': '',
#  '我可以用獎賞積分兌換到什麼？': 'SC344',
#  '綱上買股票': 'G440',
#  '我忘記密碼': 'SC1006',
#  '上網買東西，為什麼沒有短信通知？太危險⚠️': 'SC180',
#  '想知日元匯率': 'SC111',
#  '你哋喺鰂魚涌有冇分行': '',
#  '請問介紹朋友成功申請有里數嗎': 'G449',
#  '邊張信用卡最好': 'SC1019',
#  '我想問你哋有咩保險產品': 'G140',
#  '你好，我想取消個綜合銀行戶口，應該怎麼做？': 'SC87',
#  '提高每日轉賬': 'SC1003',
#  '提款卡密碼如何設定？': 'SC1006',
#  '咁如何知道提款卡密碼？': 'SC1006-1',
#  '我有Asia miles SCB, 即是冇迎新禮物？': 'SC438',
#  '有冇迎新禮物': 'SC438',
#  'For「優先理財」信用卡,想問問 priority pass 的要求是什麼？': 'SC490-1',
#  '點樣交稅': 'SC638-1',
#  '儲積分': 'G390',
#  '信用卡幾錢係一分': 'SC479',
#  '信用卡': 'G410',
#  '尋找分行': '',
#  '綜合存款戶口迎新優惠': 'WelcomeOffers',
#  '戶口迎新優惠': 'WelcomeOffers',
#  '出糧升級組合迎新優惠': 'WelcomeOffers',
#  '如何申請綜合存款戶口': 'Apply',
#  '卡迎新優惠': 'WelcomeOffers',
#  '信用卡申請資格': 'Eligibility',
#  '存款戶口迎新優惠': 'WelcomeOffers',
#  '想問下最近asiamiles mastercard去海外簽賬有無promotion?': 'Promotions_DynFAQ',
#  '迎新里數': 'Promotions_DynFAQ',
#  '如可透過網上理財繳付稅項？': 'SC638',
#  '亞洲萬里通飛行裡數是否會自動轉到我的戶口？': 'SC521',
#  '如何進行電匯交易？': 'SC230',
#  '想查看1111年全年交易紀錄': 'SC653-1',
#  '我可否透過網上理財重新預定指示？': 'SC669',
#  '信用卡年費': 'G145',
#  '定期利率': 'G428',
#  '你今年幾多歲': 'P1',
#  '現金回贈優惠': 'Promotions_DynFAQ',
#  '如何開戶口': 'SC88',
#  '我想投訴': 'SC151',
#  '亞洲萬里通飛行裡數需時多久才會轉入我的戶口？': 'SC522',
#  '請問長沙灣有冇入錢機': '',
#  '不能登入app': 'SC1016',
#  '西灣河有存款機嘛？': '',
#  '忘記了網上銀行密碼及網上銀行帳號被鎖定，可以點做？': 'SC1005',
#  '繳稅': 'SC638-1',
#  '如何查詢到我的信用卡申請進度？': 'SC417',
#  '我想同職員對話': 'SC832',
#  '我要銅鑼灣分行': '',
#  '亞洲萬里通里數優惠': 'Promotions_DynFAQ',
#  '如何賺取積分？': 'SC796',
#  '信用卡優惠': 'Promotions_DynFAQ',
#  '如何申請信用卡': 'SC467',
#  '請問銅鑼灣邊度有分行可以入錢？': '',
#  '為何不能登入流動理財app': 'SC1016',
#  '可以幫我申請豁免信用卡lage charge 及finance charge嗎': 'SC424',
#  '網上理財': 'G462',
#  '如何申請網上理財': 'SC627',
#  '可以豁免我的 Simply Cash 信用卡年費嗎？': 'SC503',
#  '網上銀行登入唔到': 'SC1012',
#  '如何開戶?': 'SC88',
#  '如何申請私人貸款': 'SC740',
#  '登入唔到': 'SC642-1',
#  '你好 我登入不到網上銀行': 'SC1012',
#  '開戶有冇咩文件要準備？': 'SC88',
#  '哪些白金信用卡交易可以賺取積分？': 'SC829',
#  '如何聯絡你們熱線職員？': 'SC831',
#  '電匯是怎樣運作？': 'SC655',
#  '貸款': 'G74'}

# %%
# Group key in dictionary
v = {}

for key, value in sorted(mydict.items()):
    v.setdefault(value, []).append(key)

# %%
v
# Out:
# {'G428': ['111萬定期', '定期', '定期利率'],
#  'SC104': ['ATM 存款上限'],
#  'SC490-1': ['For「優先理財」信用卡,想問問 priority pass 的要求是什麼？'],
#  'SC433': ['Hello,想更改聯絡電話'],
#  'SC221': ['Premium理財」客戶豁免海外提款嘅手續費'],
#  'Annotated Answer ID': ['Question'],
#  'SC503': ['Simply Cash 沒有永久豁免年費？', '可以豁免我的 Simply Cash 信用卡年費嗎？'],
#  'SC406': ['VISA 欠賬', '想問下張visa 白金卡果千幾蚊欠賬係乜來？睇唔到'],
#  'SC344': ['Visa signature card 積分有咩用？',
#   '信用卡幾多積分可換現金',
#   '信用卡積分可當現金用嗎',
#   '信用卡積分換禮物',
#   '我可以用獎賞積分兌換到什麼？'],
#  'SC516': ['asiamiles master card 分期可賺積分嗎',
#   '你好想問111萬新資金係咪有111111 Asia miles',
#   '同時申請「渣打亞洲萬里通萬事達卡」及「綜合存款戶口, 是否享有可享額外1,111「亞洲萬里通」里數?',
#   '想請問用asia miles 果張mastercard 上網繳交保險 可否儲到里數？',
#   '想請問用asia miles 果張mastercard 網上繳交保險每年費用， 可否儲到asia miles里數？',
#   '網上繳費有里數嗎?',
#   '請問用asiamile card 網上交學費可以儲里數嗎?',
#   '請問用asiamiles簽單分期，可同時 賺取asiamiles績分?'],
#  'SC662': ['一般經網上銀行付款需時多少個工作天'],
#  '': ['上水廣場分行電話',
#   '你哋喺鰂魚涌有冇分行',
#   '你有咩幫到我?',
#   '你識做得乜嘢?',
#   '咁你識得啲乜嘢?',
#   '尋找分行',
#   '尋找旅行優惠',
#   '我要銅鑼灣分行',
#   '樂富分行有提供保管箱服務嗎？',
#   '筲箕灣有冇入錢機？',
#   '西灣河有存款機嘛？',
#   '請問銅鑼灣邊度有分行可以入錢？',
#   '請問長沙灣有冇入錢機'],
#  'SC180': ['上網買東西，為什麼沒有短信通知？太危險⚠️'],
#  'SC93': ['上限是多少呢？'],
#  'SC642-1': ['不能登入', '我用唔到face id login', '登入唔到'],
#  'SC1016': ['不能登入app',
#   '无论用用户名加密码 还是指纹 都无法登录 显示we are unable to process ur request.pls try again',
#   '為何不能登入流動理財app'],
#  'P10': ['九唔搭八', '你答緊乜'],
#  'G451': ['亚洲万里通', '亞洲萬裡通', '亞洲萬里通'],
#  'Promotions_DynFAQ': ['亞洲萬里通里數優惠',
#   '信用卡優惠',
#   '品牌簽賬獎賞',
#   '想問下最近asiamiles mastercard去海外簽賬有無promotion?',
#   '最新優惠',
#   '海外優惠呢？',
#   '現金回贈優惠',
#   '現金回贈優惠迎新優惠',
#   '迎新是亞洲萬里通獎賞',
#   '迎新里數'],
#  'SC521': ['亞洲萬里通飛行裡數是否會自動轉到我的戶口？'],
#  'SC522': ['亞洲萬里通飛行裡數需時多久才會轉入我的戶口？'],
#  'SC638-1': ['交稅', '如何網上交稅', '繳稅', '點樣交稅'],
#  'SC832-1': ['人工', '人工服务', '客服', '經常收到舊租客的信，已把舊信交給管理處多次，寫明冇此人，都沒有用'],
#  'G400': ['什麼是渣打亞洲萬里通萬事達卡', '渣打亞洲萬里通萬事達卡', '萬里通萬事達信用卡'],
#  'P1': ['你今年幾多歲'],
#  'P70': ['你係咪機器人'],
#  'SC86': ['你好 想資訊一下 我將有筆海外轉賬轉入本銀行 請問我需要提供的號碼是提款咭上的號碼 或是平時的轉帳發儲蓄號？',
#   '请问大额行号是多少？',
#   '香港渣打银行的SWIFT NUMBER是多少',
#   '香港渣打银行邮政编码'],
#  'SC1012': ['你好 我登入不到網上銀行', '我 internet banking有問題', '網上銀行登入唔到'],
#  'SC99': ['你好, 我今天剛開了一個戶口, 但不知是否要收年費..', '我想問我帳戶嘅最低deposit'],
#  'SC435': ['你好,之前有信息提我補交申請信用卡證明文件,但係條link入唔到,想問問應該點做?',
#   '我已申請, 但以上文件交到哪裡',
#   '我要上載申請亞洲萬里通卡之所需文件呀'],
#  'SC87': ['你好，我想取消個綜合銀行戶口，應該怎麼做？', '我想問取消聯名戶口有什麼手續'],
#  'SC112': ['你好，我有一笔汇款，好多天了，为何还没入账？',
#   '怎么确认网上银行电汇已经汇出？',
#   '电汇到香港花旗银行需要多长时间',
#   '电汇没有汇出的原因'],
#  'SC752': ['你好，請問外幣存款收手續費嗎？', '外幣手續費', '想從外幣戶口取日元'],
#  'G498': ['你有冇家居保險既熱線電話',
#   '寄件地址',
#   '我需要向上面的地址快递文件，但不知道联系电话是什么？',
#   '留了11111111 是否渣打銀行的電話',
#   '電話號碼',
#   '電話號碼?'],
#  'SC832': ['你無真人通話？',
#   '我想同職員對話',
#   '我想致電bank confirmation department',
#   '我要找職員',
#   '有冇電話可以直接問',
#   '请问STANDARD CHARTERED BANK (HONG KONG) LIMITED P.O. BOX 11111 KOWLOON EAST POST OFFICE HONG KONG 地址及联系电话是什么？'],
#  'P5': ['你識答乜問題?'],
#  'P16': ['你長頭髮定短頭髮㗎'],
#  'G410': ['信用卡', '信用卡查詢'],
#  'G389': ['信用卡 111 reward'],
#  'SC317': ['信用卡不能用'],
#  'SC638': ['信用卡交稅',
#   '信用咭繳稅',
#   '如何用渣打信用卡交稅',
#   '如可透過網上理財繳付稅項？',
#   '我可以用 Asiamiles Mastercard去交稅嗎?',
#   '我想上網交税，應該點做？',
#   '網上交税',
#   '請問我可以以渣打信用卡交稅嗎',
#   '請問點樣用信用咭交稅?',
#   '請問點用渣打信用卡交税？'],
#  'SC831': ['信用卡務中心電話？', '信用卡客服电话', '如何聯絡你們熱線職員？'],
#  'G145': ['信用卡年費'],
#  'SC479': ['信用卡幾錢係一分'],
#  'Eligibility': ['信用卡申請資格',
#   '存款戶口申請資格',
#   '我每月薪金一萬七 可以申請money back 信用卡嗎？',
#   '最低存款額係幾多',
#   '申請資格',
#   '自動增值申請資格',
#   '需要什麼證明文件'],
#  'G390': ['信用卡積分', '儲積分'],
#  'WelcomeOffers': ['信用卡迎新優惠',
#   '出糧升級組合迎新優惠',
#   '卡迎新優惠',
#   '存款戶口迎新優惠',
#   '戶口迎新優惠',
#   '支票戶口迎新優惠',
#   '現在申請這張有什麼迎新禮品？',
#   '綜合存款戶口迎新優惠',
#   '請問simpycard 迎新優惠有＄1111回贈的詳情'],
#  'SC383': ['信用卡返现怎么拿到钱？', '回贈係回落張card?', '我想將信用卡回贈金額。全數入番落信用卡戶口度'],
#  'G374': ['八達通自動增值', '八達通自動增值服務'],
#  'G414': ['出糧戶口回贈', '出糧户口推廣', '有關開立渣打出糧戶口事宜', '用來出糧'],
#  'G387': ['可以存款嗎'],
#  'SC424': ['可以幫我申請豁免信用卡lage charge 及finance charge嗎', '我去左旅行交唔到卡數,可否WAIVE?'],
#  'Apply': ['可唔可以電話apply定期存款', '如何申請綜合存款戶口', '業主貸款'],
#  'SC138': ['各戶口有咩分別？我不是用做定期，', '港幣户口'],
#  'SC1006-1': ['咁如何知道提款卡密碼？', '我未收到提款卡密碼'],
#  'SC829': ['哪些白金信用卡交易可以賺取積分？'],
#  'SC417': ['如何查詢到我的信用卡申請進度？',
#   '已申請 但卡還未有',
#   '我想問下張simply cash張卡申請狀況？',
#   '查詢信用卡批核情況 以上number是申請信用卡編號',
#   '請問信用卡批核情況'],
#  'SC467': ['如何申請信用卡'],
#  'SC740': ['如何申請私人貸款'],
#  'SC627': ['如何申請網上理財'],
#  'SC1001': ['如何登录', '我想登入戶口唔知點解入咗嚟呢個版面', '新戶口首次登入, 如何操作?'],
#  'SC796': ['如何賺取積分？'],
#  'SC230': ['如何進行電匯交易？', '我想透過網路銀行將我的美金匯到台灣渣打銀行', '我要從香港渣打銀行匯款到台灣渣打銀行'],
#  'SC88': ['如何開戶?', '如何開戶口', '開戶有冇咩文件要準備？'],
#  'SC355': ['如果我只有信用卡可以網上理財交稅嗎？'],
#  'SC1009': ['安卓app怎么下载'],
#  'SC1005': ['忘記了網上銀行密碼及網上銀行帳號被鎖定，可以點做？'],
#  'G1015': ['怎么开公司户口', '預約公司開戶'],
#  'SC374': ['想問下信用卡簽帳分期'],
#  'GetStatement_DynFAQ': ['想問問我的戶口中的一筆繳費是什麼',
#   '我想問我credit card statement',
#   '我想睇我信用卡嘅網上月結單',
#   '我成功登入網上理財後，無法查閱我最近信用卡的消費記錄'],
#  'G80': ['想問有關按揭事宜'],
#  'SC653-1': ['想查看1111年全年交易紀錄'],
#  'SC411': ['想查詢一下如申請銀聯信用卡可否簽申請簽帳分期?'],
#  'SC111': ['想知日元匯率'],
#  'G1010': ['想補交申請信用卡文件'],
#  'SC4019': ['想預訂人民幣'],
#  'SC4008': ['我剛用轉數快轉賬，不是即時嗎？'],
#  'SC669': ['我可否透過網上理財重新預定指示？'],
#  'SC633': ['我因為忘記密碼，在剛剛有去銀行重新申請一個密碼了，但輸入新密碼為什麼還是沒有辦法登入。', '我忘記網上登入密碼'],
#  'SC423': ['我在本期月結單見到一項收費 : ANNUAL FEE ANNIVERSARY HKD1111..11', '申請取消信用卡年費'],
#  'SC364': ['我已經持有Manhattan信用咭，那是否屬於舊客戶？'],
#  'SC1006': ['我忘記密碼', '按忘記密碼，跟着步驟輸入資料又說錯誤', '提款卡密碼如何設定？'],
#  'G463': ['我想做網上物業估價', '網上估價'],
#  'SC524': ['我想問下，我申請左Asia miles張卡點解無收以迎新個里量？', '我是新卡主，請問迎新mileage 何時可以取得？'],
#  'G140': ['我想問你哋有咩保險產品'],
#  'SC151': ['我想投訴', '有冇投訴熱線'],
#  'SC629-1': ['我想查询一下我的账户',
#   '我要看我戶口裡面有多少錢',
#   '我要看我戶口裡面現在有多少錢',
#   '我要看我的戶口裡面有多少錢',
#   '查詢戶口',
#   '查詢網上過數問題',
#   '查询一下我个人账户',
#   '电汇汇出有转帐记录吗？'],
#  'G489': ['我意思係現金存款'],
#  'SC110': ['我提供的網上編號怎不對呢', '請問轉帳需要填分行信息嗎？'],
#  'SC438': ['我有Asia miles SCB, 即是冇迎新禮物？', '有冇迎新禮物'],
#  'SC642': ['我登入唔到網上信用卡'],
#  'G377': ['手續費', '要收費?'],
#  'SC4001': ['打不到 有其他電話嗎'],
#  'SC1003': ['提高每日轉賬', '每天的转账金额上限是多少？'],
#  'SC343': ['換信用卡積分'],
#  'SC434': ['更改地址'],
#  'G288': ['最低存款額', '最低存款？'],
#  'P44': ['有没人'],
#  'SC632': ['未有密码'],
#  'SC119': ['本人已持有渣打銀行戶口，想做港元定期，請問利率點計，有何手續？', '請問港元定期利率多少'],
#  'SC504': ['渣打Simply Cash Visa 卡 需要年費嗎?'],
#  'SC648': ['用來轉$比人会否收手續費？', '轉帳收費'],
#  'G462': ['电子账户', '網上理財'],
#  'G329': ['电汇'],
#  'SC234': ['电汇处理的工作时间？', '电汇服务时间', '电汇转账处理时间'],
#  'SC657': ['电汇手续费'],
#  'SC1011': ['確認收妥提款卡及設定密碼'],
#  'G1011': ['税务居留国之确认书'],
#  'SC336': ['签賬積分怎样換购禮品？', '請問我昨天在海港城消費滿1千想換領現金卷可以在網上登記換領的嗎？'],
#  'G440': ['綱上買股票'],
#  'G449': ['請問介紹朋友成功申請有里數嗎', '請問如何登記為「渣打亞洲萬里通萬事達卡會員推薦計劃 」的推薦人?'],
#  'G444': ['請問如何申請中小企戶口?'],
#  'SC353': ['請問如果我想更改郵寄地址, 但不方便去銀行辦理, 可以將表格傳真去哪個號碼?'],
#  'SC413': ['請問我有設海外提款，1/11-1/11，但是我在馬來西亞的渣打銀行也領不出來'],
#  'SC96': ['請問我用櫃員機可以轉賬11,111港紙到中銀戶口嗎'],
#  'SC489': ['請問渣打信用卡有無傻惠機場橋車接送服務'],
#  'SC365': ['請問網上申請信用卡幾時可以有答復，多謝'],
#  'SC188': ['请问如何申请港元支票薄'],
#  'SC757': ['買禮券雖要付手續費嗎?'],
#  'G74': ['貸款'],
#  'SC739': ['貸款申請資格'],
#  'SC4008-1': ['轉帳需要填嗎'],
#  'SC1019': ['邊張信用卡最好'],
#  'SC239': ['開左張支票唔知係咪彈票'],
#  'SC655': ['電匯是怎樣運作？'],
#  'SC646': ['香港本地电汇当天的工作截止时间是？'],
#  'SC345': ['點樣賺取現金回贈？']}

# %%
# remove "Annotated Answer ID" key from dictionary

def removekey(d, key):
    r = dict(d)
    del r[key]
    return r

r = removekey(v, 'Annotated Answer ID')

# %%
r
# Out:
# {'G428': ['111萬定期', '定期', '定期利率'],
#  'SC104': ['ATM 存款上限'],
#  'SC490-1': ['For「優先理財」信用卡,想問問 priority pass 的要求是什麼？'],
#  'SC433': ['Hello,想更改聯絡電話'],
#  'SC221': ['Premium理財」客戶豁免海外提款嘅手續費'],
#  'SC503': ['Simply Cash 沒有永久豁免年費？', '可以豁免我的 Simply Cash 信用卡年費嗎？'],
#  'SC406': ['VISA 欠賬', '想問下張visa 白金卡果千幾蚊欠賬係乜來？睇唔到'],
#  'SC344': ['Visa signature card 積分有咩用？',
#   '信用卡幾多積分可換現金',
#   '信用卡積分可當現金用嗎',
#   '信用卡積分換禮物',
#   '我可以用獎賞積分兌換到什麼？'],
#  'SC516': ['asiamiles master card 分期可賺積分嗎',
#   '你好想問111萬新資金係咪有111111 Asia miles',
#   '同時申請「渣打亞洲萬里通萬事達卡」及「綜合存款戶口, 是否享有可享額外1,111「亞洲萬里通」里數?',
#   '想請問用asia miles 果張mastercard 上網繳交保險 可否儲到里數？',
#   '想請問用asia miles 果張mastercard 網上繳交保險每年費用， 可否儲到asia miles里數？',
#   '網上繳費有里數嗎?',
#   '請問用asiamile card 網上交學費可以儲里數嗎?',
#   '請問用asiamiles簽單分期，可同時 賺取asiamiles績分?'],
#  'SC662': ['一般經網上銀行付款需時多少個工作天'],
#  '': ['上水廣場分行電話',
#   '你哋喺鰂魚涌有冇分行',
#   '你有咩幫到我?',
#   '你識做得乜嘢?',
#   '咁你識得啲乜嘢?',
#   '尋找分行',
#   '尋找旅行優惠',
#   '我要銅鑼灣分行',
#   '樂富分行有提供保管箱服務嗎？',
#   '筲箕灣有冇入錢機？',
#   '西灣河有存款機嘛？',
#   '請問銅鑼灣邊度有分行可以入錢？',
#   '請問長沙灣有冇入錢機'],
#  'SC180': ['上網買東西，為什麼沒有短信通知？太危險⚠️'],
#  'SC93': ['上限是多少呢？'],
#  'SC642-1': ['不能登入', '我用唔到face id login', '登入唔到'],
#  'SC1016': ['不能登入app',
#   '无论用用户名加密码 还是指纹 都无法登录 显示we are unable to process ur request.pls try again',
#   '為何不能登入流動理財app'],
#  'P10': ['九唔搭八', '你答緊乜'],
#  'G451': ['亚洲万里通', '亞洲萬裡通', '亞洲萬里通'],
#  'Promotions_DynFAQ': ['亞洲萬里通里數優惠',
#   '信用卡優惠',
#   '品牌簽賬獎賞',
#   '想問下最近asiamiles mastercard去海外簽賬有無promotion?',
#   '最新優惠',
#   '海外優惠呢？',
#   '現金回贈優惠',
#   '現金回贈優惠迎新優惠',
#   '迎新是亞洲萬里通獎賞',
#   '迎新里數'],
#  'SC521': ['亞洲萬里通飛行裡數是否會自動轉到我的戶口？'],
#  'SC522': ['亞洲萬里通飛行裡數需時多久才會轉入我的戶口？'],
#  'SC638-1': ['交稅', '如何網上交稅', '繳稅', '點樣交稅'],
#  'SC832-1': ['人工', '人工服务', '客服', '經常收到舊租客的信，已把舊信交給管理處多次，寫明冇此人，都沒有用'],
#  'G400': ['什麼是渣打亞洲萬里通萬事達卡', '渣打亞洲萬里通萬事達卡', '萬里通萬事達信用卡'],
#  'P1': ['你今年幾多歲'],
#  'P70': ['你係咪機器人'],
#  'SC86': ['你好 想資訊一下 我將有筆海外轉賬轉入本銀行 請問我需要提供的號碼是提款咭上的號碼 或是平時的轉帳發儲蓄號？',
#   '请问大额行号是多少？',
#   '香港渣打银行的SWIFT NUMBER是多少',
#   '香港渣打银行邮政编码'],
#  'SC1012': ['你好 我登入不到網上銀行', '我 internet banking有問題', '網上銀行登入唔到'],
#  'SC99': ['你好, 我今天剛開了一個戶口, 但不知是否要收年費..', '我想問我帳戶嘅最低deposit'],
#  'SC435': ['你好,之前有信息提我補交申請信用卡證明文件,但係條link入唔到,想問問應該點做?',
#   '我已申請, 但以上文件交到哪裡',
#   '我要上載申請亞洲萬里通卡之所需文件呀'],
#  'SC87': ['你好，我想取消個綜合銀行戶口，應該怎麼做？', '我想問取消聯名戶口有什麼手續'],
#  'SC112': ['你好，我有一笔汇款，好多天了，为何还没入账？',
#   '怎么确认网上银行电汇已经汇出？',
#   '电汇到香港花旗银行需要多长时间',
#   '电汇没有汇出的原因'],
#  'SC752': ['你好，請問外幣存款收手續費嗎？', '外幣手續費', '想從外幣戶口取日元'],
#  'G498': ['你有冇家居保險既熱線電話',
#   '寄件地址',
#   '我需要向上面的地址快递文件，但不知道联系电话是什么？',
#   '留了11111111 是否渣打銀行的電話',
#   '電話號碼',
#   '電話號碼?'],
#  'SC832': ['你無真人通話？',
#   '我想同職員對話',
#   '我想致電bank confirmation department',
#   '我要找職員',
#   '有冇電話可以直接問',
#   '请问STANDARD CHARTERED BANK (HONG KONG) LIMITED P.O. BOX 11111 KOWLOON EAST POST OFFICE HONG KONG 地址及联系电话是什么？'],
#  'P5': ['你識答乜問題?'],
#  'P16': ['你長頭髮定短頭髮㗎'],
#  'G410': ['信用卡', '信用卡查詢'],
#  'G389': ['信用卡 111 reward'],
#  'SC317': ['信用卡不能用'],
#  'SC638': ['信用卡交稅',
#   '信用咭繳稅',
#   '如何用渣打信用卡交稅',
#   '如可透過網上理財繳付稅項？',
#   '我可以用 Asiamiles Mastercard去交稅嗎?',
#   '我想上網交税，應該點做？',
#   '網上交税',
#   '請問我可以以渣打信用卡交稅嗎',
#   '請問點樣用信用咭交稅?',
#   '請問點用渣打信用卡交税？'],
#  'SC831': ['信用卡務中心電話？', '信用卡客服电话', '如何聯絡你們熱線職員？'],
#  'G145': ['信用卡年費'],
#  'SC479': ['信用卡幾錢係一分'],
#  'Eligibility': ['信用卡申請資格',
#   '存款戶口申請資格',
#   '我每月薪金一萬七 可以申請money back 信用卡嗎？',
#   '最低存款額係幾多',
#   '申請資格',
#   '自動增值申請資格',
#   '需要什麼證明文件'],
#  'G390': ['信用卡積分', '儲積分'],
#  'WelcomeOffers': ['信用卡迎新優惠',
#   '出糧升級組合迎新優惠',
#   '卡迎新優惠',
#   '存款戶口迎新優惠',
#   '戶口迎新優惠',
#   '支票戶口迎新優惠',
#   '現在申請這張有什麼迎新禮品？',
#   '綜合存款戶口迎新優惠',
#   '請問simpycard 迎新優惠有＄1111回贈的詳情'],
#  'SC383': ['信用卡返现怎么拿到钱？', '回贈係回落張card?', '我想將信用卡回贈金額。全數入番落信用卡戶口度'],
#  'G374': ['八達通自動增值', '八達通自動增值服務'],
#  'G414': ['出糧戶口回贈', '出糧户口推廣', '有關開立渣打出糧戶口事宜', '用來出糧'],
#  'G387': ['可以存款嗎'],
#  'SC424': ['可以幫我申請豁免信用卡lage charge 及finance charge嗎', '我去左旅行交唔到卡數,可否WAIVE?'],
#  'Apply': ['可唔可以電話apply定期存款', '如何申請綜合存款戶口', '業主貸款'],
#  'SC138': ['各戶口有咩分別？我不是用做定期，', '港幣户口'],
#  'SC1006-1': ['咁如何知道提款卡密碼？', '我未收到提款卡密碼'],
#  'SC829': ['哪些白金信用卡交易可以賺取積分？'],
#  'SC417': ['如何查詢到我的信用卡申請進度？',
#   '已申請 但卡還未有',
#   '我想問下張simply cash張卡申請狀況？',
#   '查詢信用卡批核情況 以上number是申請信用卡編號',
#   '請問信用卡批核情況'],
#  'SC467': ['如何申請信用卡'],
#  'SC740': ['如何申請私人貸款'],
#  'SC627': ['如何申請網上理財'],
#  'SC1001': ['如何登录', '我想登入戶口唔知點解入咗嚟呢個版面', '新戶口首次登入, 如何操作?'],
#  'SC796': ['如何賺取積分？'],
#  'SC230': ['如何進行電匯交易？', '我想透過網路銀行將我的美金匯到台灣渣打銀行', '我要從香港渣打銀行匯款到台灣渣打銀行'],
#  'SC88': ['如何開戶?', '如何開戶口', '開戶有冇咩文件要準備？'],
#  'SC355': ['如果我只有信用卡可以網上理財交稅嗎？'],
#  'SC1009': ['安卓app怎么下载'],
#  'SC1005': ['忘記了網上銀行密碼及網上銀行帳號被鎖定，可以點做？'],
#  'G1015': ['怎么开公司户口', '預約公司開戶'],
#  'SC374': ['想問下信用卡簽帳分期'],
#  'GetStatement_DynFAQ': ['想問問我的戶口中的一筆繳費是什麼',
#   '我想問我credit card statement',
#   '我想睇我信用卡嘅網上月結單',
#   '我成功登入網上理財後，無法查閱我最近信用卡的消費記錄'],
#  'G80': ['想問有關按揭事宜'],
#  'SC653-1': ['想查看1111年全年交易紀錄'],
#  'SC411': ['想查詢一下如申請銀聯信用卡可否簽申請簽帳分期?'],
#  'SC111': ['想知日元匯率'],
#  'G1010': ['想補交申請信用卡文件'],
#  'SC4019': ['想預訂人民幣'],
#  'SC4008': ['我剛用轉數快轉賬，不是即時嗎？'],
#  'SC669': ['我可否透過網上理財重新預定指示？'],
#  'SC633': ['我因為忘記密碼，在剛剛有去銀行重新申請一個密碼了，但輸入新密碼為什麼還是沒有辦法登入。', '我忘記網上登入密碼'],
#  'SC423': ['我在本期月結單見到一項收費 : ANNUAL FEE ANNIVERSARY HKD1111..11', '申請取消信用卡年費'],
#  'SC364': ['我已經持有Manhattan信用咭，那是否屬於舊客戶？'],
#  'SC1006': ['我忘記密碼', '按忘記密碼，跟着步驟輸入資料又說錯誤', '提款卡密碼如何設定？'],
#  'G463': ['我想做網上物業估價', '網上估價'],
#  'SC524': ['我想問下，我申請左Asia miles張卡點解無收以迎新個里量？', '我是新卡主，請問迎新mileage 何時可以取得？'],
#  'G140': ['我想問你哋有咩保險產品'],
#  'SC151': ['我想投訴', '有冇投訴熱線'],
#  'SC629-1': ['我想查询一下我的账户',
#   '我要看我戶口裡面有多少錢',
#   '我要看我戶口裡面現在有多少錢',
#   '我要看我的戶口裡面有多少錢',
#   '查詢戶口',
#   '查詢網上過數問題',
#   '查询一下我个人账户',
#   '电汇汇出有转帐记录吗？'],
#  'G489': ['我意思係現金存款'],
#  'SC110': ['我提供的網上編號怎不對呢', '請問轉帳需要填分行信息嗎？'],
#  'SC438': ['我有Asia miles SCB, 即是冇迎新禮物？', '有冇迎新禮物'],
#  'SC642': ['我登入唔到網上信用卡'],
#  'G377': ['手續費', '要收費?'],
#  'SC4001': ['打不到 有其他電話嗎'],
#  'SC1003': ['提高每日轉賬', '每天的转账金额上限是多少？'],
#  'SC343': ['換信用卡積分'],
#  'SC434': ['更改地址'],
#  'G288': ['最低存款額', '最低存款？'],
#  'P44': ['有没人'],
#  'SC632': ['未有密码'],
#  'SC119': ['本人已持有渣打銀行戶口，想做港元定期，請問利率點計，有何手續？', '請問港元定期利率多少'],
#  'SC504': ['渣打Simply Cash Visa 卡 需要年費嗎?'],
#  'SC648': ['用來轉$比人会否收手續費？', '轉帳收費'],
#  'G462': ['电子账户', '網上理財'],
#  'G329': ['电汇'],
#  'SC234': ['电汇处理的工作时间？', '电汇服务时间', '电汇转账处理时间'],
#  'SC657': ['电汇手续费'],
#  'SC1011': ['確認收妥提款卡及設定密碼'],
#  'G1011': ['税务居留国之确认书'],
#  'SC336': ['签賬積分怎样換购禮品？', '請問我昨天在海港城消費滿1千想換領現金卷可以在網上登記換領的嗎？'],
#  'G440': ['綱上買股票'],
#  'G449': ['請問介紹朋友成功申請有里數嗎', '請問如何登記為「渣打亞洲萬里通萬事達卡會員推薦計劃 」的推薦人?'],
#  'G444': ['請問如何申請中小企戶口?'],
#  'SC353': ['請問如果我想更改郵寄地址, 但不方便去銀行辦理, 可以將表格傳真去哪個號碼?'],
#  'SC413': ['請問我有設海外提款，1/11-1/11，但是我在馬來西亞的渣打銀行也領不出來'],
#  'SC96': ['請問我用櫃員機可以轉賬11,111港紙到中銀戶口嗎'],
#  'SC489': ['請問渣打信用卡有無傻惠機場橋車接送服務'],
#  'SC365': ['請問網上申請信用卡幾時可以有答復，多謝'],
#  'SC188': ['请问如何申请港元支票薄'],
#  'SC757': ['買禮券雖要付手續費嗎?'],
#  'G74': ['貸款'],
#  'SC739': ['貸款申請資格'],
#  'SC4008-1': ['轉帳需要填嗎'],
#  'SC1019': ['邊張信用卡最好'],
#  'SC239': ['開左張支票唔知係咪彈票'],
#  'SC655': ['電匯是怎樣運作？'],
#  'SC646': ['香港本地电汇当天的工作截止时间是？'],
#  'SC345': ['點樣賺取現金回贈？']}

# %%
#for key, value in r.items():
#    print (key, value)

# %%
#list(r.keys())
#list(r.values())

# %%
TAIL = 4

# --------------
from xml.etree.ElementTree import ElementTree,Element
 
def read_xml(in_path):
    '''读取并解析xml文件
       in_path: xml路径
       return: ElementTree'''
    tree = ElementTree()
    tree.parse(in_path)
    return tree
 
def write_xml(tree, out_path):
    '''将xml文件写出
       tree: xml树
       out_path: 写出路径'''
    tree.write(out_path, encoding="utf-8",xml_declaration=True)
 
    
def if_match(node, kv_map):
    '''判断某个节点是否包含所有传入参数属性
       node: 节点
       kv_map: 属性及属性值组成的map'''
    for key in kv_map:
        if node.get(key) != kv_map.get(key):
            return False
    return True
 
#---------------search -----
 
def find_nodes(tree, path):
    '''查找某个路径匹配的所有节点
       tree: xml树
       path: 节点路径'''
    return tree.findall(path)
 
 
def get_node_by_keyvalue(nodelist, kv_map):
    '''根据属性及属性值定位符合的节点，返回节点
       nodelist: 节点列表
       kv_map: 匹配属性及属性值map'''
    result_nodes = []
    for node in nodelist:
        if if_match(node, kv_map):
            result_nodes.append(node)
    return result_nodes


def get_node_by_tag(nodelist, tag):
    '''根据tag定位符合的节点，返回节点
       nodelist: 节点列表
       tag 节点类型'''
    result_nodes = []
    for node in nodelist:
        if node.tag == tag:
            result_nodes.append(node)
    return result_nodes
 
#---------------change -----
 
def change_node_properties(nodelist, kv_map, is_delete=False):
    '''修改/增加 /删除 节点的属性及属性值
       nodelist: 节点列表
       kv_map:属性及属性值map'''
    for node in nodelist:
        for key in kv_map:
            if is_delete: 
                if key in node.attrib:
                    del node.attrib[key]
            else:
                node.set(key, kv_map.get(key))
            
def change_node_text(nodelist, text, is_add=False, is_delete=False):
    '''改变/增加/删除一个节点的文本
       nodelist:节点列表
       text : 更新后的文本'''
    for node in nodelist:
        if is_add:
            node.text += text
        elif is_delete:
            node.text = ""
        else:
            node.text = text
            
def create_node(tag, property_map, content, tail=TAIL):
    '''新造一个节点
       tag:节点标签
       property_map:属性及属性值map
       content: 节点闭合标签里的文本内容
       return 新节点'''
    element = Element(tag, property_map)
    element.text = content
    element.tail = "\n" + tail*"  "
    return element
        
def add_child_node(nodelist, element, tail=TAIL):
    '''给一个节点添加子节点
       nodelist: 节点列表
       element: 子节点'''
    # 调节indent
    if len(nodelist[-1]) > 0:
        last_node = nodelist[-1][-1]
        last_node.tail = "\n" + tail*"  "
    for node in nodelist:
        node.append(element)
        
def del_node_by_tagkeyvalue(nodelist, tag, kv_map):
    '''同过属性及属性值定位一个节点，并删除之
       nodelist: 父节点列表
       tag:子节点标签
       kv_map: 属性及属性值列表'''
    for parent_node in nodelist:
        children = parent_node.getchildren()
        for child in children:
            if child.tag == tag and if_match(child, kv_map):
                parent_node.remove(child)

# %%
import hashlib

def hashify(text):
    m = hashlib.md5()
    m.update(text.encode('utf-8'))
    md5_id = m.hexdigest()
    return md5_id

# %%
def find_nodes(tree, path):
    '''查找某个路径匹配的所有节点
       tree: xml树
       path: 节点路径'''
    return tree.findall(path)


def get_all_by_scid(scid, path):
    print(scid)
    tree = read_xml(path)
    
    nodes = find_nodes(tree, "intents/intent/qa")
    
    #scid = "SC86"
    scid = "VpaGetAnswer__Question--String__"+scid
    
    result_nodes = get_node_by_keyvalue(nodes, {"id": scid})
    
    res_nodes = get_node_by_tag(result_nodes[0], tag="question")
    
    lst = list()
    
    for node in res_nodes:
        
        lst.append(node.text)
    
    return lst


def insert_xml(toAddList, scid, path):
    # --------------faq------------
    tree = read_xml(path)
    
    nodes = find_nodes(tree, "intents/intent/qa")
    
    result_nodes = get_node_by_keyvalue(nodes, {"id": scid})
    
    #--------------func------------------------
    def faq_adding(seeds, path):
        
        for i in range(len(seeds)):
            content = seeds[i]
            
            a = create_node("question", {"id":hashify(content),"scope":"train", "source":"seed"}, content)
            if i==len(seeds)-1:
                a = create_node("question", {"id":hashify(content),"scope":"train", "source":"seed"}, content, tail=3)
                
            add_child_node(result_nodes, a)
    
        write_xml(tree, path)
    #-------------------------------------
    
    faq_adding(toAddList, path)
    
    print(scid + "finished.")

# %%
get_all_by_scid('SC86', 'faq_1.xml')
# Out:
# SC86
# ['swift代碼是什麼？',
#  'swift代碼係咩？',
#  '渣打swift係唔係SCBLHKHHXXX',
#  '朋友想匯錢畀我佢要畀咩資料我',
#  '新增電匯收款人嗰度填咩',
#  '唔識填TT',
#  '人哋想匯錢畀我頂填乜',
#  '有人想海外匯款畀渣打要填乜',
#  '如果渣打收匯款要填乜',
#  '有人想海外匯款畀渣打要填乜',
#  '渣打swift是什麼',
#  '渣打銀行代碼是什麼',
#  '渣打銀行地址是什麼',
#  '我需要什麼資料才能電匯',
#  '需要什麼代碼才能匯款',
#  '渣打swift係咩',
#  '渣打swift係乜',
#  '渣打銀行代碼係咩',
#  '渣打銀行代碼係乜',
#  '渣打銀行地址係咩',
#  '渣打銀行地址係乜',
#  'SC swift係咩',
#  'SC swift係乜',
#  'SCB swift係咩',
#  'SCB swift係乜',
#  'SC 銀行代碼係咩',
#  'SC 銀行代碼係乜',
#  'SCB 銀行代碼係咩',
#  'SCB 銀行代碼係乜',
#  'SC 銀行地址係咩',
#  'SC 銀行地址係乜',
#  'SCB 銀行地址係咩',
#  'SCB 銀行地址係乜',
#  'SC 銀行address係咩',
#  'SC 銀行address係乜',
#  '我需要咩資料先電匯到',
#  '我需要咩資料先TT到',
#  '我需要咩資料先匯到錢',
#  '我需要乜資料先電匯到',
#  '我需要乜資料先TT到',
#  '我需要乜資料先匯到錢',
#  '我需要咩info先電匯到',
#  '我需要咩info先TT到',
#  '我需要咩info先匯到錢',
#  '我需要乜info先電匯到',
#  '我需要乜info先TT到',
#  '我需要乜info先匯到錢',
#  '我需要咩代碼先電匯到',
#  '我需要咩代碼先TT到',
#  '我需要咩代碼先匯到錢',
#  '我需要乜code先電匯到',
#  '我需要乜code先TT到',
#  '我需要乜code先匯到錢',
#  '我要咩資料先電匯到',
#  '我要咩資料先TT到',
#  '我要乜資料先電匯到',
#  '我要乜資料先TT到',
#  '我要咩info先電匯到',
#  '我要咩info先TT到',
#  '我要咩info先匯到錢',
#  '我要乜info先電匯到',
#  '我要乜info先TT到',
#  '我要乜info先匯到錢',
#  '我要咩代碼先電匯到',
#  '我要咩代碼先TT到',
#  '我要咩代碼先匯到錢',
#  '我要乜code先電匯到',
#  '我要乜code先TT到',
#  '我要乜code先匯到錢',
#  '要咩資料先電匯到',
#  '要咩資料先TT到',
#  '要乜資料先電匯到',
#  '要乜資料先TT到',
#  '要咩info先電匯到',
#  '要咩info先TT到',
#  '要咩info先匯到錢',
#  '要乜info先電匯到',
#  '要乜info先TT到',
#  '要乜info先匯到錢',
#  '要咩代碼先電匯到',
#  '要咩代碼先TT到',
#  '要咩代碼先匯到錢',
#  '要乜code先電匯到',
#  '要乜code先TT到',
#  '要乜code先匯到錢',
#  '個swift code係咩',
#  '渣打swift code係咩',
#  '渣打swift code',
#  '我想做電匯,有咩資料提供',
#  '我想收電匯,對方有咩要資料提供',
#  '我想收TT,對方有咩要資料提供',
#  '我想in TT,有咩資料提供',
#  '我想做in TT,有咩資料提供',
#  'SC swift code係咩',
#  'SC swift code係乜',
#  'SCB swift code係咩',
#  'SCB swift code係乜',
#  '我要咩資料先匯到錢',
#  '我要乜資料先匯到錢',
#  '要咩資料先匯到錢',
#  '要乜資料先匯到錢',
#  '要乜code先匯到錢你哋個swift係咩',
#  '你哋個swift code係咩',
#  '我想知個swift code',
#  '我想要swift code',
#  '咩係swift代碼',
#  'swift code係咩',
#  '乜係swift代碼？',
#  '請問swift代碼係乜嘢？',
#  '我想知道swift代碼係乜嘢嚟㗎？',
#  '咩嘢係swift code',
#  '乜嘢係swift代碼？',
#  'swift代碼係咩？',
#  '我想知道swift代碼係乜嘢？',
#  '咩係swift代碼？',
#  '我想知道swift代碼係乜嘢意思？',
#  '請問咩係swift代碼？',
#  '咩嘢係銀行嘅swift code',
#  '我想知其實咩嘢係swift code',
#  'swift代碼是乜嘢來的？',
#  'swift代碼係點嘅？',
#  '咩嘢係swift代碼？',
#  'swift代碼係咩嚟？',
#  '我想問下swift代碼是什麼？',
#  'swift代碼是什麼意思？',
#  '我想知swift code係咩嚟㗎',
#  '我想問swift code係咩嚟',
#  'swift代碼係咩嘢嚟？',
#  'swift code係咩嚟',
#  '咩係swift碼',
#  'swift代碼係指咩嘢？',
#  'swift code係乜嘢？',
#  '咩係swift code？',
#  '想問聲swift代碼是什麼？',
#  '想問聲swift代碼是什麼意思？',
#  '唔該請問swift代碼是什麼？',
#  '請話我知swift代碼是什麼？',
#  '想了解一下swift代碼係咩？',
#  'swift代碼係咩嚟？',
#  '我想知swift代碼咩嚟？',
#  'swift代碼係點樣？',
#  '請講我知swift代碼是什麼？',
#  '請講我知swift代碼指什麼？',
#  'swift code其實係咩嚟',
#  'swift code係咩嚟㗎',
#  '我想知道swift code係咩嚟',
#  'swift代碼係咩嚟',
#  'swift code係咩嘢嚟',
#  '咩叫做swift代碼？',
#  'swift code係咩嚟？',
#  '唔該swift代碼是什麼？',
#  '咩嘢係swift代碼',
#  '唔該swift代碼是指什麼？',
#  '想知咩係swift代碼',
#  '我唔知道swift代碼是什麼？',
#  '想問咩叫swift代碼？',
#  '想知swift代碼係咩嚟',
#  'swift code係咩？',
#  'swift代碼係咩',
#  '可唔可以講解swift代碼係咩？',
#  'swift代碼係咩意思？',
#  '話我知swift代碼係乜？',
#  '想知swift代碼係咩',
#  'swift代碼係乜？',
#  '我想知道swift代碼指什麼？',
#  '我想知道swift代碼是什麼？',
#  'swift code係乜？',
#  'swift代碼係咩嘢？',
#  '貴銀行swift代碼係咩？',
#  '咩叫swift代碼？',
#  '想知swift code係咩？',
#  '同我講swift code係咩？',
#  '何謂swift代碼？',
#  '想請問swift代碼係咩？',
#  '我想知道swift代碼係咩？',
#  'swift代碼係乜？',
#  '想了解一下swift代碼係咩嘢？',
#  'swift code是什麼？',
#  '我唔清楚swift代碼是什麼？',
#  '咩嘢叫swift代碼？',
#  'swift代碼係咩吖？',
#  'swift code係咩吖？',
#  '咩嘢叫swift?',
#  '我不清楚swift代碼指什麼？',
#  'swift代碼係咩嘢嚟㗎？',
#  '乜嘢係swift?',
#  '咩係swift code?',
#  '想請問swift代碼係咩嘢？',
#  '想請問swift代碼係咩嘢嚟？',
#  '想請問swift代碼係代表咩？',
#  '渣打香港嗰swift code係啲咩嘢嚟？',
#  '我不清楚swift代碼的意思？',
#  'swift code係什麼？',
#  'swift代碼指什麼意思？',
#  'swift代碼係咩嚟㗎',
#  '咩係swift代碼嚟',
#  '咩叫做swift 代碼？',
#  '咩係swift代碼吖',
#  '想請問swift代碼到底係咩嘢嚟？',
#  '想請問一下swift代碼係咩嘢？',
#  '煩請指教swift代碼係咩嘢？',
#  '唔該swift代碼係咩嘢？',
#  '我想多d了解一下swift代碼係咩嘢？',
#  '我想了解一下swift代碼係咩嘢？',
#  '唔該你請問一下swift代碼係咩嘢？',
#  '唔該你幫幫手，swift代碼係咩嘢？',
#  'swift嘅代碼係乜嘢？',
#  '唔該講畀我知swift代碼是什麼？',
#  '什麼是swift代碼？',
#  '銀行界嘅swift代碼係咩嘢呢？',
#  '何謂swift代碼呢？',
#  '想知悉swift代碼係咩嘢？',
#  'swift代碼係咩嘢嚟？謝謝！',
#  '咩係swift code？',
#  'swift code即係乜嘢？',
#  '唔該講畀我知swift代碼是什麼意思？',
#  '我想知swift code咩嚟？',
#  'swift代碼係乜嘢？',
#  'swift代碼係銀行係統嚟講係咩嘢？',
#  '我想咨詢一下swift代碼係乜意思？',
#  '你好。請問你swift代碼係咩嘢？',
#  'swift代碼可以用來做乜？',
#  '乜係swift代碼？',
#  'swift代碼是什麼來的？',
#  '我想知swift code咩嘢嚟？',
#  '同我講swift code係咩嚟？',
#  '請問swift代碼指什麼意思？',
#  '我想咨詢一下swift代碼是什麼來的？',
#  'swift代碼係咩嚟？',
#  'swift code係咩嚟？',
#  'swift代碼是點樣？',
#  '借問一下，swift代碼係咩嘢？',
#  '知唔知什麼是swift代碼？',
#  '話畀我知，swift代碼係咩嘢？',
#  '唔該幫我查下乜嘢是swift代碼？',
#  'swift代碼係咩嘢嚟嘅？',
#  'swift code係乜》',
#  'swift代碼乜嘢number，我想知。',
#  'swift代碼係咩嘢嚟嘅？',
#  'swift代碼係咩嘢我想知',
#  '銀行swift number是什麼？',
#  'swift代碼有乜用？',
#  'swift代碼係哋咩嘢嚟嘅？',
#  'swift代碼係什麼？',
#  'swift代碼是咩嘢？',
#  '乜是swift個代碼',
#  '同我講swift代碼是幾號？',
#  '乜係swift嘅代碼',
#  '我swift代碼係乜嘢？',
#  '同我講乜是swift代碼？',
#  'swift代碼是乜來嘅？',
#  '請問什麼是swift代碼？',
#  '麻煩同我講swift代碼係乜？',
#  '唔該幫我查下什麼是swift代碼？',
#  '請問乜係swift代碼？',
#  '我想睇下什麼是swift代碼？',
#  'swift代碼可以用來做乜嘢？',
#  'swift代碼有乜用途？',
#  'swift代碼可以用來做乜？',
#  '唔該幫我查swift代碼是什麼？',
#  '要點樣check swift代碼是什麼？',
#  'swift代碼係乜嘢來嘅？',
#  '請問swift代碼是什麼？',
#  '請問swift 代碼係咩？',
#  '點check 銀行swift代碼？',
#  'swift嘅代碼係乜嘢？',
#  'swift code係乜？',
#  '乜嘢是swift代碼,話我知。？',
#  'swift code可以用來做乜？',
#  'swift代碼是什麼，同我講下？',
#  'swift code有乜作用？',
#  'swift代碼係乜嘢？',
#  '我要怎麼知swift代碼是什麼？',
#  '唔該幫我查下swift代碼是什麼？',
#  'swift代碼有乜作用？',
#  '請解釋swift代碼。',
#  '什麼是swift代碼？',
#  'swift code有乜用途？',
#  '斯威夫特代碼係乜嘢',
#  'swift代碼是怎樣的？',
#  'swift代碼有乜作用？唔該畀我知。',
#  '請問swift代碼有乜用途？',
#  'swift代碼應該用來做乜？',
#  'swift代碼係乜意思？',
#  '睇返我swift代碼是什麼？',
#  '知唔知swift代碼是乜？',
#  '什麼是swift代碼？',
#  'swift代碼有乜意義？',
#  '同我check下什麼是swift代碼？',
#  '我想知道swift代碼是咩。',
#  '怎樣的代碼是swift代碼？',
#  'swift代碼是什麼樣的？',
#  '呢個 swift代碼係咩來嘅？',
#  'swift代碼到底是咩？',
#  'swift代碼係麼嘢嚟嘅？',
#  'swift code嘅用途係乜？',
#  'what is swift代碼？',
#  'swift代碼是哪類？',
#  '哪類代碼是swift代碼？',
#  '幫我查一下swift代碼係咩嘢？',
#  '我想了解什麼是swift代碼？',
#  'swift代碼嘅作用係乜？',
#  'swift code嘅用途有乜？',
#  '乜嘢是swift代碼，同我講下？',
#  'swift code 可以用來做乜嘢？',
#  'TT點樣填吖',
#  '海外匯款畀渣打, 銀行嗰度係填咩？',
#  '新增TT收款人應該填什麼？',
#  '渣打swift 即係SCBLHKHHXXX?',
#  '如果有人想係外國匯錢畀渣打，銀行嗰度需要填D咩？',
#  '朋友希望匯錢畀我，我要有佢什麼資料？',
#  '朋友想匯錢畀我，我應該知道咩資料？',
#  '電匯該怎樣填寫？',
#  '別人匯錢給我要填乜？',
#  '渣打嗰個swift code係咪SCBLHKHHXXX',
#  '人哋有咩要填先可以匯款畀我',
#  '別人匯錢畀我嘅程序係？',
#  '呢嗰TT係唔係tele transfer？ 應該要點填？',
#  '其他人想海外匯款給予渣打的話, 銀行是填寫什麼呢？',
#  '乜係我要填嘅先可以讓渣打收匯款？',
#  '渣打收匯款要填什麼',
#  '我想問填TT嘅方法？',
#  '我想請問如果想海外匯款畀渣打嘅話，係咪有d咩要填呢？',
#  'TT程序點樣做？',
#  '我想知渣打收匯款該填嘅資料。',
#  '填乜可以讓我攞到人哋匯畀我嘅錢？',
#  '我唔識TT填乜嘢',
#  '我唔識TT要填乜嘢',
#  '新增電匯個收款人係要點填㗎？',
#  '人哋想匯款畀我唔知要填乜',
#  '告訴我新增嘅TT 收款人該填什麼資料。',
#  '你可以話我知渣打嘅swift係咪SCBLHKHHXXX嗎?',
#  '有人匯款給我要填什麼',
#  '要填乜嘢如果我想加個電匯payee',
#  '想要海外匯款畀渣打嘅話， 我想問銀行點樣填㗎？',
#  '不明白怎樣填TT',
#  '在海外匯款畀渣打銀行有什麼要填',
#  '怎樣填TT？',
#  '渣打嘅swift係咪SCBLHKHHXXX？',
#  '渣打的swift 是SCBLHKHHXXX?',
#  '我想問人哋要匯錢畀我嘅話有d乜嘢要填？',
#  '我不懂填TT',
#  '我想問填什麼渣打先可以收到匯款？',
#  '新增電匯收款人要點填',
#  '我想知渣打swift是等於SCBLHKHHXXX？',
#  'TT手續怎樣填？',
#  '你教我點填TT',
#  '我應該點填TT？',
#  '別人要匯款給我該怎麼辦',
#  '要做海外匯款畀渣打銀行應填寫什麼？',
#  '填TT嘅方式是什麼？',
#  '可唔可以教我係渣打收匯款要點做',
#  '朋友要畀咩info我先可以匯錢過嚟?',
#  '渣打要收呢個匯款嘅話需要填D咩資料？',
#  '如果朋友想匯綫給我, 需要提供什麼資料給我?',
#  '海外匯款畀渣打銀行有什麼要填',
#  '我想知道如果我個friend想匯錢畀我，佢要畀我咩資料。',
#  '渣打收匯款係咪有d乜嘢需要填呢？',
#  '我想知SCBLHKHHXXX是否渣打的swift',
#  '渣打swift能否用SCBLHKHHXXX吖？',
#  'SCBLHKHHXXX係咪即係渣打swift？',
#  '朋友想匯錢畀我嘅時候，佢需要提供什麼資料畀我？',
#  '我需要填d乜先可以收到人哋匯畀我嘅錢？',
#  '我想知道人哋想匯錢畀我嘅話點做？',
#  '海外transfer money 畀渣打銀行要填咩',
#  '你可以話我知海外匯款畀渣打有冇d乜嘢要填嘛？',
#  '話我知SCBLHKHHXXX是渣打的swift ma?',
#  '我想知其他人想海外匯款給予渣打, 銀行要點寫？',
#  '新增電匯收款人嗰度要點填㗎？',
#  '新增電匯收款人嗰格要填乜嘢？',
#  '人哋要填乜先可以匯款畀我',
#  '人哋想匯錢畀我點樣填？',
#  '有人匯錢畀我頂填寫咩㗎？',
#  '人哋想匯錢畀我應如何填寫？',
#  '不明白如何填TT。',
#  '點樣填新增電匯收款人嗰度',
#  '邊個可以教我點填TT？',
#  '渣打收匯款要填寫嘅資料是什麼呢？',
#  '朋友想匯錢畀我可以點做？',
#  '朋友要匯錢畀我我需要距嘅乜資料',
#  'SCBLHKHHXXX係咪即係渣打swift',
#  '渣打swift 是否SCBLHKHHXXXah?',
#  '朋友想匯錢畀我要有咩資料',
#  'SCBLHKHHXXX是否渣打swift',
#  '有人想海外匯款給予渣打, 銀行要點填？',
#  '其他人想海外匯款給予渣打, 銀行係填乜㗎？',
#  '渣打收匯款要點樣填？',
#  'SCBLHKHHXXX是渣打的swift嗎？',
#  '究竟要點填TT',
#  '人哋想匯錢畀我要填乜',
#  '渣打swift 係咪寫SCBLHKHHXXX',
#  '新加嘅電匯收款人係填咩呢？',
#  '新增電匯收款人嗰格該填寫什麼？',
#  '想海外匯款畀渣打銀行有乜要填',
#  '渣打收匯款有咩填',
#  '我想知新增電匯收款人要填乜嘢㗎？',
#  '新增電匯收款人嗰度要點填',
#  '海外匯款畀渣打銀行要填乜嘢吖',
#  '想問渣打收匯款點填㗎？',
#  '海外匯款畀渣打嘅手續銀行嗰格要點填㗎？',
#  '銀行份form要點寫先可以海外匯款畀渣打',
#  '我唔識TT要填咩',
#  '如果渣打收匯款填咩資料？',
#  '不懂填寫電匯。',
#  '我想知道如果有人想匯錢畀我，咁佢係咪有d咩資料要畀我呢？',
#  '有人要係海外匯錢過來渣打，銀行方面要填咩？',
#  '我想問下海外匯款畀渣打，係咪有d咩嘢需要填呢？',
#  '收匯款嘅渣打要填乜呢？',
#  '渣打收匯款嘅話係填咩？',
#  '人哋匯錢給我頂填寫什麼呢？',
#  '我想係渣打收匯款要點搞',
#  '係渣打收匯款有咩嘢要填',
#  '其他人匯款畀我應填寫什麼？',
#  '如果渣打收匯款要畀咩資料？',
#  '渣打收匯款要填乜呢？',
#  '你可唔可以教我填呢嗰TT？',
#  '想海外匯款畀渣打銀行要點做',
#  '我唔識點填電匯',
#  '朋友要點匯錢畀我',
#  '要點做, 畀咩資料詳情, 我個friend先匯到錢畀我?',
#  'Add電匯receiver 嗰度要填咩',
#  '若果渣打收匯款要填咩㗎？',
#  '你幫我填TT啦我唔識',
#  '話我知朋友匯錢畀我嘅話，我需要知道嘅資料。',
#  '朋友想匯錢畀我，佢要給予什麼資料畀我？',
#  '渣打要收匯款嗰陣要填d乜？',
#  '朋友想匯錢給我，他要提供咩資料予我呢？',
#  '渣打收匯款係咪要填咩呢？',
#  '新增電匯收款人嗰格填寫什麼？',
#  '銀行應填寫什麼，別人才可以由海外匯款予渣打?',
#  '點先可以係海外transfer money 畀渣打銀行',
#  '我想知道如果渣打收匯款的話，需要填寫什麼資料。',
#  '如果渣打收匯款需要填咩㗎？',
#  'SCBLHKHHXXX係咪就係渣打嘅swift',
#  '電匯點填㗎？',
#  '我想收對方匯款，人哋要點填表',
#  '渣打收匯款應該填什麼？',
#  '唔識點填TT',
#  '想海外匯款畀渣打銀行有咩嘢要填',
#  '我唔識點填TT',
#  '渣打收remittance嘅話使唔使填d乜嘢？',
#  '我想知道呢嗰新add嘅電匯收款人要點填。',
#  '有人想海外匯款畀渣打要填咩嘢？',
#  '我個friend要匯錢畀我要畀乜info我',
#  '有個人要匯錢畀我，要填咩資料？',
#  '做一筆TT要點操作',
#  '人哋匯畀我嘅錢可以填乜先可以攞到？',
#  '朋友想匯錢畀我要點做',
#  '如果人哋匯畀我錢，應該填乜？',
#  '朋友想匯錢畀我的話，佢應要提供乜嘢資料予我呢？',
#  '要收匯款嘅話渣打嗰邊點填',
#  '人哋想匯錢畀我有咩要填',
#  '我想confirm下渣打嘅swift係咪SCBLHKHHXXX?',
#  '我想問朋友要匯錢畀我，我需要咩資料呢？',
#  '朋友想匯錢畀我，佢要畀乜資料我㗎？',
#  '新增TT收款人嗰度寫咩㗎？',
#  '乜係我需要填嘅來收到人哋匯畀我嘅錢？',
#  '別人如何匯款給我',
#  '渣打嘅swift嘅代碼係唔係SCBLHKHHXXX？',
#  '我唔知道點填TT？',
#  '電匯點樣填？',
#  '我想知道如果有人要係外國匯款畀渣打，咁銀行要填咩？',
#  '渣打收匯款係填d咩？',
#  '請問渣打swift是SCBLHKHHXXX嗎？',
#  '渣打戶口收轉帳要點填表',
#  '朋友想匯錢畀我，他要給什麼資料予我？',
#  '人哋要匯款畀我要點搞',
#  '我有個朋友想匯D錢畀我，但係我哋唔知道要填咩資料。',
#  '人哋想匯錢畀我嘅話程序是什麼吖？',
#  'SCBLHKHHXXX係唔係渣打的swift code',
#  '想新增電匯收款人有乜嘢要填',
#  '我想問人哋要匯d錢過嚟嘅話要填d咩嘢？',
#  '要填乜來讓渣打收匯款？',
#  '添加電匯收款人嗰度要點填',
#  '朋友要畀乜資料我先可以匯錢畀我',
#  '有其他人想海外匯款畀渣打的話， 銀行要填d乜？',
#  '有人想海外匯款畀渣打要fill in 什麼？',
#  '新增嘅TT 收款人係點填呢？',
#  'TT我唔係好識填',
#  '渣打收匯款要填咩',
#  '填電匯嘅程序係咩？',
#  '渣打個swift code是咪SCBLHKHHXXX',
#  'TT要點填㗎？',
#  '我想請問下如果想做海外remittance畀渣打嘅話，係咪要填d咩嘢？',
#  '朋友要點做先可以匯錢畀我',
#  '我想海外匯款畀渣打，我應該填乜？',
#  '有人係外國匯錢過來畀渣打，bank嗰度要填咩？',
#  '新增電匯個收款人係要點填咩㗎？',
#  '其他人想匯錢畀我該填寫什麼？',
#  '人哋想匯錢畀我有咩嘢要填',
#  '點樣完成電匯？',
#  '你可以教我點填TT嘛？',
#  '別人匯款畀我係填咩㗎？',
#  '唔識填電匯',
#  '我要有咩資料朋友先可以匯錢給我？',
#  '我個朋友要匯錢畀我，我需要同佢攞咩資料？',
#  '海外transfer 啲錢畀渣打銀行要填乜嘢',
#  '海外匯款畀渣打銀行要點',
#  '你可唔可以教我填TT',
#  '想新增電匯收款人要點搞',
#  '想要海外匯款畀渣打， 銀行該填什麼？',
#  '如果想海外匯款畀渣打嘅話，要填乜呢？',
#  '渣打swift 係咪等於SCBLHKHHXXX?',
#  '新增嘅TT 收款人應該填咩？',
#  '如果渣打收匯款要點樣填form',
#  '其他人匯錢畀我頂填咩？',
#  '其他人想匯錢給我點填？',
#  '朋友想匯錢畀我的話，佢需要提供咩資料我？',
#  '我想請問下如果我有friend匯錢畀我嘅話，佢有冇d咩資料要畀我？',
#  '如果有人想海外匯款畀渣打， 銀行可以填什麼？',
#  'SCBLHKHHXXX是否渣打正確嘅swift?',
#  '渣打嘅客戶需要填乜來收到海外匯款？',
#  '人哋匯錢給我頂填寫乜？',
#  '電匯唔知要點寫',
#  '如果想海外匯款畀渣打銀行需要填咩呢？',
#  '別人匯錢畀我應填什麼？',
#  '有人想海外匯款畀渣打銀行要點整',
#  '假如我個friend要匯D錢畀我，佢需要填咩資料？',
#  '別人想匯錢點做？',
#  '渣打swift是否化表SCBLHKHHXXX？',
#  '請問一下渣打嘅swift係唔係SCBLHKHHXXX呢？',
#  '我想知道新增TT收款人正確填寫嘅資料。',
#  '有其他人想海外匯款畀渣打嘅話，銀行嗰度點樣填ah？',
#  'SCBLHKHHXXX係咪refer to渣打swift？',
#  '有人想轉d錢畀海外嘅渣打要點填',
#  '點樣填TT？',
#  '渣打收匯款要填什麼？',
#  '銀行要點填先可以海外匯款畀渣打',
#  '我想海外匯款畀渣打銀行應該填咩呢？',
#  '如果有人想海外匯款畀渣打銀行嗰邊要點填',
#  '我的朋友需要提供什麼資料才可以匯錢給我?',
#  '話我知渣打ge swift 是代確A正確嗎？',
#  '我唔識填電匯嗰份form',
#  '渣打收匯款要填什麼',
#  '人哋匯款畀我有咩要填',
#  '渣打收匯款正確該填寫什麼？',
#  '我唔知點填TT',
#  '新增電匯payee度點填',
#  '渣打的Swift 是SCBLHKHHXXX嗎？',
#  '新增電匯收款人嗰欄要填咩',
#  '他人匯錢給我嘅方式係咩呢？',
#  '渣打swift 應該是SCBLHKHHXXXma?',
#  '如果朋友要匯錢畀我需要d乜距嘅資料',
#  '想係渣打收匯款要點搞',
#  '要加個電匯收款人嗰話嗰一行要填乜',
#  '我想問新增TT收款人係填咩ga?',
#  '其他人匯款畀渣打,銀行係點樣填？',
#  '如果我個friend要匯錢畀我，佢要畀我咩info？',
#  '其他人匯錢嘅時候該填寫咩呢？',
#  '新增電匯個收款人要填咩資料？',
#  '我唔知道要點樣填呢嗰TT。',
#  '其他人想電匯畀我要點填表',
#  '點先可以係渣打收匯款',
#  '我有個朋友要匯錢畀我，但係我唔知道佢需要畀我咩資料。',
#  'TT怎樣填寫？',
#  '渣打收匯款的程序是什麼？',
#  '新增電匯收款人要填咩',
#  '我想問海外匯款畀渣打有咩手續要做？',
#  '新增TT收款人嗰度要填咩？',
#  '渣打swift 是不是SCBLHKHHXXX嗎？',
#  '新增電匯收款人要填什麼',
#  '點樣係渣打收匯款',
#  '人哋要匯款畀我唔知要填咩',
#  '渣打swift係咪用SCBLHKHHXXX',
#  '我唔識點填申請電匯份form',
#  'SCBLHKHHXXX是渣打嘅swift嘛？',
#  'SCBLHKHHXXX是渣打正確的swift ma?',
#  '填TT 的方法係咩呢？',
#  '渣打swift 係咪填SCBLHKHHXXX',
#  '朋友可以點匯錢畀我',
#  '新增電匯收款人嗰度係咪要填d乜嘢？',
#  '如果渣打收匯款要怎樣做？',
#  '人哋想匯錢畀我嘅話嘅手續是什麼？',
#  '話我知渣打嘅 swift係SCBLHKHHXXXma?',
#  '我想知新增嘅TT 收款人要填嘅嘢。',
#  'SCBLHKHHXXX係渣打嘅swift?',
#  '渣打swift 是否SCBLHKHHXXX',
#  '別人匯款畀渣打,銀行該怎麼填？',
#  '人哋匯錢過嚟要填d乜嘢？',
#  '點樣可以係渣打收匯款',
#  '話我知如果如果想海外匯款畀渣打銀行填咩吖？',
#  '渣打swift 係咪SCBLHKHHXXX㗎?',
#  '渣打swift係咪SCBLHKHHXXX',
#  '我唔知道呢嗰新增電匯嘅收款人要填D咩。',
#  '新增電匯收款人係要賣咩㗎？',
#  '渣打swift是否代表SCBLHKHHXXXga？',
#  '有人匯款去我係渣打嘅戶口，需要填咩資料？',
#  '新增電匯收款人嗰度寫咩',
#  '如果想海外匯款畀渣打，係咪要填d乜呢？',
#  '渣打嗰個swift係咪SCBLHKHHXXX',
#  '請教我填TT',
#  '朋友要畀咩資料我先可以匯錢畀我？',
#  '朋友想匯錢給我，佢需要咩資料我㗎？',
#  '朋友想匯錢畀我，我要準備咩資料？',
#  '我要有朋友什麼資料才可以成功匯款？',
#  '假如有個人要匯錢給我，他需要填什麼資料？',
#  '渣打收匯款有咩要填',
#  '我唔識點樣填TT',
#  '我想知點填渣打收匯款㗎？',
#  '新增TT收款人嗰度係要點樣填？',
#  '有冇人畀我知應該點填TT？',
#  '唔知要寫咩TT',
#  '要填d咩人哋先可以TT畀我？',
#  '可否告訴我朋友想匯錢畀我我需要畀咩資料？',
#  '渣打嘅swift code係唔係SCBLHKHHXXX',
#  '渣打swift 確認是SCBLHKHHXXX嗎？',
#  '我想通過渣打收匯款，請問要填乜？',
#  '渣打swift填SCBLHKHHXXX?',
#  '話我知新增電匯個收款人填咩呢？',
#  '想匯錢畀我的話頂填咩ah？',
#  '呢度寫住新增電匯收款人嗰欄需要填D咩？',
#  '如果我有個friend想匯錢畀我，我係咪要問佢拎d咩資料？',
#  '我想知道如果人哋要匯錢過嚟畀我嘅話要填d咩嘢？',
#  '有人想匯錢給我頂填d 咩呢？',
#  '有其他人匯錢給我該怎樣做？',
#  '渣打如果要收呢個匯款，要填乜嘢資料？',
#  '新增電匯收款人要寫咩',
#  '朋友想匯錢畀我我需要畀咩資料？',
#  'TT該怎樣填？',
#  '人哋先做一筆TT去我戶口點填',
#  '朋友想匯款給我他要給我什麼資料',
#  '我要有咩資料，朋友先可以匯錢畀我？',
#  '我想問如果有個朋友想匯錢畀我嘅時候，佢要畀咩資料我？',
#  '我需要有咩資料朋友先可以匯錢畀我？',
#  '有人想做海外嘅TT畀渣打,銀行要填乜',
#  '想新增電匯收款人有咩要填',
#  '新增電匯收款人嗰度寫咩㗎？',
#  '新增電匯收款人嗰個位置該寫什麼？',
#  '渣打嘅SCBLHKHHXXX係咪即係swift？',
#  '渣打要receive payment個話點填',
#  '我唔知點樣填TT',
#  '想渣打收匯款點填㗎？',
#  '新增電匯收款人嗰個位填咩㗎？',
#  '我想知道渣打要收匯款嘅時候係咪有d乜嘢要填？',
#  '新增電匯收款人嗰度該填D咩？',
#  '點樣填寫讓別人可以成功匯錢給我？',
#  'SCBLHKHHXXX係唔係渣打swift',
#  '新增電匯收款人嗰度要寫什麼ah?',
#  '渣打個swift code係咪SCBLHKHHXXX',
#  '需要填乜來讓渣打收到海外匯款？',
#  '渣打那個swift code是不是SCBLHKHHXXX',
#  '人哋想匯錢畀我要畀咩資料',
#  '新增TT收款人該填寫什麼？',
#  '要點樣填人哋先可以匯錢畀我',
#  '渣打收匯款應該點樣填？',
#  '其他人匯錢畀我要點樣做？',
#  '我的朋友想要匯錢給我，我們需要提供什麼資料？',
#  '我想知道如果我有個friend想匯錢畀我嘅時候，佢係咪要畀d乜嘢資料我？',
#  '渣打swift用SCBLHKHHXXX?',
#  '渣打swift 寫SCBLHKHHXXX?',
#  '朋友想匯錢畀我要畀乜嘢我',
#  'Add電匯receiver 要填咩',
#  '呢嗰新add嘅電匯收款人需要填咩？',
#  '話我知想渣打收匯款要點做呢？',
#  '我想知渣打收匯款要填寫ge 資料。',
#  '別人想海外匯款畀渣打係fill in d 乜？',
#  '朋友想匯錢畀我，我想知佢要畀咩資料我？',
#  '我唔識呢嗰新增電匯收款人嘅地方要點樣填。',
#  '在渣打收匯款要怎樣做',
#  '話我知點填電匯。',
#  'SCBLHKHHXXX是不是渣打swift',
#  '話我知朋友匯錢畀我嘅話要準備嘅資料。',
#  '新增電匯收款人嗰度要填咩先啱',
#  '其他人匯錢畀我該怎樣做？',
#  '如果我係渣打收取人哋匯過來嘅錢，需要咩資料？',
#  '海外匯款畀渣打要填d乜嘢？',
#  '有人想匯錢畀我要填咩',
#  '我想問如果想海外匯款畀渣打，係咪有d乜嘢要填呢？',
#  '渣打收匯款嘅話使唔使填d咩嘢呢？',
#  '我想知道渣打要收匯款嘅話係咪有d咩要填？',
#  '我想問人哋要匯錢畀我嘅話有咩嘢要填？',
#  '人哋想匯錢畀我嘅話頂填咩？',
#  '請問裡個TT點填？',
#  '我想請問渣打嘅swift係咪即係SCBLHKHHXXX？',
#  '不懂填TT的指示。',
#  '渣打swift是SCBLHKHHXXX嗎？',
#  '新增TT收款人嗰度正確要提供什麼？',
#  '朋友想匯錢畀我，我要知道咩資料呢？',
#  '如何海外匯款畀渣打銀行',
#  '如果渣打收匯款點樣填？',
#  '新增電匯收款人嗰度有冇嘢要填㗎呢？',
#  '如果渣打收匯款要點做？',
#  '新增TT收款人寫什麼才正確？',
#  '新增TT收款人嗰個位要填咩？',
#  '我唔識填呢嗰電匯。',
#  '人哋匯錢畀我嘅填乜㗎？',
#  '我想問下新增電匯收款人嗰度係咪有d咩嘢要填？',
#  '朋友想匯錢畀我有咩資料要畀我',
#  '有人想海外匯款畀渣打銀行要填什麼',
#  '渣打收匯款有乜要填',
#  '渣打嘅swift 是SCBLHKHHXXX嗎？',
#  '做TT嘅方法是什麼？',
#  '渣打收匯款有什麼要填',
#  '有人想海外匯款給予渣打, 銀行需要填寫什麼？',
#  '我想問新增電匯個收款人需要點樣填呢？',
#  '點先可以海外匯款畀渣打銀行',
#  '渣打需要填乜先可以收到海外匯款？',
#  '朋友要匯錢畀我，佢需要提供的資料是什麼？',
#  '有人想匯款畀我該填寫什麼？',
#  '如果我想通過渣打收匯款要填乜？',
#  '怎樣知道SCBLHKHHXXX是渣打swift?',
#  '渣打嘅銀行代碼係咪SCBLHKHHXXX',
#  '電匯要點填法',
#  '海外匯款予渣打的話，銀行要填乜嘢㗎？',
#  '渣打swift 是不是SCBLHKHHXXX',
#  '乜係要填嘅先可以海外匯款畀渣打？',
#  '如果要添加電匯收款人要寫d乜',
#  'SCBLHKHHXXX係唔係渣打的swift？',
#  '你可以教我點填電匯份表格嘛？',
#  '渣打嗰邊收匯款要填乜',
#  '想要海外匯款畀渣打嘅話， 我想問銀行要寫D乜嘢？',
#  '人哋要點填先可以匯錢畀我',
#  '如果有人想要匯錢畀我，佢需要填D咩？',
#  '朋友想匯錢畀我要畀咩資料我',
#  '我想請教你，如果有人想從海外匯錢給渣打，銀行需要填什麼資料？',
#  '我想問下渣打嘅swift係唔係即係SCBLHKHHXXX？',
#  '在海外匯款畀渣打銀行要填什麼',
#  '如果想海外匯款畀渣打，有冇d乜嘢需要填？',
#  '如果朋友想匯錢畀我，佢需要提供什麼資料給我㗎？',
#  '話我知TT 點填。',
#  '呢嗰TT要點樣填？',
#  '電匯怎樣做？',
#  '人哋想匯錢畀我要填咩？',
#  '渣打收匯款係咪有d咩嘢要填呢？',
#  '我需要朋友嘅乜資料先可以接受距嘅bank transfer',
#  'TT要填乜嘢吖',
#  '係海外匯款給予渣打， 銀行係填咩？',
#  '我想知渣打收匯款怎樣填寫？',
#  '朋友想匯錢畀我，我需提供咩資料？',
#  '想add電匯收款人要填乜',
#  '我想知道SCBLHKHHXXX是否渣打的swift。',
#  '我提供咩資料先可以收取朋友的匯款？',
#  'TT要點填？',
#  'TT怎樣做？',
#  '新增嘅電匯收款人填什麼呢？',
#  '可唔可以話畀我知如果渣打收匯款要填乜？',
#  '我唔知點填電匯張form',
#  '如何填寫電匯？',
#  '我個Friend想匯返D錢畀我, 仲要畀咩資料我?',
#  '渣打收匯款嘅話需要咩手續',
#  '朋友希望匯錢畀我我必需具備什麼資料㗎？',
#  '要給予我什麼資料朋友才可以匯錢給我？',
#  '有人要匯錢畀我要填乜嘢',
#  '朋友匯款畀我要有什麼資料',
#  'scb tt code?',
#  'swift',
#  'swiftcode',
#  'swiftcode?',
#  '我要收匯款，要提供咩資料畀對方?',
#  '我要收款，要swiftcode',
#  '收取電匯所需資料',
#  '你好，請問我在國內向我的香港銀行匯款，需要提供rgts代碼',
#  '銀行的swift是什麼',
#  '我有國際匯款到我戶口，想問swift同sort code',
#  '你們的swift code資料是什麼?',
#  '請問貴行美元帳戶的swift code是？',
#  '收款人哋址',
#  '收款人資料地址',
#  '其他人係hk匯款至我渣打香港戶口，帳戶號碼前面加什麼數字？',
#  '匯款所需要用到的swift',
#  '匯款 code',
#  '匯款信息',
#  '銀行代碼',
#  '公司編號1111，請問如果寄出口文件到貴行的地址是哪裡']

# %%
# --------------faq------------
path = 'faq_2.xml'
tree = read_xml(path)

nodes = find_nodes(tree, "intents/intent/qa")

for a, b in r.items():
    scid = a
    toAddList = list(b)
    result_nodes = get_node_by_keyvalue(nodes, {"label": scid})    
    
    if len(result_nodes) == 0:
        print (scid)
        continue
    
    for i in range(len(toAddList)):
        content = toAddList[i]

        a = create_node("question", {"id":hashify(content),"scope":"train.annotation", "source":"scb.annotation.190226"}, content)
        if i==len(toAddList)-1:
            a = create_node("question", {"id":hashify(content),"scope":"train.annotation", "source":"scb.annotation.190226"}, content, tail=3)
        add_child_node(result_nodes, a)

new_path = "faq_2_added.xml"
write_xml(tree, new_path)
# Out:
# SC503
#
# SC423
